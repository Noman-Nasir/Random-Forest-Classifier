# %% [markdown]
# # Assignment No 4b
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of **Random Axis-Aligned** weak learner based Random Forest, i.e. you will be randomly selecting the feature from all set of features and than setting the threshold by randomly selecting a threshold.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## TODO:
#
# **Complete the code in files `randomForest.py`, `tree.py` and `weakLearner.py` by writing the missing code.**
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# !pip install nose
# %load_ext autoreload
# %autoreload 2
# Out:
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 2.8MB/s
# Installing collected packages: nose
# Successfully installed nose-1.3.7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/'Colab Notebooks'/'Assignment 4'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/Assignment 4

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples//4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples//4,1)),2*np.ones((nexamples//4,1)),3*np.ones((nexamples//4,1)),4*np.ones((nexamples//4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples//4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples//4,1)),2*np.ones((ntexamples//4,1)),3*np.ones((ntexamples//4,1)),4*np.ones((ntexamples//4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random')

# %%
print (X.shape, Y.shape)
# Out:
# (2000, 2) (2000, 1)

# %%
#%debug
rfc.train(X,Y)
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 436 Examples, and Right Node with 1564 Examples
# Creating Left Child Node With 222 Examples, and Right Node with 214 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=222, classes=[(1.0, 1.0)]
# Creating Left Child Node With 214 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 214 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=214, classes=[(4.0, 0.9953271028037384), (1.0, 0.004672897196261682)]
# Creating Left Child Node With 565 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 276 Examples, and Right Node with 289 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 276 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=276, classes=[(1.0, 0.9927536231884058), (4.0, 0.007246376811594203)]
# Creating Left Child Node With 289 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=289, classes=[(4.0, 0.986159169550173), (2.0, 0.010380622837370242), (1.0, 0.0034602076124567475)]
# Creating Left Child Node With 501 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 501 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=501, classes=[(3.0, 0.9960079840319361), (1.0, 0.003992015968063872)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
#
# Creating tree # 2
# Creating Left Child Node With 1999 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1001 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1001, classes=[(4.0, 0.4995004995004995), (1.0, 0.4975024975024975), (2.0, 0.002997002997002997)]
# Creating Left Child Node With 0 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=500, classes=[(3.0, 0.996), (1.0, 0.004)]
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1001, classes=[(4.0, 0.4995004995004995), (1.0, 0.4975024975024975), (2.0, 0.002997002997002997)]
# Creating Left Child Node With 998 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=500, classes=[(3.0, 0.996), (1.0, 0.004)]
# Creating Left Child Node With 498 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
#
# Creating tree # 4
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 1001 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 503 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=498, classes=[(1.0, 0.9959839357429718), (4.0, 0.004016064257028112)]
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Left Child Node With 223 Examples, and Right Node with 776 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=223, classes=[(3.0, 1.0)]
# Creating Left Child Node With 775 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 775 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=775, classes=[(2.0, 0.6412903225806451), (3.0, 0.3561290322580645), (1.0, 0.0025806451612903226)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
#
# Creating tree # 5
# Creating Left Child Node With 1572 Examples, and Right Node with 428 Examples
# Creating Left Child Node With 999 Examples, and Right Node with 573 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 998 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Left Child Node With 497 Examples, and Right Node with 501 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
# Creating Child Node With ClassLabel=3.0, nexamples=501, classes=[(3.0, 0.9960079840319361), (1.0, 0.003992015968063872)]
# Creating Left Child Node With 0 Examples, and Right Node with 573 Examples
# Creating Left Child Node With 279 Examples, and Right Node with 294 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=279, classes=[(4.0, 0.985663082437276), (1.0, 0.007168458781362007), (2.0, 0.007168458781362007)]
# Creating Child Node With ClassLabel=2.0, nexamples=294, classes=[(2.0, 0.9965986394557823), (3.0, 0.003401360544217687)]
# Creating Left Child Node With 0 Examples, and Right Node with 428 Examples
# Creating Left Child Node With 224 Examples, and Right Node with 204 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 224 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=224, classes=[(4.0, 0.9955357142857143), (2.0, 0.004464285714285714)]
# Creating Child Node With ClassLabel=2.0, nexamples=204, classes=[(2.0, 1.0)]
#
# Creating tree # 6
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 497 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Left Child Node With 497 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 503 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Left Child Node With 501 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 500 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 500 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=500, classes=[(3.0, 0.996), (1.0, 0.004)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
#
# Creating tree # 7
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 998 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 497 Examples, and Right Node with 501 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
# Creating Child Node With ClassLabel=3.0, nexamples=501, classes=[(3.0, 0.9960079840319361), (1.0, 0.003992015968063872)]
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
#
# Creating tree # 8
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 998 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Left Child Node With 998 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 998 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=998, classes=[(3.0, 0.5), (1.0, 0.49799599198396793), (4.0, 0.002004008016032064)]
# Creating Left Child Node With 0 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
#
# Creating tree # 9
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 998 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Left Child Node With 497 Examples, and Right Node with 501 Examples
# Creating Left Child Node With 497 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
# Creating Left Child Node With 500 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=500, classes=[(3.0, 0.996), (1.0, 0.004)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]
#
# Creating tree # 10
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 501 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 497 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=1, classes=[(1.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
# Creating Left Child Node With 500 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 500 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=500, classes=[(3.0, 0.996), (1.0, 0.004)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 503 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=503, classes=[(4.0, 0.9900596421471173), (2.0, 0.005964214711729622), (1.0, 0.003976143141153081)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]

# %%
len(rfc.trees)
# Out:
# 10

# %%
# Training Confusion Matrix...
# %pdb

Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        496    0    2    2   500
# 2.0          0  497    0    3   500
# 3.0          0    1  499    0   500
# 4.0          2    0    0  498   500
# All        498  498  501  503  2000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.995

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-raa-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print (Yt.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (1000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        250    0    0    0   250
# 2.0          0  249    0    1   250
# 3.0          3    1  246    0   250
# 4.0          1    0    0  249   250
# All        254  250  246  250  1000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Yt))
acc = np.sum(tlabels == plabels) / len(Yt)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.994

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows = int(ntrees/2)
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Axis-Aligned-Random',usebagging=False)
rfc.train(X,Y)
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 13664 Examples, and Right Node with 16336 Examples
# Creating Left Child Node With 11651 Examples, and Right Node with 2013 Examples
# Creating Left Child Node With 4489 Examples, and Right Node with 7162 Examples
# Creating Left Child Node With 549 Examples, and Right Node with 3940 Examples
# Creating Child Node With ClassLabel=0, nexamples=549, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3940, classes=[(0, 0.8324873096446701), (2, 0.16751269035532995)]
# Creating Left Child Node With 0 Examples, and Right Node with 7162 Examples
# Creating Child Node With ClassLabel=2, nexamples=7162, classes=[(2, 0.8371963138788048), (1, 0.09522479754258587), (0, 0.06757888857860933)]
# Creating Left Child Node With 1610 Examples, and Right Node with 403 Examples
# Creating Left Child Node With 1610 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=1610, classes=[(0, 0.9993788819875776), (1, 0.0006211180124223603)]
# Creating Child Node With ClassLabel=1, nexamples=403, classes=[(1, 1.0)]
# Creating Left Child Node With 10816 Examples, and Right Node with 5520 Examples
# Creating Left Child Node With 1215 Examples, and Right Node with 9601 Examples
# Creating Child Node With ClassLabel=2, nexamples=1215, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 9601 Examples
# Creating Child Node With ClassLabel=1, nexamples=9601, classes=[(1, 0.4994271430059369), (0, 0.42474742214352673), (2, 0.0758254348505364)]
# Creating Left Child Node With 1301 Examples, and Right Node with 4219 Examples
# Creating Child Node With ClassLabel=2, nexamples=1301, classes=[(2, 1.0)]
# Creating Left Child Node With 1407 Examples, and Right Node with 2812 Examples
# Creating Child Node With ClassLabel=1, nexamples=1407, classes=[(1, 0.929637526652452), (2, 0.07036247334754797)]
# Creating Child Node With ClassLabel=1, nexamples=2812, classes=[(1, 0.9996443812233285), (2, 0.00035561877667140827)]
#
# Creating tree # 2
# Creating Left Child Node With 13664 Examples, and Right Node with 16336 Examples
# Creating Left Child Node With 4683 Examples, and Right Node with 8981 Examples
# Creating Left Child Node With 549 Examples, and Right Node with 4134 Examples
# Creating Child Node With ClassLabel=0, nexamples=549, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 4134 Examples
# Creating Child Node With ClassLabel=0, nexamples=4134, classes=[(0, 0.8374455732946299), (2, 0.15965166908563136), (1, 0.002902757619738752)]
# Creating Left Child Node With 7162 Examples, and Right Node with 1819 Examples
# Creating Left Child Node With 7162 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=7162, classes=[(2, 0.8371963138788048), (1, 0.09522479754258587), (0, 0.06757888857860933)]
# Creating Left Child Node With 1427 Examples, and Right Node with 392 Examples
# Creating Child Node With ClassLabel=0, nexamples=1427, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=392, classes=[(1, 1.0)]
# Creating Left Child Node With 16043 Examples, and Right Node with 293 Examples
# Creating Left Child Node With 10816 Examples, and Right Node with 5227 Examples
# Creating Left Child Node With 4716 Examples, and Right Node with 6100 Examples
# Creating Child Node With ClassLabel=1, nexamples=4716, classes=[(1, 0.7417302798982188), (2, 0.25763358778625955), (0, 0.0006361323155216285)]
# Creating Child Node With ClassLabel=0, nexamples=6100, classes=[(0, 0.6680327868852459), (1, 0.21262295081967214), (2, 0.11934426229508197)]
# Creating Left Child Node With 1108 Examples, and Right Node with 4119 Examples
# Creating Child Node With ClassLabel=2, nexamples=1108, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=4119, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=293, classes=[(2, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 13915 Examples, and Right Node with 16085 Examples
# Creating Left Child Node With 6491 Examples, and Right Node with 7424 Examples
# Creating Left Child Node With 2565 Examples, and Right Node with 3926 Examples
# Creating Left Child Node With 911 Examples, and Right Node with 1654 Examples
# Creating Child Node With ClassLabel=0, nexamples=911, classes=[(0, 0.9615806805708014), (2, 0.038419319429198684)]
# Creating Child Node With ClassLabel=2, nexamples=1654, classes=[(2, 0.9854897218863361), (0, 0.014510278113663845)]
# Creating Left Child Node With 1811 Examples, and Right Node with 2115 Examples
# Creating Child Node With ClassLabel=0, nexamples=1811, classes=[(0, 0.6631695196024296), (2, 0.3368304803975704)]
# Creating Child Node With ClassLabel=2, nexamples=2115, classes=[(2, 0.6775413711583924), (1, 0.3224586288416076)]
# Creating Left Child Node With 2516 Examples, and Right Node with 4908 Examples
# Creating Child Node With ClassLabel=2, nexamples=2516, classes=[(2, 1.0)]
# Creating Left Child Node With 4809 Examples, and Right Node with 99 Examples
# Creating Child Node With ClassLabel=1, nexamples=4809, classes=[(1, 0.9993761696818465), (0, 0.0006238303181534623)]
# Creating Child Node With ClassLabel=2, nexamples=99, classes=[(2, 1.0)]
# Creating Left Child Node With 11476 Examples, and Right Node with 4609 Examples
# Creating Left Child Node With 11476 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 11476 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=11476, classes=[(0, 0.5299756012547926), (2, 0.3204078075984664), (1, 0.14961659114674103)]
# Creating Left Child Node With 3352 Examples, and Right Node with 1257 Examples
# Creating Left Child Node With 1610 Examples, and Right Node with 1742 Examples
# Creating Child Node With ClassLabel=0, nexamples=1610, classes=[(0, 0.9993788819875776), (1, 0.0006211180124223603)]
# Creating Child Node With ClassLabel=1, nexamples=1742, classes=[(1, 0.8823191733639495), (0, 0.11768082663605052)]
# Creating Child Node With ClassLabel=1, nexamples=1257, classes=[(1, 1.0)]
#
# Creating tree # 4
# Creating Left Child Node With 5081 Examples, and Right Node with 24919 Examples
# Creating Left Child Node With 911 Examples, and Right Node with 4170 Examples
# Creating Left Child Node With 51 Examples, and Right Node with 860 Examples
# Creating Child Node With ClassLabel=0, nexamples=51, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 860 Examples
# Creating Child Node With ClassLabel=0, nexamples=860, classes=[(0, 0.9593023255813954), (2, 0.040697674418604654)]
# Creating Left Child Node With 1654 Examples, and Right Node with 2516 Examples
# Creating Left Child Node With 25 Examples, and Right Node with 1629 Examples
# Creating Child Node With ClassLabel=0, nexamples=25, classes=[(0, 0.88), (2, 0.12)]
# Creating Child Node With ClassLabel=2, nexamples=1629, classes=[(2, 0.9987722529158993), (0, 0.0012277470841006752)]
# Creating Child Node With ClassLabel=2, nexamples=2516, classes=[(2, 1.0)]
# Creating Left Child Node With 8834 Examples, and Right Node with 16085 Examples
# Creating Left Child Node With 3926 Examples, and Right Node with 4908 Examples
# Creating Left Child Node With 1811 Examples, and Right Node with 2115 Examples
# Creating Child Node With ClassLabel=0, nexamples=1811, classes=[(0, 0.6631695196024296), (2, 0.3368304803975704)]
# Creating Child Node With ClassLabel=2, nexamples=2115, classes=[(2, 0.6775413711583924), (1, 0.3224586288416076)]
# Creating Left Child Node With 0 Examples, and Right Node with 4908 Examples
# Creating Child Node With ClassLabel=1, nexamples=4908, classes=[(1, 0.9792176039119804), (2, 0.020171149144254278), (0, 0.0006112469437652812)]
# Creating Left Child Node With 13273 Examples, and Right Node with 2812 Examples
# Creating Left Child Node With 12044 Examples, and Right Node with 1229 Examples
# Creating Child Node With ClassLabel=0, nexamples=12044, classes=[(0, 0.6555961474593158), (2, 0.30521421454666225), (1, 0.03918963799402192)]
# Creating Child Node With ClassLabel=1, nexamples=1229, classes=[(1, 1.0)]
# Creating Left Child Node With 2811 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=1, nexamples=2811, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
#
# Creating tree # 5
# Creating Left Child Node With 5081 Examples, and Right Node with 24919 Examples
# Creating Left Child Node With 911 Examples, and Right Node with 4170 Examples
# Creating Left Child Node With 51 Examples, and Right Node with 860 Examples
# Creating Child Node With ClassLabel=0, nexamples=51, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 860 Examples
# Creating Child Node With ClassLabel=0, nexamples=860, classes=[(0, 0.9593023255813954), (2, 0.040697674418604654)]
# Creating Left Child Node With 1654 Examples, and Right Node with 2516 Examples
# Creating Left Child Node With 25 Examples, and Right Node with 1629 Examples
# Creating Child Node With ClassLabel=0, nexamples=25, classes=[(0, 0.88), (2, 0.12)]
# Creating Child Node With ClassLabel=2, nexamples=1629, classes=[(2, 0.9987722529158993), (0, 0.0012277470841006752)]
# Creating Child Node With ClassLabel=2, nexamples=2516, classes=[(2, 1.0)]
# Creating Left Child Node With 11099 Examples, and Right Node with 13820 Examples
# Creating Left Child Node With 3772 Examples, and Right Node with 7327 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 3274 Examples
# Creating Child Node With ClassLabel=0, nexamples=498, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3274, classes=[(0, 0.8054367745876604), (2, 0.19089798411728773), (1, 0.0036652412950519244)]
# Creating Left Child Node With 5508 Examples, and Right Node with 1819 Examples
# Creating Child Node With ClassLabel=2, nexamples=5508, classes=[(2, 0.7926652142338417), (1, 0.12381989832970225), (0, 0.08351488743645606)]
# Creating Child Node With ClassLabel=0, nexamples=1819, classes=[(0, 0.7844969763606378), (1, 0.21550302363936227)]
# Creating Left Child Node With 4908 Examples, and Right Node with 8912 Examples
# Creating Left Child Node With 4809 Examples, and Right Node with 99 Examples
# Creating Child Node With ClassLabel=1, nexamples=4809, classes=[(1, 0.9993761696818465), (0, 0.0006238303181534623)]
# Creating Child Node With ClassLabel=2, nexamples=99, classes=[(2, 1.0)]
# Creating Left Child Node With 6316 Examples, and Right Node with 2596 Examples
# Creating Child Node With ClassLabel=0, nexamples=6316, classes=[(0, 0.6127295756808107), (1, 0.27184927169094364), (2, 0.11542115262824572)]
# Creating Child Node With ClassLabel=1, nexamples=2596, classes=[(1, 0.9210323574730355), (0, 0.07896764252696456)]
#
# Creating tree # 6
# Creating Left Child Node With 13915 Examples, and Right Node with 16085 Examples
# Creating Left Child Node With 5081 Examples, and Right Node with 8834 Examples
# Creating Left Child Node With 143 Examples, and Right Node with 4938 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 143 Examples
# Creating Child Node With ClassLabel=2, nexamples=143, classes=[(2, 0.6153846153846154), (0, 0.38461538461538464)]
# Creating Left Child Node With 0 Examples, and Right Node with 4938 Examples
# Creating Child Node With ClassLabel=2, nexamples=4938, classes=[(2, 0.8288780882948562), (0, 0.1711219117051438)]
# Creating Left Child Node With 8834 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 8834 Examples
# Creating Child Node With ClassLabel=1, nexamples=8834, classes=[(1, 0.6212361331220285), (2, 0.24247226624405704), (0, 0.13629160063391443)]
# Creating Left Child Node With 1961 Examples, and Right Node with 14124 Examples
# Creating Left Child Node With 1950 Examples, and Right Node with 11 Examples
# Creating Left Child Node With 1767 Examples, and Right Node with 183 Examples
# Creating Child Node With ClassLabel=0, nexamples=1767, classes=[(0, 0.9915110356536503), (2, 0.008488964346349746)]
# Creating Child Node With ClassLabel=0, nexamples=183, classes=[(0, 0.994535519125683), (1, 0.00546448087431694)]
# Creating Child Node With ClassLabel=1, nexamples=11, classes=[(1, 1.0)]
# Creating Left Child Node With 5212 Examples, and Right Node with 8912 Examples
# Creating Left Child Node With 3393 Examples, and Right Node with 1819 Examples
# Creating Child Node With ClassLabel=2, nexamples=3393, classes=[(2, 0.8644267609784851), (0, 0.13557323902151489)]
# Creating Child Node With ClassLabel=0, nexamples=1819, classes=[(0, 0.7844969763606378), (1, 0.21550302363936227)]
# Creating Left Child Node With 8911 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=1, nexamples=8911, classes=[(1, 0.4610032544046684), (0, 0.4572999663337448), (2, 0.0816967792615868)]
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 5081 Examples, and Right Node with 24919 Examples
# Creating Left Child Node With 143 Examples, and Right Node with 4938 Examples
# Creating Left Child Node With 58 Examples, and Right Node with 85 Examples
# Creating Left Child Node With 33 Examples, and Right Node with 25 Examples
# Creating Child Node With ClassLabel=0, nexamples=33, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=25, classes=[(0, 0.88), (2, 0.12)]
# Creating Child Node With ClassLabel=2, nexamples=85, classes=[(2, 1.0)]
# Creating Left Child Node With 4938 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 4938 Examples
# Creating Child Node With ClassLabel=2, nexamples=4938, classes=[(2, 0.8288780882948562), (0, 0.1711219117051438)]
# Creating Left Child Node With 11099 Examples, and Right Node with 13820 Examples
# Creating Left Child Node With 9086 Examples, and Right Node with 2013 Examples
# Creating Left Child Node With 9086 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=9086, classes=[(2, 0.5493066255778121), (0, 0.37563284173453665), (1, 0.07506053268765134)]
# Creating Left Child Node With 0 Examples, and Right Node with 2013 Examples
# Creating Child Node With ClassLabel=0, nexamples=2013, classes=[(0, 0.799304520615996), (1, 0.20069547938400398)]
# Creating Left Child Node With 4908 Examples, and Right Node with 8912 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 4908 Examples
# Creating Child Node With ClassLabel=1, nexamples=4908, classes=[(1, 0.9792176039119804), (2, 0.020171149144254278), (0, 0.0006112469437652812)]
# Creating Left Child Node With 6100 Examples, and Right Node with 2812 Examples
# Creating Child Node With ClassLabel=0, nexamples=6100, classes=[(0, 0.6680327868852459), (1, 0.21262295081967214), (2, 0.11934426229508197)]
# Creating Child Node With ClassLabel=1, nexamples=2812, classes=[(1, 0.9996443812233285), (2, 0.00035561877667140827)]
#
# Creating tree # 8
# Creating Left Child Node With 5081 Examples, and Right Node with 24919 Examples
# Creating Left Child Node With 4888 Examples, and Right Node with 193 Examples
# Creating Left Child Node With 911 Examples, and Right Node with 3977 Examples
# Creating Left Child Node With 33 Examples, and Right Node with 878 Examples
# Creating Child Node With ClassLabel=0, nexamples=33, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=878, classes=[(0, 0.9601366742596811), (2, 0.03986332574031891)]
# Creating Left Child Node With 3977 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=3977, classes=[(2, 0.993965300477747), (0, 0.0060346995222529546)]
# Creating Child Node With ClassLabel=2, nexamples=193, classes=[(2, 1.0)]
# Creating Left Child Node With 8834 Examples, and Right Node with 16085 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 8834 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 8834 Examples
# Creating Child Node With ClassLabel=1, nexamples=8834, classes=[(1, 0.6212361331220285), (2, 0.24247226624405704), (0, 0.13629160063391443)]
# Creating Left Child Node With 11476 Examples, and Right Node with 4609 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 11476 Examples
# Creating Child Node With ClassLabel=0, nexamples=11476, classes=[(0, 0.5299756012547926), (2, 0.3204078075984664), (1, 0.14961659114674103)]
# Creating Left Child Node With 2013 Examples, and Right Node with 2596 Examples
# Creating Child Node With ClassLabel=0, nexamples=2013, classes=[(0, 0.799304520615996), (1, 0.20069547938400398)]
# Creating Child Node With ClassLabel=1, nexamples=2596, classes=[(1, 0.9210323574730355), (0, 0.07896764252696456)]
#
# Creating tree # 9
# Creating Left Child Node With 4683 Examples, and Right Node with 25317 Examples
# Creating Left Child Node With 2722 Examples, and Right Node with 1961 Examples
# Creating Left Child Node With 490 Examples, and Right Node with 2232 Examples
# Creating Child Node With ClassLabel=0, nexamples=490, classes=[(0, 1.0)]
# Creating Left Child Node With 2232 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=2232, classes=[(0, 0.7110215053763441), (2, 0.28897849462365593)]
# Creating Left Child Node With 1950 Examples, and Right Node with 11 Examples
# Creating Left Child Node With 1767 Examples, and Right Node with 183 Examples
# Creating Child Node With ClassLabel=0, nexamples=1767, classes=[(0, 0.9915110356536503), (2, 0.008488964346349746)]
# Creating Child Node With ClassLabel=0, nexamples=183, classes=[(0, 0.994535519125683), (1, 0.00546448087431694)]
# Creating Child Node With ClassLabel=1, nexamples=11, classes=[(1, 1.0)]
# Creating Left Child Node With 4170 Examples, and Right Node with 21147 Examples
# Creating Left Child Node With 110 Examples, and Right Node with 4060 Examples
# Creating Left Child Node With 25 Examples, and Right Node with 85 Examples
# Creating Child Node With ClassLabel=0, nexamples=25, classes=[(0, 0.88), (2, 0.12)]
# Creating Child Node With ClassLabel=2, nexamples=85, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 4060 Examples
# Creating Child Node With ClassLabel=2, nexamples=4060, classes=[(2, 0.9995073891625615), (0, 0.0004926108374384236)]
# Creating Left Child Node With 7023 Examples, and Right Node with 14124 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 7023 Examples
# Creating Child Node With ClassLabel=1, nexamples=7023, classes=[(1, 0.7814324362807917), (2, 0.21814039584223266), (0, 0.00042716787697565144)]
# Creating Left Child Node With 9709 Examples, and Right Node with 4415 Examples
# Creating Child Node With ClassLabel=0, nexamples=9709, classes=[(0, 0.4459779585951179), (2, 0.37717581625296115), (1, 0.1768462251519209)]
# Creating Child Node With ClassLabel=1, nexamples=4415, classes=[(1, 0.6303510758776897), (0, 0.3696489241223103)]
#
# Creating tree # 10
# Creating Left Child Node With 5081 Examples, and Right Node with 24919 Examples
# Creating Left Child Node With 143 Examples, and Right Node with 4938 Examples
# Creating Left Child Node With 143 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 58 Examples, and Right Node with 85 Examples
# Creating Child Node With ClassLabel=0, nexamples=58, classes=[(0, 0.9482758620689655), (2, 0.05172413793103448)]
# Creating Child Node With ClassLabel=2, nexamples=85, classes=[(2, 1.0)]
# Creating Left Child Node With 2507 Examples, and Right Node with 2431 Examples
# Creating Left Child Node With 878 Examples, and Right Node with 1629 Examples
# Creating Child Node With ClassLabel=0, nexamples=878, classes=[(0, 0.9601366742596811), (2, 0.03986332574031891)]
# Creating Child Node With ClassLabel=2, nexamples=1629, classes=[(2, 0.9987722529158993), (0, 0.0012277470841006752)]
# Creating Child Node With ClassLabel=2, nexamples=2431, classes=[(2, 1.0)]
# Creating Left Child Node With 11099 Examples, and Right Node with 13820 Examples
# Creating Left Child Node With 3772 Examples, and Right Node with 7327 Examples
# Creating Left Child Node With 498 Examples, and Right Node with 3274 Examples
# Creating Child Node With ClassLabel=0, nexamples=498, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3274, classes=[(0, 0.8054367745876604), (2, 0.19089798411728773), (1, 0.0036652412950519244)]
# Creating Left Child Node With 5508 Examples, and Right Node with 1819 Examples
# Creating Child Node With ClassLabel=2, nexamples=5508, classes=[(2, 0.7926652142338417), (1, 0.12381989832970225), (0, 0.08351488743645606)]
# Creating Child Node With ClassLabel=0, nexamples=1819, classes=[(0, 0.7844969763606378), (1, 0.21550302363936227)]
# Creating Left Child Node With 9601 Examples, and Right Node with 4219 Examples
# Creating Left Child Node With 3501 Examples, and Right Node with 6100 Examples
# Creating Child Node With ClassLabel=1, nexamples=3501, classes=[(1, 0.9991431019708654), (0, 0.000856898029134533)]
# Creating Child Node With ClassLabel=0, nexamples=6100, classes=[(0, 0.6680327868852459), (1, 0.21262295081967214), (2, 0.11934426229508197)]
# Creating Left Child Node With 4119 Examples, and Right Node with 100 Examples
# Creating Child Node With ClassLabel=1, nexamples=4119, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=100, classes=[(2, 1.0)]

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9330   208   462  10000
# 1            594  8724   682  10000
# 2           1392    99  8509  10000
# All        11316  9031  9653  30000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.8854333333333333

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print (Ytest.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (15000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4700   107   193   5000
# 1           294  4382   324   5000
# 2           680    49  4271   5000
# All        5674  4538  4788  15000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Ytest))
acc = np.sum(tlabels == plabels) / len(Ytest)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.8902

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=int(ntrees/2)
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, V_train, Y_train, V_test = train_test_split(X, Y, train_size=0.8)
print(X_train.shape, V_train.shape, Y_train.shape, V_test.shape)
# Out:
# (24000, 2) (6000, 2) (24000,) (6000,)

# %%
rfc = rf.RandomForest(weaklearner="Axis-Aligned-Random", usebagging= True)
rfc.train(X_train,Y_train, V_train, V_test)
# rfc.train(X_train,Y_train)
# Out:
# Creating Classifier with 10 trees.
# Accuracy of Classifier with 10 trees is 80.81666666666666.
# Creating Classifier with 12 trees.
# Accuracy of Classifier with 12 trees is 84.65.
# Creating Classifier with 14 trees.
# Accuracy of Classifier with 14 trees is 89.23333333333333.
# Creating Classifier with 16 trees.
# Accuracy of Classifier with 16 trees is 89.25.
# Creating Classifier with 18 trees.
# Accuracy of Classifier with 18 trees is 87.98333333333333.
# Creating Classifier with 20 trees.
# Accuracy of Classifier with 20 trees is 87.66666666666667.
# Creating Classifier with 22 trees.
# Accuracy of Classifier with 22 trees is 87.66666666666667.
# Creating Classifier with 24 trees.
# Accuracy of Classifier with 24 trees is 89.23333333333333.
# Creating Classifier with 26 trees.
# Accuracy of Classifier with 26 trees is 87.7.
# Creating Classifier with 28 trees.
# Accuracy of Classifier with 28 trees is 88.94999999999999.
# Creating Classifier with 30 trees.
# Accuracy of Classifier with 30 trees is 87.94999999999999.
# Validation Comple. Optimal Parameters: Trees =  16 with Accuracy 0.8925
#
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 2451 Examples, and Right Node with 11949 Examples
# Creating Left Child Node With 1826 Examples, and Right Node with 625 Examples
# Creating Left Child Node With 441 Examples, and Right Node with 1385 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 418 Examples
# Creating Child Node With ClassLabel=0, nexamples=23, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=418, classes=[(0, 0.9760765550239234), (2, 0.023923444976076555)]
# Creating Left Child Node With 41 Examples, and Right Node with 1344 Examples
# Creating Child Node With ClassLabel=2, nexamples=41, classes=[(2, 0.7560975609756098), (0, 0.24390243902439024)]
# Creating Child Node With ClassLabel=2, nexamples=1344, classes=[(2, 0.9992559523809523), (0, 0.000744047619047619)]
# Creating Child Node With ClassLabel=2, nexamples=625, classes=[(2, 1.0)]
# Creating Left Child Node With 4220 Examples, and Right Node with 7729 Examples
# Creating Left Child Node With 4220 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 1849 Examples, and Right Node with 2371 Examples
# Creating Child Node With ClassLabel=2, nexamples=1849, classes=[(2, 0.5294753921038399), (0, 0.3055705786911844), (1, 0.16495402920497565)]
# Creating Child Node With ClassLabel=1, nexamples=2371, classes=[(1, 0.9810206663854913), (2, 0.018135807676086038), (0, 0.0008435259384226065)]
# Creating Left Child Node With 6354 Examples, and Right Node with 1375 Examples
# Creating Left Child Node With 5767 Examples, and Right Node with 587 Examples
# Creating Child Node With ClassLabel=0, nexamples=5767, classes=[(0, 0.6511184324605515), (2, 0.31125368475810644), (1, 0.03762788278134212)]
# Creating Child Node With ClassLabel=1, nexamples=587, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1375, classes=[(1, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 6565 Examples, and Right Node with 7835 Examples
# Creating Left Child Node With 5595 Examples, and Right Node with 970 Examples
# Creating Left Child Node With 2173 Examples, and Right Node with 3422 Examples
# Creating Left Child Node With 1333 Examples, and Right Node with 840 Examples
# Creating Child Node With ClassLabel=0, nexamples=1333, classes=[(0, 0.7591897974493623), (2, 0.24081020255063765)]
# Creating Child Node With ClassLabel=0, nexamples=840, classes=[(0, 0.9880952380952381), (2, 0.011904761904761904)]
# Creating Left Child Node With 3422 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=3422, classes=[(2, 0.8483343074225599), (1, 0.08766803039158387), (0, 0.06399766218585623)]
# Creating Left Child Node With 781 Examples, and Right Node with 189 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 781 Examples
# Creating Child Node With ClassLabel=0, nexamples=781, classes=[(0, 0.998719590268886), (1, 0.0012804097311139564)]
# Creating Child Node With ClassLabel=1, nexamples=189, classes=[(1, 1.0)]
# Creating Left Child Node With 1206 Examples, and Right Node with 6629 Examples
# Creating Child Node With ClassLabel=2, nexamples=1206, classes=[(2, 1.0)]
# Creating Left Child Node With 5384 Examples, and Right Node with 1245 Examples
# Creating Left Child Node With 3984 Examples, and Right Node with 1400 Examples
# Creating Child Node With ClassLabel=0, nexamples=3984, classes=[(0, 0.4711345381526104), (1, 0.44252008032128515), (2, 0.08634538152610442)]
# Creating Child Node With ClassLabel=1, nexamples=1400, classes=[(1, 0.9685714285714285), (2, 0.03142857142857143)]
# Creating Left Child Node With 618 Examples, and Right Node with 627 Examples
# Creating Child Node With ClassLabel=1, nexamples=618, classes=[(1, 0.8317152103559871), (0, 0.16828478964401294)]
# Creating Child Node With ClassLabel=1, nexamples=627, classes=[(1, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 6575 Examples, and Right Node with 7825 Examples
# Creating Left Child Node With 5604 Examples, and Right Node with 971 Examples
# Creating Left Child Node With 1233 Examples, and Right Node with 4371 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1233 Examples
# Creating Child Node With ClassLabel=2, nexamples=1233, classes=[(2, 0.6593673965936739), (0, 0.340632603406326)]
# Creating Left Child Node With 1855 Examples, and Right Node with 2516 Examples
# Creating Child Node With ClassLabel=2, nexamples=1855, classes=[(2, 0.5126684636118598), (0, 0.3110512129380054), (1, 0.17628032345013478)]
# Creating Child Node With ClassLabel=2, nexamples=2516, classes=[(2, 0.5806836248012719), (0, 0.41931637519872816)]
# Creating Left Child Node With 780 Examples, and Right Node with 191 Examples
# Creating Left Child Node With 85 Examples, and Right Node with 695 Examples
# Creating Child Node With ClassLabel=0, nexamples=85, classes=[(0, 0.9882352941176471), (1, 0.011764705882352941)]
# Creating Child Node With ClassLabel=0, nexamples=695, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=191, classes=[(1, 1.0)]
# Creating Left Child Node With 1213 Examples, and Right Node with 6612 Examples
# Creating Child Node With ClassLabel=2, nexamples=1213, classes=[(2, 1.0)]
# Creating Left Child Node With 2377 Examples, and Right Node with 4235 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 2377 Examples
# Creating Child Node With ClassLabel=1, nexamples=2377, classes=[(1, 0.9810685738325621), (2, 0.01851072780816155), (0, 0.00042069835927639884)]
# Creating Left Child Node With 2990 Examples, and Right Node with 1245 Examples
# Creating Child Node With ClassLabel=0, nexamples=2990, classes=[(0, 0.6130434782608696), (1, 0.2688963210702341), (2, 0.11806020066889632)]
# Creating Child Node With ClassLabel=1, nexamples=1245, classes=[(1, 0.9100401606425703), (0, 0.08995983935742972)]
#
# Creating tree # 4
# Creating Left Child Node With 6580 Examples, and Right Node with 7820 Examples
# Creating Left Child Node With 5601 Examples, and Right Node with 979 Examples
# Creating Left Child Node With 2167 Examples, and Right Node with 3434 Examples
# Creating Left Child Node With 257 Examples, and Right Node with 1910 Examples
# Creating Child Node With ClassLabel=0, nexamples=257, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1910, classes=[(0, 0.8172774869109948), (2, 0.18272251308900522)]
# Creating Left Child Node With 801 Examples, and Right Node with 2633 Examples
# Creating Child Node With ClassLabel=2, nexamples=801, classes=[(2, 0.9862671660424469), (0, 0.01373283395755306)]
# Creating Child Node With ClassLabel=2, nexamples=2633, classes=[(2, 0.8104823395366502), (1, 0.1135586783137106), (0, 0.0759589821496392)]
# Creating Left Child Node With 90 Examples, and Right Node with 889 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 90 Examples
# Creating Child Node With ClassLabel=0, nexamples=90, classes=[(0, 0.9111111111111111), (1, 0.08888888888888889)]
# Creating Left Child Node With 700 Examples, and Right Node with 189 Examples
# Creating Child Node With ClassLabel=0, nexamples=700, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=189, classes=[(1, 1.0)]
# Creating Left Child Node With 3581 Examples, and Right Node with 4239 Examples
# Creating Left Child Node With 3448 Examples, and Right Node with 133 Examples
# Creating Left Child Node With 1157 Examples, and Right Node with 2291 Examples
# Creating Child Node With ClassLabel=2, nexamples=1157, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=2291, classes=[(1, 0.9991270187690965), (0, 0.0008729812309035355)]
# Creating Child Node With ClassLabel=2, nexamples=133, classes=[(2, 1.0)]
# Creating Left Child Node With 2901 Examples, and Right Node with 1338 Examples
# Creating Left Child Node With 2901 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=2901, classes=[(0, 0.6687349189934505), (1, 0.20889348500517063), (2, 0.12237159600137884)]
# Creating Child Node With ClassLabel=1, nexamples=1338, classes=[(1, 1.0)]
#
# Creating tree # 5
# Creating Left Child Node With 6579 Examples, and Right Node with 7821 Examples
# Creating Left Child Node With 2243 Examples, and Right Node with 4336 Examples
# Creating Left Child Node With 276 Examples, and Right Node with 1967 Examples
# Creating Child Node With ClassLabel=0, nexamples=276, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1967 Examples
# Creating Child Node With ClassLabel=0, nexamples=1967, classes=[(0, 0.8251143873919674), (2, 0.17183528215556684), (1, 0.003050330452465684)]
# Creating Left Child Node With 0 Examples, and Right Node with 4336 Examples
# Creating Left Child Node With 3451 Examples, and Right Node with 885 Examples
# Creating Child Node With ClassLabel=2, nexamples=3451, classes=[(2, 0.8426543031005506), (1, 0.08953926398145465), (0, 0.06780643291799478)]
# Creating Child Node With ClassLabel=0, nexamples=885, classes=[(0, 0.7954802259887006), (1, 0.20451977401129945)]
# Creating Left Child Node With 1196 Examples, and Right Node with 6625 Examples
# Creating Child Node With ClassLabel=2, nexamples=1196, classes=[(2, 1.0)]
# Creating Left Child Node With 4624 Examples, and Right Node with 2001 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 4624 Examples
# Creating Child Node With ClassLabel=1, nexamples=4624, classes=[(1, 0.4961072664359862), (0, 0.4264705882352941), (2, 0.07742214532871973)]
# Creating Left Child Node With 1967 Examples, and Right Node with 34 Examples
# Creating Child Node With ClassLabel=1, nexamples=1967, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=34, classes=[(2, 1.0)]
#
# Creating tree # 6
# Creating Left Child Node With 6511 Examples, and Right Node with 7889 Examples
# Creating Left Child Node With 5541 Examples, and Right Node with 970 Examples
# Creating Left Child Node With 3085 Examples, and Right Node with 2456 Examples
# Creating Left Child Node With 1239 Examples, and Right Node with 1846 Examples
# Creating Child Node With ClassLabel=2, nexamples=1239, classes=[(2, 0.6585956416464891), (0, 0.3414043583535109)]
# Creating Child Node With ClassLabel=2, nexamples=1846, classes=[(2, 0.5270855904658721), (0, 0.3001083423618635), (1, 0.17280606717226435)]
# Creating Left Child Node With 823 Examples, and Right Node with 1633 Examples
# Creating Child Node With ClassLabel=0, nexamples=823, classes=[(0, 0.9902794653705954), (2, 0.009720534629404616)]
# Creating Child Node With ClassLabel=2, nexamples=1633, classes=[(2, 0.8799755052051439), (0, 0.1200244947948561)]
# Creating Left Child Node With 96 Examples, and Right Node with 874 Examples
# Creating Left Child Node With 90 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=0, nexamples=90, classes=[(0, 0.9888888888888889), (1, 0.011111111111111112)]
# Creating Child Node With ClassLabel=1, nexamples=6, classes=[(1, 1.0)]
# Creating Left Child Node With 682 Examples, and Right Node with 192 Examples
# Creating Child Node With ClassLabel=0, nexamples=682, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=192, classes=[(1, 1.0)]
# Creating Left Child Node With 5267 Examples, and Right Node with 2622 Examples
# Creating Left Child Node With 2305 Examples, and Right Node with 2962 Examples
# Creating Left Child Node With 584 Examples, and Right Node with 1721 Examples
# Creating Child Node With ClassLabel=2, nexamples=584, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1721, classes=[(1, 0.9982568274259151), (0, 0.0017431725740848344)]
# Creating Left Child Node With 2962 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=2962, classes=[(0, 0.6826468602295747), (1, 0.2035786630654963), (2, 0.1137744767049291)]
# Creating Left Child Node With 2489 Examples, and Right Node with 133 Examples
# Creating Left Child Node With 2489 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=2489, classes=[(1, 0.7902772197669747), (2, 0.20972278023302532)]
# Creating Child Node With ClassLabel=2, nexamples=133, classes=[(2, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 2283 Examples, and Right Node with 12117 Examples
# Creating Left Child Node With 276 Examples, and Right Node with 2007 Examples
# Creating Child Node With ClassLabel=0, nexamples=276, classes=[(0, 1.0)]
# Creating Left Child Node With 1103 Examples, and Right Node with 904 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1103 Examples
# Creating Child Node With ClassLabel=0, nexamples=1103, classes=[(0, 0.6844968268359021), (2, 0.3155031731640979)]
# Creating Left Child Node With 898 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=0, nexamples=898, classes=[(0, 0.9866369710467706), (2, 0.013363028953229399)]
# Creating Child Node With ClassLabel=1, nexamples=6, classes=[(1, 1.0)]
# Creating Left Child Node With 4278 Examples, and Right Node with 7839 Examples
# Creating Left Child Node With 3416 Examples, and Right Node with 862 Examples
# Creating Left Child Node With 1792 Examples, and Right Node with 1624 Examples
# Creating Child Node With ClassLabel=2, nexamples=1792, classes=[(2, 0.8197544642857143), (1, 0.17410714285714285), (0, 0.006138392857142857)]
# Creating Child Node With ClassLabel=2, nexamples=1624, classes=[(2, 0.8663793103448276), (0, 0.1336206896551724)]
# Creating Left Child Node With 674 Examples, and Right Node with 188 Examples
# Creating Child Node With ClassLabel=0, nexamples=674, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=188, classes=[(1, 1.0)]
# Creating Left Child Node With 7693 Examples, and Right Node with 146 Examples
# Creating Left Child Node With 1160 Examples, and Right Node with 6533 Examples
# Creating Child Node With ClassLabel=2, nexamples=1160, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=6533, classes=[(1, 0.6484004285932956), (0, 0.2983315475279351), (2, 0.053268023878769326)]
# Creating Child Node With ClassLabel=2, nexamples=146, classes=[(2, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 12179 Examples, and Right Node with 2221 Examples
# Creating Left Child Node With 2134 Examples, and Right Node with 10045 Examples
# Creating Left Child Node With 1304 Examples, and Right Node with 830 Examples
# Creating Left Child Node With 433 Examples, and Right Node with 871 Examples
# Creating Child Node With ClassLabel=0, nexamples=433, classes=[(0, 0.9607390300230947), (2, 0.03926096997690531)]
# Creating Child Node With ClassLabel=0, nexamples=871, classes=[(0, 0.6440872560275546), (2, 0.3559127439724455)]
# Creating Left Child Node With 30 Examples, and Right Node with 800 Examples
# Creating Child Node With ClassLabel=0, nexamples=30, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=800, classes=[(0, 0.99125), (2, 0.00875)]
# Creating Left Child Node With 3415 Examples, and Right Node with 6630 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3415 Examples
# Creating Child Node With ClassLabel=2, nexamples=3415, classes=[(2, 0.84099560761347), (1, 0.09428989751098096), (0, 0.06471449487554905)]
# Creating Left Child Node With 1217 Examples, and Right Node with 5413 Examples
# Creating Child Node With ClassLabel=2, nexamples=1217, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5413, classes=[(1, 0.5806392019213006), (0, 0.3428782560502494), (2, 0.07648254202845003)]
# Creating Left Child Node With 95 Examples, and Right Node with 2126 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 95 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 95 Examples
# Creating Child Node With ClassLabel=0, nexamples=95, classes=[(0, 0.9368421052631579), (1, 0.06315789473684211)]
# Creating Left Child Node With 900 Examples, and Right Node with 1226 Examples
# Creating Left Child Node With 724 Examples, and Right Node with 176 Examples
# Creating Child Node With ClassLabel=0, nexamples=724, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=176, classes=[(1, 1.0)]
# Creating Left Child Node With 813 Examples, and Right Node with 413 Examples
# Creating Child Node With ClassLabel=1, nexamples=813, classes=[(1, 0.8622386223862238), (0, 0.13776137761377613)]
# Creating Child Node With ClassLabel=1, nexamples=413, classes=[(1, 1.0)]
#
# Creating tree # 9
# Creating Left Child Node With 2428 Examples, and Right Node with 11972 Examples
# Creating Left Child Node With 430 Examples, and Right Node with 1998 Examples
# Creating Left Child Node With 9 Examples, and Right Node with 421 Examples
# Creating Child Node With ClassLabel=0, nexamples=9, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 421 Examples
# Creating Child Node With ClassLabel=0, nexamples=421, classes=[(0, 0.9643705463182898), (2, 0.035629453681710214)]
# Creating Left Child Node With 0 Examples, and Right Node with 1998 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1998 Examples
# Creating Child Node With ClassLabel=2, nexamples=1998, classes=[(2, 0.9954954954954955), (0, 0.0045045045045045045)]
# Creating Left Child Node With 4238 Examples, and Right Node with 7734 Examples
# Creating Left Child Node With 225 Examples, and Right Node with 4013 Examples
# Creating Child Node With ClassLabel=0, nexamples=225, classes=[(0, 1.0)]
# Creating Left Child Node With 689 Examples, and Right Node with 3324 Examples
# Creating Child Node With ClassLabel=0, nexamples=689, classes=[(0, 0.5108853410740203), (2, 0.48911465892597966)]
# Creating Child Node With ClassLabel=1, nexamples=3324, classes=[(1, 0.7891095066185319), (2, 0.21058965102286403), (0, 0.00030084235860409147)]
# Creating Left Child Node With 5489 Examples, and Right Node with 2245 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 5489 Examples
# Creating Child Node With ClassLabel=0, nexamples=5489, classes=[(0, 0.5296046638732009), (2, 0.32665330661322645), (1, 0.1437420295135726)]
# Creating Left Child Node With 971 Examples, and Right Node with 1274 Examples
# Creating Child Node With ClassLabel=0, nexamples=971, classes=[(0, 0.7899073120494335), (1, 0.21009268795056643)]
# Creating Child Node With ClassLabel=1, nexamples=1274, classes=[(1, 0.9215070643642073), (0, 0.07849293563579278)]
#
# Creating tree # 10
# Creating Left Child Node With 2429 Examples, and Right Node with 11971 Examples
# Creating Left Child Node With 424 Examples, and Right Node with 2005 Examples
# Creating Left Child Node With 27 Examples, and Right Node with 397 Examples
# Creating Child Node With ClassLabel=0, nexamples=27, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 397 Examples
# Creating Child Node With ClassLabel=0, nexamples=397, classes=[(0, 0.9622166246851386), (2, 0.037783375314861464)]
# Creating Left Child Node With 822 Examples, and Right Node with 1183 Examples
# Creating Left Child Node With 14 Examples, and Right Node with 808 Examples
# Creating Child Node With ClassLabel=0, nexamples=14, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=808, classes=[(2, 0.9987623762376238), (0, 0.0012376237623762376)]
# Creating Child Node With ClassLabel=2, nexamples=1183, classes=[(2, 1.0)]
# Creating Left Child Node With 5346 Examples, and Right Node with 6625 Examples
# Creating Left Child Node With 5146 Examples, and Right Node with 200 Examples
# Creating Left Child Node With 4363 Examples, and Right Node with 783 Examples
# Creating Child Node With ClassLabel=2, nexamples=4363, classes=[(2, 0.5574146229658492), (0, 0.36901214760485906), (1, 0.07357322942929177)]
# Creating Child Node With ClassLabel=0, nexamples=783, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=200, classes=[(1, 1.0)]
# Creating Left Child Node With 4607 Examples, and Right Node with 2018 Examples
# Creating Left Child Node With 1711 Examples, and Right Node with 2896 Examples
# Creating Child Node With ClassLabel=1, nexamples=1711, classes=[(1, 0.9994155464640561), (0, 0.0005844535359438924)]
# Creating Child Node With ClassLabel=0, nexamples=2896, classes=[(0, 0.6667817679558011), (1, 0.21892265193370167), (2, 0.11429558011049724)]
# Creating Left Child Node With 0 Examples, and Right Node with 2018 Examples
# Creating Child Node With ClassLabel=1, nexamples=2018, classes=[(1, 0.9752229930624381), (2, 0.024777006937561942)]
#
# Creating tree # 11
# Creating Left Child Node With 2448 Examples, and Right Node with 11952 Examples
# Creating Left Child Node With 1259 Examples, and Right Node with 1189 Examples
# Creating Left Child Node With 26 Examples, and Right Node with 1233 Examples
# Creating Child Node With ClassLabel=0, nexamples=26, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1233 Examples
# Creating Child Node With ClassLabel=2, nexamples=1233, classes=[(2, 0.6715328467153284), (0, 0.3284671532846715)]
# Creating Child Node With ClassLabel=2, nexamples=1189, classes=[(2, 1.0)]
# Creating Left Child Node With 5348 Examples, and Right Node with 6604 Examples
# Creating Left Child Node With 4362 Examples, and Right Node with 986 Examples
# Creating Left Child Node With 1744 Examples, and Right Node with 2618 Examples
# Creating Child Node With ClassLabel=0, nexamples=1744, classes=[(0, 0.8056192660550459), (2, 0.19438073394495411)]
# Creating Child Node With ClassLabel=2, nexamples=2618, classes=[(2, 0.7948815889992361), (1, 0.12337662337662338), (0, 0.08174178762414057)]
# Creating Left Child Node With 769 Examples, and Right Node with 217 Examples
# Creating Child Node With ClassLabel=0, nexamples=769, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=217, classes=[(1, 1.0)]
# Creating Left Child Node With 4577 Examples, and Right Node with 2027 Examples
# Creating Left Child Node With 4577 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=4577, classes=[(1, 0.49901682324666813), (0, 0.4271356783919598), (2, 0.07384749836137208)]
# Creating Left Child Node With 647 Examples, and Right Node with 1380 Examples
# Creating Child Node With ClassLabel=1, nexamples=647, classes=[(1, 0.9428129829984544), (2, 0.0571870170015456)]
# Creating Child Node With ClassLabel=1, nexamples=1380, classes=[(1, 1.0)]
#
# Creating tree # 12
# Creating Left Child Node With 6559 Examples, and Right Node with 7841 Examples
# Creating Left Child Node With 5585 Examples, and Right Node with 974 Examples
# Creating Left Child Node With 3117 Examples, and Right Node with 2468 Examples
# Creating Left Child Node With 1273 Examples, and Right Node with 1844 Examples
# Creating Child Node With ClassLabel=2, nexamples=1273, classes=[(2, 0.6669285153181461), (0, 0.3330714846818539)]
# Creating Child Node With ClassLabel=2, nexamples=1844, classes=[(2, 0.5211496746203904), (0, 0.30748373101952275), (1, 0.17136659436008678)]
# Creating Left Child Node With 2468 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=2468, classes=[(2, 0.5826580226904376), (0, 0.4173419773095624)]
# Creating Left Child Node With 90 Examples, and Right Node with 884 Examples
# Creating Left Child Node With 90 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=90, classes=[(0, 0.9333333333333333), (1, 0.06666666666666667)]
# Creating Left Child Node With 0 Examples, and Right Node with 884 Examples
# Creating Child Node With ClassLabel=0, nexamples=884, classes=[(0, 0.7929864253393665), (1, 0.20701357466063347)]
# Creating Left Child Node With 1247 Examples, and Right Node with 6594 Examples
# Creating Child Node With ClassLabel=2, nexamples=1247, classes=[(2, 1.0)]
# Creating Left Child Node With 2356 Examples, and Right Node with 4238 Examples
# Creating Left Child Node With 2312 Examples, and Right Node with 44 Examples
# Creating Child Node With ClassLabel=1, nexamples=2312, classes=[(1, 0.9995674740484429), (0, 0.00043252595155709344)]
# Creating Child Node With ClassLabel=2, nexamples=44, classes=[(2, 1.0)]
# Creating Left Child Node With 2915 Examples, and Right Node with 1323 Examples
# Creating Child Node With ClassLabel=0, nexamples=2915, classes=[(0, 0.6614065180102916), (1, 0.220926243567753), (2, 0.11766723842195541)]
# Creating Child Node With ClassLabel=1, nexamples=1323, classes=[(1, 1.0)]
#
# Creating tree # 13
# Creating Left Child Node With 6706 Examples, and Right Node with 7694 Examples
# Creating Left Child Node With 2384 Examples, and Right Node with 4322 Examples
# Creating Left Child Node With 432 Examples, and Right Node with 1952 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 432 Examples
# Creating Child Node With ClassLabel=0, nexamples=432, classes=[(0, 0.9699074074074074), (2, 0.03009259259259259)]
# Creating Left Child Node With 0 Examples, and Right Node with 1952 Examples
# Creating Child Node With ClassLabel=2, nexamples=1952, classes=[(2, 0.9943647540983607), (0, 0.0056352459016393444)]
# Creating Left Child Node With 1905 Examples, and Right Node with 2417 Examples
# Creating Left Child Node With 895 Examples, and Right Node with 1010 Examples
# Creating Child Node With ClassLabel=0, nexamples=895, classes=[(0, 0.6402234636871509), (2, 0.35977653631284917)]
# Creating Child Node With ClassLabel=2, nexamples=1010, classes=[(2, 0.6643564356435644), (1, 0.33564356435643566)]
# Creating Left Child Node With 0 Examples, and Right Node with 2417 Examples
# Creating Child Node With ClassLabel=1, nexamples=2417, classes=[(1, 0.9772445179975175), (2, 0.021928009929664875), (0, 0.0008274720728175424)]
# Creating Left Child Node With 5483 Examples, and Right Node with 2211 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 5483 Examples
# Creating Left Child Node With 2443 Examples, and Right Node with 3040 Examples
# Creating Child Node With ClassLabel=2, nexamples=2443, classes=[(2, 0.5747032337290217), (0, 0.4252967662709783)]
# Creating Child Node With ClassLabel=0, nexamples=3040, classes=[(0, 0.6233552631578947), (1, 0.26282894736842105), (2, 0.11381578947368422)]
# Creating Left Child Node With 1555 Examples, and Right Node with 656 Examples
# Creating Left Child Node With 980 Examples, and Right Node with 575 Examples
# Creating Child Node With ClassLabel=0, nexamples=980, classes=[(0, 0.886734693877551), (1, 0.11326530612244898)]
# Creating Child Node With ClassLabel=1, nexamples=575, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=656, classes=[(1, 1.0)]
#
# Creating tree # 14
# Creating Left Child Node With 2489 Examples, and Right Node with 11911 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 2489 Examples
# Creating Left Child Node With 1264 Examples, and Right Node with 1225 Examples
# Creating Left Child Node With 18 Examples, and Right Node with 1246 Examples
# Creating Child Node With ClassLabel=0, nexamples=18, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1246, classes=[(2, 0.6685393258426966), (0, 0.33146067415730335)]
# Creating Child Node With ClassLabel=2, nexamples=1225, classes=[(2, 1.0)]
# Creating Left Child Node With 5347 Examples, and Right Node with 6564 Examples
# Creating Left Child Node With 4403 Examples, and Right Node with 944 Examples
# Creating Left Child Node With 1932 Examples, and Right Node with 2471 Examples
# Creating Child Node With ClassLabel=2, nexamples=1932, classes=[(2, 0.5419254658385093), (0, 0.3007246376811594), (1, 0.15734989648033126)]
# Creating Child Node With ClassLabel=2, nexamples=2471, classes=[(2, 0.5787130716309187), (0, 0.4212869283690813)]
# Creating Left Child Node With 767 Examples, and Right Node with 177 Examples
# Creating Child Node With ClassLabel=0, nexamples=767, classes=[(0, 0.9986962190352021), (1, 0.001303780964797914)]
# Creating Child Node With ClassLabel=1, nexamples=177, classes=[(1, 1.0)]
# Creating Left Child Node With 4554 Examples, and Right Node with 2010 Examples
# Creating Left Child Node With 4152 Examples, and Right Node with 402 Examples
# Creating Child Node With ClassLabel=0, nexamples=4152, classes=[(0, 0.4576107899807322), (1, 0.45375722543352603), (2, 0.08863198458574181)]
# Creating Child Node With ClassLabel=1, nexamples=402, classes=[(1, 1.0)]
# Creating Left Child Node With 1963 Examples, and Right Node with 47 Examples
# Creating Child Node With ClassLabel=1, nexamples=1963, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=47, classes=[(2, 1.0)]
#
# Creating tree # 15
# Creating Left Child Node With 6588 Examples, and Right Node with 7812 Examples
# Creating Left Child Node With 2250 Examples, and Right Node with 4338 Examples
# Creating Left Child Node With 2244 Examples, and Right Node with 6 Examples
# Creating Left Child Node With 289 Examples, and Right Node with 1955 Examples
# Creating Child Node With ClassLabel=0, nexamples=289, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1955, classes=[(0, 0.8342710997442455), (2, 0.16572890025575449)]
# Creating Child Node With ClassLabel=1, nexamples=6, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 4338 Examples
# Creating Left Child Node With 4338 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=4338, classes=[(2, 0.6742738589211619), (0, 0.20977408944213924), (1, 0.11595205163669894)]
# Creating Left Child Node With 1188 Examples, and Right Node with 6624 Examples
# Creating Child Node With ClassLabel=2, nexamples=1188, classes=[(2, 1.0)]
# Creating Left Child Node With 2345 Examples, and Right Node with 4279 Examples
# Creating Left Child Node With 2299 Examples, and Right Node with 46 Examples
# Creating Child Node With ClassLabel=1, nexamples=2299, classes=[(1, 0.9991300565463245), (0, 0.0008699434536755111)]
# Creating Child Node With ClassLabel=2, nexamples=46, classes=[(2, 1.0)]
# Creating Left Child Node With 3010 Examples, and Right Node with 1269 Examples
# Creating Child Node With ClassLabel=0, nexamples=3010, classes=[(0, 0.6109634551495017), (1, 0.27674418604651163), (2, 0.1122923588039867)]
# Creating Child Node With ClassLabel=1, nexamples=1269, classes=[(1, 0.9141055949566588), (0, 0.08589440504334121)]
#
# Creating tree # 16
# Creating Left Child Node With 12165 Examples, and Right Node with 2235 Examples
# Creating Left Child Node With 6651 Examples, and Right Node with 5514 Examples
# Creating Left Child Node With 2458 Examples, and Right Node with 4193 Examples
# Creating Left Child Node With 1268 Examples, and Right Node with 1190 Examples
# Creating Child Node With ClassLabel=2, nexamples=1268, classes=[(2, 0.6553627760252366), (0, 0.34463722397476343)]
# Creating Child Node With ClassLabel=2, nexamples=1190, classes=[(2, 1.0)]
# Creating Left Child Node With 867 Examples, and Right Node with 3326 Examples
# Creating Child Node With ClassLabel=0, nexamples=867, classes=[(0, 0.6401384083044983), (2, 0.35986159169550175)]
# Creating Child Node With ClassLabel=1, nexamples=3326, classes=[(1, 0.7877330126277812), (2, 0.211665664461816), (0, 0.0006013229104028864)]
# Creating Left Child Node With 2442 Examples, and Right Node with 3072 Examples
# Creating Left Child Node With 821 Examples, and Right Node with 1621 Examples
# Creating Child Node With ClassLabel=0, nexamples=821, classes=[(0, 0.9878197320341048), (2, 0.012180267965895249)]
# Creating Child Node With ClassLabel=2, nexamples=1621, classes=[(2, 0.8704503392967304), (0, 0.1295496607032696)]
# Creating Left Child Node With 3072 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=3072, classes=[(0, 0.6100260416666666), (1, 0.2760416666666667), (2, 0.11393229166666667)]
# Creating Left Child Node With 1622 Examples, and Right Node with 613 Examples
# Creating Left Child Node With 1622 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 784 Examples, and Right Node with 838 Examples
# Creating Child Node With ClassLabel=0, nexamples=784, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=838, classes=[(1, 0.8735083532219571), (0, 0.12649164677804295)]
# Creating Child Node With ClassLabel=1, nexamples=613, classes=[(1, 1.0)]
