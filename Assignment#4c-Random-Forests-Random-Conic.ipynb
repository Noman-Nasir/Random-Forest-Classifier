# %% [markdown]
# # Assignment No 4d
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests. For this part you will be implemented randomized version of Conic weak learner based Random Forest.
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# !pip install nose
# %load_ext autoreload
# %autoreload 2
# Out:
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 2.8MB/s
# Installing collected packages: nose
# Successfully installed nose-1.3.7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/'Colab Notebooks'/'Assignment 4'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/Assignment 4

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples//4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples//4,1)),2*np.ones((nexamples//4,1)),3*np.ones((nexamples//4,1)),4*np.ones((nexamples//4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples//4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples//4,1)),2*np.ones((ntexamples//4,1)),3*np.ones((ntexamples//4,1)),4*np.ones((ntexamples//4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Conic')

# %%
print (X.shape, Y.shape)
# Out:
# (2000, 2) (2000, 1)

# %%
# %pdb
rfc.train(X,Y)
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 1250 Examples, and Right Node with 750 Examples
# Creating Left Child Node With 777 Examples, and Right Node with 473 Examples
# Creating Left Child Node With 520 Examples, and Right Node with 257 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 512 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=8, classes=[(4.0, 0.625), (1.0, 0.25), (2.0, 0.125)]
# Creating Child Node With ClassLabel=2.0, nexamples=512, classes=[(2.0, 0.970703125), (3.0, 0.025390625), (1.0, 0.00390625)]
# Creating Left Child Node With 249 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=249, classes=[(1.0, 0.9759036144578314), (3.0, 0.024096385542168676)]
# Creating Child Node With ClassLabel=3.0, nexamples=8, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=473, classes=[(3.0, 1.0)]
# Creating Left Child Node With 468 Examples, and Right Node with 282 Examples
# Creating Left Child Node With 458 Examples, and Right Node with 10 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=458, classes=[(4.0, 1.0)]
# Creating Left Child Node With 10 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=10, classes=[(4.0, 0.9), (2.0, 0.1)]
# Creating Left Child Node With 254 Examples, and Right Node with 28 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 247 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=7, classes=[(4.0, 0.7142857142857143), (1.0, 0.14285714285714285), (2.0, 0.14285714285714285)]
# Creating Child Node With ClassLabel=1.0, nexamples=247, classes=[(1.0, 0.9959514170040485), (4.0, 0.004048582995951417)]
# Creating Left Child Node With 24 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=24, classes=[(4.0, 0.9166666666666666), (1.0, 0.08333333333333333)]
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 485 Examples, and Right Node with 1515 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 485 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 472 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 12 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=12, classes=[(3.0, 0.9166666666666666), (1.0, 0.08333333333333333)]
# Creating Child Node With ClassLabel=3.0, nexamples=472, classes=[(3.0, 1.0)]
# Creating Left Child Node With 556 Examples, and Right Node with 959 Examples
# Creating Left Child Node With 514 Examples, and Right Node with 42 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 506 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=8, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=506, classes=[(2.0, 0.9861660079051383), (4.0, 0.011857707509881422), (3.0, 0.001976284584980237)]
# Creating Left Child Node With 21 Examples, and Right Node with 21 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=21, classes=[(1.0, 0.9047619047619048), (2.0, 0.047619047619047616), (4.0, 0.047619047619047616)]
# Creating Child Node With ClassLabel=4.0, nexamples=21, classes=[(4.0, 0.9523809523809523), (1.0, 0.047619047619047616)]
# Creating Left Child Node With 460 Examples, and Right Node with 499 Examples
# Creating Left Child Node With 460 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=460, classes=[(1.0, 0.9847826086956522), (3.0, 0.015217391304347827)]
# Creating Left Child Node With 36 Examples, and Right Node with 463 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=36, classes=[(1.0, 0.6388888888888888), (4.0, 0.3611111111111111)]
# Creating Child Node With ClassLabel=4.0, nexamples=463, classes=[(4.0, 0.9935205183585313), (1.0, 0.0064794816414686825)]
#
# Creating tree # 3
# Creating Left Child Node With 587 Examples, and Right Node with 1413 Examples
# Creating Left Child Node With 84 Examples, and Right Node with 503 Examples
# Creating Left Child Node With 61 Examples, and Right Node with 23 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 60 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=60, classes=[(2.0, 0.9833333333333333), (4.0, 0.016666666666666666)]
# Creating Left Child Node With 23 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=23, classes=[(1.0, 0.9130434782608695), (4.0, 0.08695652173913043)]
# Creating Left Child Node With 497 Examples, and Right Node with 6 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 476 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=21, classes=[(4.0, 0.9523809523809523), (2.0, 0.047619047619047616)]
# Creating Child Node With ClassLabel=4.0, nexamples=476, classes=[(4.0, 0.9957983193277311), (1.0, 0.004201680672268907)]
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(2.0, 0.6666666666666666), (4.0, 0.3333333333333333)]
# Creating Left Child Node With 917 Examples, and Right Node with 496 Examples
# Creating Left Child Node With 439 Examples, and Right Node with 478 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 439 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=439, classes=[(2.0, 0.9931662870159453), (3.0, 0.00683371298405467)]
# Creating Left Child Node With 189 Examples, and Right Node with 289 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=189, classes=[(1.0, 0.9841269841269841), (3.0, 0.015873015873015872)]
# Creating Child Node With ClassLabel=1.0, nexamples=289, classes=[(1.0, 1.0)]
# Creating Left Child Node With 495 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 469 Examples, and Right Node with 26 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=469, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=26, classes=[(3.0, 0.9230769230769231), (1.0, 0.07692307692307693)]
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
#
# Creating tree # 4
# Creating Left Child Node With 995 Examples, and Right Node with 1005 Examples
# Creating Left Child Node With 482 Examples, and Right Node with 513 Examples
# Creating Left Child Node With 479 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=479, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=3, classes=[(2.0, 0.6666666666666666), (1.0, 0.3333333333333333)]
# Creating Left Child Node With 82 Examples, and Right Node with 431 Examples
# Creating Left Child Node With 82 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=82, classes=[(4.0, 0.8780487804878049), (1.0, 0.12195121951219512)]
# Creating Left Child Node With 430 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=430, classes=[(4.0, 0.9953488372093023), (2.0, 0.004651162790697674)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1.0)]
# Creating Left Child Node With 517 Examples, and Right Node with 488 Examples
# Creating Left Child Node With 485 Examples, and Right Node with 32 Examples
# Creating Left Child Node With 30 Examples, and Right Node with 455 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=30, classes=[(2.0, 0.5333333333333333), (3.0, 0.4666666666666667)]
# Creating Child Node With ClassLabel=3.0, nexamples=455, classes=[(3.0, 0.9978021978021978), (1.0, 0.002197802197802198)]
# Creating Child Node With ClassLabel=1.0, nexamples=32, classes=[(1.0, 1.0)]
# Creating Left Child Node With 452 Examples, and Right Node with 36 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 449 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 0.6666666666666666), (1.0, 0.3333333333333333)]
# Creating Child Node With ClassLabel=1.0, nexamples=449, classes=[(1.0, 1.0)]
# Creating Left Child Node With 26 Examples, and Right Node with 10 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=26, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=10, classes=[(1.0, 0.6), (3.0, 0.4)]
#
# Creating tree # 5
# Creating Left Child Node With 988 Examples, and Right Node with 1012 Examples
# Creating Left Child Node With 546 Examples, and Right Node with 442 Examples
# Creating Left Child Node With 161 Examples, and Right Node with 385 Examples
# Creating Left Child Node With 104 Examples, and Right Node with 57 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=104, classes=[(3.0, 0.9711538461538461), (2.0, 0.028846153846153848)]
# Creating Child Node With ClassLabel=2.0, nexamples=57, classes=[(2.0, 0.8070175438596491), (4.0, 0.14035087719298245), (3.0, 0.05263157894736842)]
# Creating Left Child Node With 379 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=379, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=6, classes=[(1.0, 1.0)]
# Creating Left Child Node With 426 Examples, and Right Node with 16 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=426, classes=[(2.0, 1.0)]
# Creating Left Child Node With 12 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=12, classes=[(2.0, 0.5833333333333334), (1.0, 0.4166666666666667)]
# Creating Child Node With ClassLabel=4.0, nexamples=4, classes=[(4.0, 1.0)]
# Creating Left Child Node With 483 Examples, and Right Node with 529 Examples
# Creating Left Child Node With 481 Examples, and Right Node with 2 Examples
# Creating Left Child Node With 443 Examples, and Right Node with 38 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=443, classes=[(1.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=38, classes=[(1.0, 0.9473684210526315), (4.0, 0.05263157894736842)]
# Creating Child Node With ClassLabel=1.0, nexamples=2, classes=[(1.0, 0.5), (3.0, 0.5)]
# Creating Left Child Node With 507 Examples, and Right Node with 22 Examples
# Creating Left Child Node With 17 Examples, and Right Node with 490 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=17, classes=[(2.0, 0.9411764705882353), (4.0, 0.058823529411764705)]
# Creating Child Node With ClassLabel=4.0, nexamples=490, classes=[(4.0, 0.9897959183673469), (1.0, 0.006122448979591836), (2.0, 0.004081632653061225)]
# Creating Left Child Node With 1 Examples, and Right Node with 21 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=21, classes=[(3.0, 0.7142857142857143), (1.0, 0.2857142857142857)]
#
# Creating tree # 6
# Creating Left Child Node With 1042 Examples, and Right Node with 958 Examples
# Creating Left Child Node With 481 Examples, and Right Node with 561 Examples
# Creating Left Child Node With 51 Examples, and Right Node with 430 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 45 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=6, classes=[(3.0, 0.8333333333333334), (2.0, 0.16666666666666666)]
# Creating Child Node With ClassLabel=2.0, nexamples=45, classes=[(2.0, 0.9111111111111111), (3.0, 0.08888888888888889)]
# Creating Child Node With ClassLabel=2.0, nexamples=430, classes=[(2.0, 1.0)]
# Creating Left Child Node With 366 Examples, and Right Node with 195 Examples
# Creating Left Child Node With 16 Examples, and Right Node with 350 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=16, classes=[(4.0, 0.8125), (2.0, 0.1875)]
# Creating Child Node With ClassLabel=4.0, nexamples=350, classes=[(4.0, 1.0)]
# Creating Left Child Node With 170 Examples, and Right Node with 25 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=170, classes=[(4.0, 0.8058823529411765), (1.0, 0.19411764705882353)]
# Creating Child Node With ClassLabel=1.0, nexamples=25, classes=[(1.0, 1.0)]
# Creating Left Child Node With 482 Examples, and Right Node with 476 Examples
# Creating Left Child Node With 403 Examples, and Right Node with 79 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=403, classes=[(1.0, 1.0)]
# Creating Left Child Node With 42 Examples, and Right Node with 37 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=42, classes=[(3.0, 0.9523809523809523), (1.0, 0.047619047619047616)]
# Creating Child Node With ClassLabel=1.0, nexamples=37, classes=[(1.0, 1.0)]
# Creating Left Child Node With 32 Examples, and Right Node with 444 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 28 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=4, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=28, classes=[(2.0, 0.8928571428571429), (3.0, 0.10714285714285714)]
# Creating Child Node With ClassLabel=3.0, nexamples=444, classes=[(3.0, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 495 Examples, and Right Node with 1505 Examples
# Creating Left Child Node With 491 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 491 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 236 Examples, and Right Node with 255 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=236, classes=[(1.0, 0.9872881355932204), (4.0, 0.012711864406779662)]
# Creating Child Node With ClassLabel=1.0, nexamples=255, classes=[(1.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 0.75), (4.0, 0.25)]
# Creating Left Child Node With 1004 Examples, and Right Node with 501 Examples
# Creating Left Child Node With 483 Examples, and Right Node with 521 Examples
# Creating Left Child Node With 480 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=480, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=3, classes=[(1.0, 1.0)]
# Creating Left Child Node With 490 Examples, and Right Node with 31 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=490, classes=[(3.0, 0.9938775510204082), (1.0, 0.006122448979591836)]
# Creating Child Node With ClassLabel=2.0, nexamples=31, classes=[(2.0, 0.5806451612903226), (3.0, 0.41935483870967744)]
# Creating Left Child Node With 500 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 499 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=499, classes=[(4.0, 0.9919839679358717), (1.0, 0.006012024048096192), (2.0, 0.002004008016032064)]
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 1129 Examples, and Right Node with 871 Examples
# Creating Left Child Node With 664 Examples, and Right Node with 465 Examples
# Creating Left Child Node With 465 Examples, and Right Node with 199 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 462 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=3, classes=[(1.0, 0.3333333333333333), (2.0, 0.3333333333333333), (4.0, 0.3333333333333333)]
# Creating Child Node With ClassLabel=2.0, nexamples=462, classes=[(2.0, 1.0)]
# Creating Left Child Node With 131 Examples, and Right Node with 68 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=131, classes=[(4.0, 0.9465648854961832), (2.0, 0.05343511450381679)]
# Creating Child Node With ClassLabel=3.0, nexamples=68, classes=[(3.0, 0.9852941176470589), (1.0, 0.014705882352941176)]
# Creating Left Child Node With 432 Examples, and Right Node with 33 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 427 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=5, classes=[(3.0, 0.6), (1.0, 0.2), (2.0, 0.2)]
# Creating Child Node With ClassLabel=3.0, nexamples=427, classes=[(3.0, 1.0)]
# Creating Left Child Node With 3 Examples, and Right Node with 30 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=30, classes=[(2.0, 0.9666666666666667), (4.0, 0.03333333333333333)]
# Creating Left Child Node With 373 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=373, classes=[(1.0, 1.0)]
# Creating Left Child Node With 117 Examples, and Right Node with 381 Examples
# Creating Left Child Node With 117 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=117, classes=[(1.0, 0.9829059829059829), (4.0, 0.017094017094017096)]
# Creating Left Child Node With 369 Examples, and Right Node with 12 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=369, classes=[(4.0, 0.994579945799458), (1.0, 0.005420054200542005)]
# Creating Child Node With ClassLabel=1.0, nexamples=12, classes=[(1.0, 0.5833333333333334), (4.0, 0.4166666666666667)]
#
# Creating tree # 9
# Creating Left Child Node With 751 Examples, and Right Node with 1249 Examples
# Creating Left Child Node With 263 Examples, and Right Node with 488 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=263, classes=[(3.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 488 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 488 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=488, classes=[(2.0, 0.9979508196721312), (3.0, 0.0020491803278688526)]
# Creating Left Child Node With 605 Examples, and Right Node with 644 Examples
# Creating Left Child Node With 138 Examples, and Right Node with 467 Examples
# Creating Left Child Node With 97 Examples, and Right Node with 41 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=97, classes=[(1.0, 0.9278350515463918), (4.0, 0.07216494845360824)]
# Creating Child Node With ClassLabel=4.0, nexamples=41, classes=[(4.0, 0.9512195121951219), (1.0, 0.04878048780487805)]
# Creating Left Child Node With 20 Examples, and Right Node with 447 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=20, classes=[(2.0, 0.6), (4.0, 0.4)]
# Creating Child Node With ClassLabel=4.0, nexamples=447, classes=[(4.0, 0.9977628635346756), (2.0, 0.0022371364653243847)]
# Creating Left Child Node With 443 Examples, and Right Node with 201 Examples
# Creating Left Child Node With 392 Examples, and Right Node with 51 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=392, classes=[(1.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=51, classes=[(3.0, 0.6862745098039216), (1.0, 0.3137254901960784)]
# Creating Child Node With ClassLabel=3.0, nexamples=201, classes=[(3.0, 1.0)]
#
# Creating tree # 10
# Creating Left Child Node With 524 Examples, and Right Node with 1476 Examples
# Creating Left Child Node With 491 Examples, and Right Node with 33 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 489 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=2, classes=[(2.0, 0.5), (4.0, 0.5)]
# Creating Left Child Node With 0 Examples, and Right Node with 489 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=489, classes=[(2.0, 0.9979550102249489), (3.0, 0.002044989775051125)]
# Creating Left Child Node With 25 Examples, and Right Node with 8 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=23, classes=[(4.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=2, classes=[(2.0, 0.5), (4.0, 0.5)]
# Creating Child Node With ClassLabel=2.0, nexamples=8, classes=[(2.0, 1.0)]
# Creating Left Child Node With 498 Examples, and Right Node with 978 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 496 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=2, classes=[(3.0, 1.0)]
# Creating Left Child Node With 496 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=496, classes=[(3.0, 0.9959677419354839), (1.0, 0.004032258064516129)]
# Creating Left Child Node With 296 Examples, and Right Node with 682 Examples
# Creating Left Child Node With 264 Examples, and Right Node with 32 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=264, classes=[(4.0, 0.9848484848484849), (1.0, 0.007575757575757576), (2.0, 0.007575757575757576)]
# Creating Child Node With ClassLabel=4.0, nexamples=32, classes=[(4.0, 0.53125), (1.0, 0.375), (3.0, 0.09375)]
# Creating Left Child Node With 256 Examples, and Right Node with 426 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=256, classes=[(4.0, 0.7734375), (1.0, 0.2265625)]
# Creating Child Node With ClassLabel=1.0, nexamples=426, classes=[(1.0, 1.0)]

# %%
len(rfc.trees)
# Out:
# 10

# %%
# %pdb
# Training Confusion Matrix...
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        496    0    2    2   500
# 2.0          0  499    0    1   500
# 3.0          0    2  498    0   500
# 4.0          2    0    0  498   500
# All        498  501  500  501  2000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.9955

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print (Y.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (2000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        250    0    0    0   250
# 2.0          0  249    0    1   250
# 3.0          1    1  248    0   250
# 4.0          1    1    0  248   250
# All        252  251  248  249  1000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Yt))
acc = np.sum(tlabels == plabels) / len(Yt)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.995

# %%
t.plot_decision_regions(Xt,np.squeeze(Yt), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
import tools as t

# %%
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows= int(ntrees/2)
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print (X.shape, Y.shape)
# Out:
# (30000, 2) (30000,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Conic',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 20673 Examples, and Right Node with 9327 Examples
# Creating Left Child Node With 16406 Examples, and Right Node with 4267 Examples
# Creating Left Child Node With 5550 Examples, and Right Node with 10856 Examples
# Creating Left Child Node With 3628 Examples, and Right Node with 1922 Examples
# Creating Child Node With ClassLabel=0, nexamples=3628, classes=[(0, 0.9864939360529217), (1, 0.012403528114663727), (2, 0.0011025358324145535)]
# Creating Child Node With ClassLabel=0, nexamples=1922, classes=[(0, 0.8303850156087409), (2, 0.1696149843912591)]
# Creating Left Child Node With 2166 Examples, and Right Node with 8690 Examples
# Creating Child Node With ClassLabel=0, nexamples=2166, classes=[(0, 0.8079409048938134), (2, 0.18421052631578946), (1, 0.007848568790397045)]
# Creating Child Node With ClassLabel=2, nexamples=8690, classes=[(2, 0.8042577675489068), (0, 0.1911392405063291), (1, 0.004602991944764097)]
# Creating Left Child Node With 568 Examples, and Right Node with 3699 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 568 Examples
# Creating Child Node With ClassLabel=0, nexamples=568, classes=[(0, 0.7411971830985915), (1, 0.25880281690140844)]
# Creating Left Child Node With 3699 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=3699, classes=[(1, 0.9991889699918897), (0, 0.0008110300081103001)]
# Creating Left Child Node With 7030 Examples, and Right Node with 2297 Examples
# Creating Left Child Node With 6440 Examples, and Right Node with 590 Examples
# Creating Left Child Node With 493 Examples, and Right Node with 5947 Examples
# Creating Child Node With ClassLabel=2, nexamples=493, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5947, classes=[(1, 0.9826803430300992), (2, 0.016983352951067766), (0, 0.00033630401883302503)]
# Creating Child Node With ClassLabel=0, nexamples=590, classes=[(0, 1.0)]
# Creating Left Child Node With 1694 Examples, and Right Node with 603 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 1683 Examples
# Creating Child Node With ClassLabel=1, nexamples=11, classes=[(1, 0.5454545454545454), (2, 0.45454545454545453)]
# Creating Child Node With ClassLabel=2, nexamples=1683, classes=[(2, 1.0)]
# Creating Left Child Node With 242 Examples, and Right Node with 361 Examples
# Creating Child Node With ClassLabel=1, nexamples=242, classes=[(1, 0.8471074380165289), (0, 0.15289256198347106)]
# Creating Child Node With ClassLabel=0, nexamples=361, classes=[(0, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 25865 Examples, and Right Node with 4135 Examples
# Creating Left Child Node With 16404 Examples, and Right Node with 9461 Examples
# Creating Left Child Node With 5422 Examples, and Right Node with 10982 Examples
# Creating Left Child Node With 2446 Examples, and Right Node with 2976 Examples
# Creating Child Node With ClassLabel=1, nexamples=2446, classes=[(1, 0.7469337694194603), (0, 0.2530662305805397)]
# Creating Child Node With ClassLabel=0, nexamples=2976, classes=[(0, 0.9939516129032258), (1, 0.004368279569892473), (2, 0.0016801075268817205)]
# Creating Left Child Node With 6350 Examples, and Right Node with 4632 Examples
# Creating Child Node With ClassLabel=0, nexamples=6350, classes=[(0, 0.8075590551181102), (1, 0.19228346456692913), (2, 0.00015748031496062991)]
# Creating Child Node With ClassLabel=2, nexamples=4632, classes=[(2, 0.5677892918825561), (0, 0.24352331606217617), (1, 0.18868739205526772)]
# Creating Left Child Node With 7196 Examples, and Right Node with 2265 Examples
# Creating Left Child Node With 3569 Examples, and Right Node with 3627 Examples
# Creating Child Node With ClassLabel=2, nexamples=3569, classes=[(2, 0.5155505743905856), (1, 0.43877836929111796), (0, 0.04567105631829644)]
# Creating Child Node With ClassLabel=1, nexamples=3627, classes=[(1, 1.0)]
# Creating Left Child Node With 2212 Examples, and Right Node with 53 Examples
# Creating Child Node With ClassLabel=2, nexamples=2212, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=53, classes=[(1, 1.0)]
# Creating Left Child Node With 1820 Examples, and Right Node with 2315 Examples
# Creating Left Child Node With 1752 Examples, and Right Node with 68 Examples
# Creating Child Node With ClassLabel=2, nexamples=1752, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 68 Examples
# Creating Child Node With ClassLabel=2, nexamples=68, classes=[(2, 0.9411764705882353), (0, 0.058823529411764705)]
# Creating Left Child Node With 1229 Examples, and Right Node with 1086 Examples
# Creating Left Child Node With 770 Examples, and Right Node with 459 Examples
# Creating Child Node With ClassLabel=2, nexamples=770, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=459, classes=[(1, 0.5686274509803921), (2, 0.43137254901960786)]
# Creating Left Child Node With 528 Examples, and Right Node with 558 Examples
# Creating Child Node With ClassLabel=2, nexamples=528, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=558, classes=[(1, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 22720 Examples, and Right Node with 7280 Examples
# Creating Left Child Node With 4697 Examples, and Right Node with 18023 Examples
# Creating Left Child Node With 285 Examples, and Right Node with 4412 Examples
# Creating Left Child Node With 157 Examples, and Right Node with 128 Examples
# Creating Child Node With ClassLabel=0, nexamples=157, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=128, classes=[(2, 1.0)]
# Creating Left Child Node With 190 Examples, and Right Node with 4222 Examples
# Creating Child Node With ClassLabel=1, nexamples=190, classes=[(1, 0.8), (2, 0.2)]
# Creating Child Node With ClassLabel=1, nexamples=4222, classes=[(1, 0.9990525817148271), (0, 0.0009474182851729038)]
# Creating Left Child Node With 14212 Examples, and Right Node with 3811 Examples
# Creating Left Child Node With 11221 Examples, and Right Node with 2991 Examples
# Creating Child Node With ClassLabel=0, nexamples=11221, classes=[(0, 0.6144728633811604), (2, 0.2809909990196952), (1, 0.10453613759914446)]
# Creating Child Node With ClassLabel=2, nexamples=2991, classes=[(2, 0.7569374791039786), (1, 0.2156469408224674), (0, 0.027415580073553995)]
# Creating Child Node With ClassLabel=1, nexamples=3811, classes=[(1, 1.0)]
# Creating Left Child Node With 3711 Examples, and Right Node with 3569 Examples
# Creating Left Child Node With 3525 Examples, and Right Node with 186 Examples
# Creating Left Child Node With 3133 Examples, and Right Node with 392 Examples
# Creating Child Node With ClassLabel=0, nexamples=3133, classes=[(0, 0.7813597191190552), (2, 0.21864028088094478)]
# Creating Child Node With ClassLabel=0, nexamples=392, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=186, classes=[(2, 1.0)]
# Creating Left Child Node With 3568 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 1558 Examples, and Right Node with 2010 Examples
# Creating Child Node With ClassLabel=2, nexamples=1558, classes=[(2, 0.9858793324775353), (0, 0.014120667522464698)]
# Creating Child Node With ClassLabel=2, nexamples=2010, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1, classes=[(1, 1.0)]
#
# Creating tree # 4
# Creating Left Child Node With 9899 Examples, and Right Node with 20101 Examples
# Creating Left Child Node With 3900 Examples, and Right Node with 5999 Examples
# Creating Left Child Node With 1638 Examples, and Right Node with 2262 Examples
# Creating Left Child Node With 1332 Examples, and Right Node with 306 Examples
# Creating Child Node With ClassLabel=1, nexamples=1332, classes=[(1, 0.9316816816816816), (2, 0.06831831831831832)]
# Creating Child Node With ClassLabel=2, nexamples=306, classes=[(2, 0.7516339869281046), (1, 0.24836601307189543)]
# Creating Left Child Node With 14 Examples, and Right Node with 2248 Examples
# Creating Child Node With ClassLabel=1, nexamples=14, classes=[(1, 0.8571428571428571), (0, 0.14285714285714285)]
# Creating Child Node With ClassLabel=1, nexamples=2248, classes=[(1, 1.0)]
# Creating Left Child Node With 2779 Examples, and Right Node with 3220 Examples
# Creating Child Node With ClassLabel=0, nexamples=2779, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 3220 Examples
# Creating Child Node With ClassLabel=0, nexamples=3220, classes=[(0, 0.5546583850931677), (1, 0.4453416149068323)]
# Creating Left Child Node With 5975 Examples, and Right Node with 14126 Examples
# Creating Left Child Node With 2615 Examples, and Right Node with 3360 Examples
# Creating Left Child Node With 70 Examples, and Right Node with 2545 Examples
# Creating Child Node With ClassLabel=1, nexamples=70, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2545, classes=[(2, 0.9913555992141454), (0, 0.008644400785854617)]
# Creating Left Child Node With 1637 Examples, and Right Node with 1723 Examples
# Creating Child Node With ClassLabel=0, nexamples=1637, classes=[(0, 0.9896151496640195), (2, 0.010384850335980453)]
# Creating Child Node With ClassLabel=2, nexamples=1723, classes=[(2, 0.942542077771329), (0, 0.057457922228670924)]
# Creating Left Child Node With 5957 Examples, and Right Node with 8169 Examples
# Creating Left Child Node With 682 Examples, and Right Node with 5275 Examples
# Creating Child Node With ClassLabel=2, nexamples=682, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5275, classes=[(1, 0.7495734597156398), (2, 0.2504265402843602)]
# Creating Left Child Node With 4548 Examples, and Right Node with 3621 Examples
# Creating Child Node With ClassLabel=2, nexamples=4548, classes=[(2, 0.772207563764292), (0, 0.16886543535620052), (1, 0.058927000879507474)]
# Creating Child Node With ClassLabel=0, nexamples=3621, classes=[(0, 0.8075117370892019), (1, 0.19248826291079812)]
#
# Creating tree # 5
# Creating Left Child Node With 7517 Examples, and Right Node with 22483 Examples
# Creating Left Child Node With 4590 Examples, and Right Node with 2927 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 4582 Examples
# Creating Child Node With ClassLabel=2, nexamples=8, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=4582, classes=[(1, 1.0)]
# Creating Left Child Node With 2923 Examples, and Right Node with 4 Examples
# Creating Left Child Node With 607 Examples, and Right Node with 2316 Examples
# Creating Child Node With ClassLabel=0, nexamples=607, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2316, classes=[(0, 0.9991364421416234), (1, 0.0008635578583765112)]
# Creating Child Node With ClassLabel=0, nexamples=4, classes=[(0, 0.5), (1, 0.5)]
# Creating Left Child Node With 9683 Examples, and Right Node with 12800 Examples
# Creating Left Child Node With 3064 Examples, and Right Node with 6619 Examples
# Creating Left Child Node With 1410 Examples, and Right Node with 1654 Examples
# Creating Child Node With ClassLabel=0, nexamples=1410, classes=[(0, 0.9659574468085106), (1, 0.03404255319148936)]
# Creating Child Node With ClassLabel=0, nexamples=1654, classes=[(0, 1.0)]
# Creating Left Child Node With 2911 Examples, and Right Node with 3708 Examples
# Creating Child Node With ClassLabel=0, nexamples=2911, classes=[(0, 0.9996564754379939), (1, 0.00034352456200618345)]
# Creating Child Node With ClassLabel=1, nexamples=3708, classes=[(1, 0.5857605177993528), (2, 0.41423948220064727)]
# Creating Left Child Node With 10103 Examples, and Right Node with 2697 Examples
# Creating Left Child Node With 9027 Examples, and Right Node with 1076 Examples
# Creating Child Node With ClassLabel=2, nexamples=9027, classes=[(2, 0.6576935859089399), (1, 0.23451866622355158), (0, 0.10778774786750858)]
# Creating Child Node With ClassLabel=1, nexamples=1076, classes=[(1, 1.0)]
# Creating Left Child Node With 869 Examples, and Right Node with 1828 Examples
# Creating Child Node With ClassLabel=2, nexamples=869, classes=[(2, 0.7951668584579977), (0, 0.2048331415420023)]
# Creating Child Node With ClassLabel=2, nexamples=1828, classes=[(2, 1.0)]
#
# Creating tree # 6
# Creating Left Child Node With 20018 Examples, and Right Node with 9982 Examples
# Creating Left Child Node With 10870 Examples, and Right Node with 9148 Examples
# Creating Left Child Node With 5686 Examples, and Right Node with 5184 Examples
# Creating Left Child Node With 4087 Examples, and Right Node with 1599 Examples
# Creating Child Node With ClassLabel=1, nexamples=4087, classes=[(1, 0.9860533398580866), (2, 0.013946660141913383)]
# Creating Child Node With ClassLabel=1, nexamples=1599, classes=[(1, 0.7454659161976235), (0, 0.25453408380237647)]
# Creating Left Child Node With 3411 Examples, and Right Node with 1773 Examples
# Creating Child Node With ClassLabel=2, nexamples=3411, classes=[(2, 0.9917912635590735), (0, 0.008208736440926415)]
# Creating Child Node With ClassLabel=1, nexamples=1773, classes=[(1, 0.9554427523970671), (2, 0.044557247602932885)]
# Creating Left Child Node With 3307 Examples, and Right Node with 5841 Examples
# Creating Left Child Node With 1838 Examples, and Right Node with 1469 Examples
# Creating Child Node With ClassLabel=1, nexamples=1838, classes=[(1, 0.9804134929270947), (0, 0.01958650707290533)]
# Creating Child Node With ClassLabel=0, nexamples=1469, classes=[(0, 0.5929203539823009), (1, 0.40707964601769914)]
# Creating Left Child Node With 3422 Examples, and Right Node with 2419 Examples
# Creating Child Node With ClassLabel=0, nexamples=3422, classes=[(0, 0.668614845119813), (2, 0.2559906487434249), (1, 0.07539450613676213)]
# Creating Child Node With ClassLabel=0, nexamples=2419, classes=[(0, 0.9847044233154196), (1, 0.015295576684580404)]
# Creating Left Child Node With 6541 Examples, and Right Node with 3441 Examples
# Creating Left Child Node With 2478 Examples, and Right Node with 4063 Examples
# Creating Left Child Node With 1345 Examples, and Right Node with 1133 Examples
# Creating Child Node With ClassLabel=2, nexamples=1345, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1133, classes=[(2, 0.8058252427184466), (0, 0.1941747572815534)]
# Creating Left Child Node With 784 Examples, and Right Node with 3279 Examples
# Creating Child Node With ClassLabel=0, nexamples=784, classes=[(0, 0.6237244897959183), (2, 0.3762755102040816)]
# Creating Child Node With ClassLabel=0, nexamples=3279, classes=[(0, 1.0)]
# Creating Left Child Node With 3044 Examples, and Right Node with 397 Examples
# Creating Left Child Node With 3044 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=3044, classes=[(2, 0.9996714848883048), (1, 0.000328515111695138)]
# Creating Left Child Node With 9 Examples, and Right Node with 388 Examples
# Creating Child Node With ClassLabel=2, nexamples=9, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=388, classes=[(1, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 21015 Examples, and Right Node with 8985 Examples
# Creating Left Child Node With 11824 Examples, and Right Node with 9191 Examples
# Creating Left Child Node With 8710 Examples, and Right Node with 3114 Examples
# Creating Left Child Node With 2382 Examples, and Right Node with 6328 Examples
# Creating Child Node With ClassLabel=0, nexamples=2382, classes=[(0, 0.9848866498740554), (1, 0.015113350125944584)]
# Creating Child Node With ClassLabel=2, nexamples=6328, classes=[(2, 0.6178887484197219), (0, 0.3361251580278129), (1, 0.04598609355246523)]
# Creating Left Child Node With 252 Examples, and Right Node with 2862 Examples
# Creating Child Node With ClassLabel=2, nexamples=252, classes=[(2, 0.746031746031746), (0, 0.25396825396825395)]
# Creating Child Node With ClassLabel=1, nexamples=2862, classes=[(1, 0.9863731656184487), (2, 0.013626834381551363)]
# Creating Left Child Node With 5419 Examples, and Right Node with 3772 Examples
# Creating Left Child Node With 2989 Examples, and Right Node with 2430 Examples
# Creating Child Node With ClassLabel=0, nexamples=2989, classes=[(0, 0.7223151555704249), (1, 0.2773502843760455), (2, 0.00033456005352960856)]
# Creating Child Node With ClassLabel=1, nexamples=2430, classes=[(1, 0.920164609053498), (0, 0.07983539094650206)]
# Creating Left Child Node With 3 Examples, and Right Node with 3769 Examples
# Creating Child Node With ClassLabel=1, nexamples=3, classes=[(1, 0.6666666666666666), (2, 0.3333333333333333)]
# Creating Child Node With ClassLabel=1, nexamples=3769, classes=[(1, 1.0)]
# Creating Left Child Node With 5422 Examples, and Right Node with 3563 Examples
# Creating Left Child Node With 2915 Examples, and Right Node with 2507 Examples
# Creating Left Child Node With 2857 Examples, and Right Node with 58 Examples
# Creating Child Node With ClassLabel=0, nexamples=2857, classes=[(0, 0.9866993349667483), (2, 0.013300665033251663)]
# Creating Child Node With ClassLabel=2, nexamples=58, classes=[(2, 1.0)]
# Creating Left Child Node With 2507 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=2507, classes=[(2, 0.8930993218986837), (0, 0.10690067810131632)]
# Creating Left Child Node With 2908 Examples, and Right Node with 655 Examples
# Creating Left Child Node With 2907 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=2, nexamples=2907, classes=[(2, 0.9951840385276918), (1, 0.004471964224286206), (0, 0.0003439972480220158)]
# Creating Child Node With ClassLabel=1, nexamples=1, classes=[(1, 1.0)]
# Creating Left Child Node With 292 Examples, and Right Node with 363 Examples
# Creating Child Node With ClassLabel=2, nexamples=292, classes=[(2, 0.9246575342465754), (0, 0.07534246575342465)]
# Creating Child Node With ClassLabel=2, nexamples=363, classes=[(2, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 16277 Examples, and Right Node with 13723 Examples
# Creating Left Child Node With 10419 Examples, and Right Node with 5858 Examples
# Creating Left Child Node With 7219 Examples, and Right Node with 3200 Examples
# Creating Left Child Node With 3061 Examples, and Right Node with 4158 Examples
# Creating Child Node With ClassLabel=2, nexamples=3061, classes=[(2, 0.9905259719046063), (0, 0.009474028095393662)]
# Creating Child Node With ClassLabel=0, nexamples=4158, classes=[(0, 0.7710437710437711), (2, 0.227994227994228), (1, 0.000962000962000962)]
# Creating Child Node With ClassLabel=2, nexamples=3200, classes=[(2, 1.0)]
# Creating Left Child Node With 3291 Examples, and Right Node with 2567 Examples
# Creating Left Child Node With 1719 Examples, and Right Node with 1572 Examples
# Creating Child Node With ClassLabel=1, nexamples=1719, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1572, classes=[(0, 0.4669211195928753), (1, 0.4402035623409669), (2, 0.09287531806615776)]
# Creating Left Child Node With 599 Examples, and Right Node with 1968 Examples
# Creating Child Node With ClassLabel=0, nexamples=599, classes=[(0, 0.5843071786310517), (2, 0.41569282136894825)]
# Creating Child Node With ClassLabel=0, nexamples=1968, classes=[(0, 0.9994918699186992), (1, 0.0005081300813008131)]
# Creating Left Child Node With 4600 Examples, and Right Node with 9123 Examples
# Creating Left Child Node With 2373 Examples, and Right Node with 2227 Examples
# Creating Left Child Node With 812 Examples, and Right Node with 1561 Examples
# Creating Child Node With ClassLabel=1, nexamples=812, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1561, classes=[(2, 1.0)]
# Creating Left Child Node With 1940 Examples, and Right Node with 287 Examples
# Creating Child Node With ClassLabel=0, nexamples=1940, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=287, classes=[(2, 1.0)]
# Creating Left Child Node With 4185 Examples, and Right Node with 4938 Examples
# Creating Left Child Node With 2096 Examples, and Right Node with 2089 Examples
# Creating Child Node With ClassLabel=0, nexamples=2096, classes=[(0, 0.8463740458015268), (1, 0.09255725190839695), (2, 0.061068702290076333)]
# Creating Child Node With ClassLabel=1, nexamples=2089, classes=[(1, 0.9923408329344183), (2, 0.007659167065581618)]
# Creating Left Child Node With 4505 Examples, and Right Node with 433 Examples
# Creating Child Node With ClassLabel=1, nexamples=4505, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=433, classes=[(2, 1.0)]
#
# Creating tree # 9
# Creating Left Child Node With 21481 Examples, and Right Node with 8519 Examples
# Creating Left Child Node With 8914 Examples, and Right Node with 12567 Examples
# Creating Left Child Node With 4359 Examples, and Right Node with 4555 Examples
# Creating Left Child Node With 3560 Examples, and Right Node with 799 Examples
# Creating Child Node With ClassLabel=0, nexamples=3560, classes=[(0, 0.8460674157303371), (1, 0.15393258426966291)]
# Creating Child Node With ClassLabel=1, nexamples=799, classes=[(1, 1.0)]
# Creating Left Child Node With 2004 Examples, and Right Node with 2551 Examples
# Creating Child Node With ClassLabel=1, nexamples=2004, classes=[(1, 0.9955089820359282), (2, 0.004491017964071856)]
# Creating Child Node With ClassLabel=1, nexamples=2551, classes=[(1, 1.0)]
# Creating Left Child Node With 7488 Examples, and Right Node with 5079 Examples
# Creating Left Child Node With 7337 Examples, and Right Node with 151 Examples
# Creating Child Node With ClassLabel=0, nexamples=7337, classes=[(0, 0.7802916723456453), (2, 0.21970832765435463)]
# Creating Child Node With ClassLabel=1, nexamples=151, classes=[(1, 1.0)]
# Creating Left Child Node With 1661 Examples, and Right Node with 3418 Examples
# Creating Child Node With ClassLabel=0, nexamples=1661, classes=[(0, 0.5960264900662252), (2, 0.2600842865743528), (1, 0.14388922335942203)]
# Creating Child Node With ClassLabel=2, nexamples=3418, classes=[(2, 0.9631363370392042), (0, 0.03627852545348157), (1, 0.0005851375073142189)]
# Creating Left Child Node With 3663 Examples, and Right Node with 4856 Examples
# Creating Left Child Node With 3322 Examples, and Right Node with 341 Examples
# Creating Left Child Node With 3316 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=1, nexamples=3316, classes=[(1, 0.9987937273823885), (2, 0.0012062726176115801)]
# Creating Child Node With ClassLabel=2, nexamples=6, classes=[(2, 1.0)]
# Creating Left Child Node With 276 Examples, and Right Node with 65 Examples
# Creating Child Node With ClassLabel=2, nexamples=276, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=65, classes=[(1, 0.9846153846153847), (2, 0.015384615384615385)]
# Creating Left Child Node With 2624 Examples, and Right Node with 2232 Examples
# Creating Left Child Node With 1324 Examples, and Right Node with 1300 Examples
# Creating Child Node With ClassLabel=2, nexamples=1324, classes=[(2, 0.9916918429003021), (0, 0.008308157099697885)]
# Creating Child Node With ClassLabel=2, nexamples=1300, classes=[(2, 0.7392307692307692), (1, 0.26076923076923075)]
# Creating Left Child Node With 1176 Examples, and Right Node with 1056 Examples
# Creating Child Node With ClassLabel=2, nexamples=1176, classes=[(2, 0.8826530612244898), (0, 0.11734693877551021)]
# Creating Child Node With ClassLabel=2, nexamples=1056, classes=[(2, 1.0)]
#
# Creating tree # 10
# Creating Left Child Node With 16864 Examples, and Right Node with 13136 Examples
# Creating Left Child Node With 12594 Examples, and Right Node with 4270 Examples
# Creating Left Child Node With 9073 Examples, and Right Node with 3521 Examples
# Creating Left Child Node With 7389 Examples, and Right Node with 1684 Examples
# Creating Child Node With ClassLabel=1, nexamples=7389, classes=[(1, 0.8216267424550007), (2, 0.09798348897009068), (0, 0.08038976857490865)]
# Creating Child Node With ClassLabel=0, nexamples=1684, classes=[(0, 0.998812351543943), (2, 0.0011876484560570072)]
# Creating Left Child Node With 3414 Examples, and Right Node with 107 Examples
# Creating Child Node With ClassLabel=0, nexamples=3414, classes=[(0, 0.8280609256004686), (2, 0.11511423550087874), (1, 0.056824838898652606)]
# Creating Child Node With ClassLabel=1, nexamples=107, classes=[(1, 1.0)]
# Creating Left Child Node With 2243 Examples, and Right Node with 2027 Examples
# Creating Left Child Node With 2186 Examples, and Right Node with 57 Examples
# Creating Child Node With ClassLabel=2, nexamples=2186, classes=[(2, 0.9917657822506862), (0, 0.008234217749313814)]
# Creating Child Node With ClassLabel=1, nexamples=57, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=2027, classes=[(1, 1.0)]
# Creating Left Child Node With 2951 Examples, and Right Node with 10185 Examples
# Creating Left Child Node With 747 Examples, and Right Node with 2204 Examples
# Creating Child Node With ClassLabel=0, nexamples=747, classes=[(0, 1.0)]
# Creating Left Child Node With 1879 Examples, and Right Node with 325 Examples
# Creating Child Node With ClassLabel=1, nexamples=1879, classes=[(1, 0.739755188930282), (0, 0.2602448110697179)]
# Creating Child Node With ClassLabel=0, nexamples=325, classes=[(0, 0.9692307692307692), (1, 0.03076923076923077)]
# Creating Left Child Node With 1746 Examples, and Right Node with 8439 Examples
# Creating Left Child Node With 1670 Examples, and Right Node with 76 Examples
# Creating Child Node With ClassLabel=0, nexamples=1670, classes=[(0, 0.9425149700598803), (1, 0.029940119760479042), (2, 0.027544910179640718)]
# Creating Child Node With ClassLabel=1, nexamples=76, classes=[(1, 1.0)]
# Creating Left Child Node With 7013 Examples, and Right Node with 1426 Examples
# Creating Child Node With ClassLabel=2, nexamples=7013, classes=[(2, 0.9506630543276772), (0, 0.04677028375873378), (1, 0.002566661913589049)]
# Creating Child Node With ClassLabel=0, nexamples=1426, classes=[(0, 1.0)]
#
# Creating tree # 11
# Creating Left Child Node With 22944 Examples, and Right Node with 7056 Examples
# Creating Left Child Node With 18628 Examples, and Right Node with 4316 Examples
# Creating Left Child Node With 6871 Examples, and Right Node with 11757 Examples
# Creating Left Child Node With 3338 Examples, and Right Node with 3533 Examples
# Creating Child Node With ClassLabel=2, nexamples=3338, classes=[(2, 0.6153385260635111), (0, 0.3846614739364889)]
# Creating Child Node With ClassLabel=0, nexamples=3533, classes=[(0, 0.6651570902915369), (1, 0.3348429097084631)]
# Creating Left Child Node With 4085 Examples, and Right Node with 7672 Examples
# Creating Child Node With ClassLabel=0, nexamples=4085, classes=[(0, 0.6844553243574052), (2, 0.19657282741738066), (1, 0.1189718482252142)]
# Creating Child Node With ClassLabel=1, nexamples=7672, classes=[(1, 0.9813607924921793), (2, 0.018639207507820648)]
# Creating Left Child Node With 603 Examples, and Right Node with 3713 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 598 Examples
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(1, 0.6), (0, 0.4)]
# Creating Child Node With ClassLabel=1, nexamples=598, classes=[(1, 1.0)]
# Creating Left Child Node With 3512 Examples, and Right Node with 201 Examples
# Creating Child Node With ClassLabel=2, nexamples=3512, classes=[(2, 0.9678246013667426), (0, 0.032175398633257406)]
# Creating Child Node With ClassLabel=1, nexamples=201, classes=[(1, 1.0)]
# Creating Left Child Node With 6524 Examples, and Right Node with 532 Examples
# Creating Left Child Node With 3625 Examples, and Right Node with 2899 Examples
# Creating Left Child Node With 2056 Examples, and Right Node with 1569 Examples
# Creating Child Node With ClassLabel=0, nexamples=2056, classes=[(0, 0.9873540856031129), (2, 0.01264591439688716)]
# Creating Child Node With ClassLabel=2, nexamples=1569, classes=[(2, 0.6035691523263225), (0, 0.3964308476736775)]
# Creating Left Child Node With 515 Examples, and Right Node with 2384 Examples
# Creating Child Node With ClassLabel=0, nexamples=515, classes=[(0, 0.5262135922330097), (2, 0.47378640776699027)]
# Creating Child Node With ClassLabel=2, nexamples=2384, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=532, classes=[(0, 1.0)]
#
# Creating tree # 12
# Creating Left Child Node With 19079 Examples, and Right Node with 10921 Examples
# Creating Left Child Node With 4719 Examples, and Right Node with 14360 Examples
# Creating Left Child Node With 4634 Examples, and Right Node with 85 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 4634 Examples
# Creating Child Node With ClassLabel=1, nexamples=4634, classes=[(1, 0.9993526111350884), (0, 0.0006473888649115235)]
# Creating Left Child Node With 85 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=85, classes=[(2, 0.9764705882352941), (1, 0.023529411764705882)]
# Creating Left Child Node With 6109 Examples, and Right Node with 8251 Examples
# Creating Left Child Node With 480 Examples, and Right Node with 5629 Examples
# Creating Child Node With ClassLabel=0, nexamples=480, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5629, classes=[(1, 0.8948303428672943), (0, 0.09379996446971042), (2, 0.011369692662995203)]
# Creating Left Child Node With 2451 Examples, and Right Node with 5800 Examples
# Creating Child Node With ClassLabel=0, nexamples=2451, classes=[(0, 0.8694410444716443), (1, 0.0762953896368829), (2, 0.05426356589147287)]
# Creating Child Node With ClassLabel=2, nexamples=5800, classes=[(2, 0.5705172413793104), (0, 0.42948275862068963)]
# Creating Left Child Node With 6236 Examples, and Right Node with 4685 Examples
# Creating Left Child Node With 2888 Examples, and Right Node with 3348 Examples
# Creating Left Child Node With 1249 Examples, and Right Node with 1639 Examples
# Creating Child Node With ClassLabel=0, nexamples=1249, classes=[(0, 0.8783026421136909), (2, 0.12169735788630905)]
# Creating Child Node With ClassLabel=2, nexamples=1639, classes=[(2, 1.0)]
# Creating Left Child Node With 2865 Examples, and Right Node with 483 Examples
# Creating Child Node With ClassLabel=0, nexamples=2865, classes=[(0, 0.9993019197207679), (2, 0.0006980802792321117)]
# Creating Child Node With ClassLabel=0, nexamples=483, classes=[(0, 0.7039337474120083), (1, 0.29606625258799174)]
# Creating Left Child Node With 3026 Examples, and Right Node with 1659 Examples
# Creating Left Child Node With 1611 Examples, and Right Node with 1415 Examples
# Creating Child Node With ClassLabel=2, nexamples=1611, classes=[(2, 0.9584109248913718), (0, 0.04158907510862818)]
# Creating Child Node With ClassLabel=2, nexamples=1415, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1659, classes=[(2, 1.0)]
#
# Creating tree # 13
# Creating Left Child Node With 14508 Examples, and Right Node with 15492 Examples
# Creating Left Child Node With 3441 Examples, and Right Node with 11067 Examples
# Creating Left Child Node With 366 Examples, and Right Node with 3075 Examples
# Creating Child Node With ClassLabel=2, nexamples=366, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=3075, classes=[(1, 1.0)]
# Creating Left Child Node With 7334 Examples, and Right Node with 3733 Examples
# Creating Left Child Node With 1159 Examples, and Right Node with 6175 Examples
# Creating Child Node With ClassLabel=2, nexamples=1159, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=6175, classes=[(0, 0.6455060728744939), (2, 0.3544939271255061)]
# Creating Left Child Node With 1266 Examples, and Right Node with 2467 Examples
# Creating Child Node With ClassLabel=2, nexamples=1266, classes=[(2, 0.9162717219589257), (1, 0.05529225908372828), (0, 0.02843601895734597)]
# Creating Child Node With ClassLabel=2, nexamples=2467, classes=[(2, 0.9995946493717065), (0, 0.00040535062829347385)]
# Creating Left Child Node With 5933 Examples, and Right Node with 9559 Examples
# Creating Left Child Node With 5708 Examples, and Right Node with 225 Examples
# Creating Left Child Node With 5305 Examples, and Right Node with 403 Examples
# Creating Child Node With ClassLabel=1, nexamples=5305, classes=[(1, 0.9890669180018851), (2, 0.00999057492931197), (0, 0.000942507068803016)]
# Creating Child Node With ClassLabel=2, nexamples=403, classes=[(2, 0.9528535980148883), (1, 0.04714640198511166)]
# Creating Child Node With ClassLabel=2, nexamples=225, classes=[(2, 1.0)]
# Creating Left Child Node With 7976 Examples, and Right Node with 1583 Examples
# Creating Left Child Node With 2578 Examples, and Right Node with 5398 Examples
# Creating Child Node With ClassLabel=0, nexamples=2578, classes=[(0, 0.8297129557796742), (1, 0.12490302560124127), (2, 0.04538401861908456)]
# Creating Child Node With ClassLabel=0, nexamples=5398, classes=[(0, 0.657465728047425), (2, 0.342534271952575)]
# Creating Left Child Node With 1299 Examples, and Right Node with 284 Examples
# Creating Child Node With ClassLabel=1, nexamples=1299, classes=[(1, 0.9753656658968437), (2, 0.024634334103156273)]
# Creating Child Node With ClassLabel=0, nexamples=284, classes=[(0, 1.0)]
#
# Creating tree # 14
# Creating Left Child Node With 17936 Examples, and Right Node with 12064 Examples
# Creating Left Child Node With 3897 Examples, and Right Node with 14039 Examples
# Creating Child Node With ClassLabel=1, nexamples=3897, classes=[(1, 1.0)]
# Creating Left Child Node With 7285 Examples, and Right Node with 6754 Examples
# Creating Left Child Node With 4274 Examples, and Right Node with 3011 Examples
# Creating Child Node With ClassLabel=2, nexamples=4274, classes=[(2, 0.7201684604585868), (0, 0.23444080486663546), (1, 0.04539073467477773)]
# Creating Child Node With ClassLabel=1, nexamples=3011, classes=[(1, 1.0)]
# Creating Left Child Node With 2854 Examples, and Right Node with 3900 Examples
# Creating Child Node With ClassLabel=0, nexamples=2854, classes=[(0, 0.9887876664330764), (1, 0.007358093903293623), (2, 0.003854239663629993)]
# Creating Child Node With ClassLabel=1, nexamples=3900, classes=[(1, 0.6597435897435897), (0, 0.34025641025641024)]
# Creating Left Child Node With 6380 Examples, and Right Node with 5684 Examples
# Creating Left Child Node With 3472 Examples, and Right Node with 2908 Examples
# Creating Left Child Node With 841 Examples, and Right Node with 2631 Examples
# Creating Child Node With ClassLabel=2, nexamples=841, classes=[(2, 0.9726516052318668), (1, 0.027348394768133173)]
# Creating Child Node With ClassLabel=2, nexamples=2631, classes=[(2, 0.9973394146712277), (0, 0.0026605853287723297)]
# Creating Left Child Node With 59 Examples, and Right Node with 2849 Examples
# Creating Child Node With ClassLabel=0, nexamples=59, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2849, classes=[(2, 0.9484029484029484), (0, 0.051597051597051594)]
# Creating Left Child Node With 5083 Examples, and Right Node with 601 Examples
# Creating Left Child Node With 1858 Examples, and Right Node with 3225 Examples
# Creating Child Node With ClassLabel=0, nexamples=1858, classes=[(0, 0.8665231431646933), (1, 0.1302475780409042), (2, 0.0032292787944025836)]
# Creating Child Node With ClassLabel=0, nexamples=3225, classes=[(0, 0.9382945736434108), (2, 0.06170542635658915)]
# Creating Left Child Node With 323 Examples, and Right Node with 278 Examples
# Creating Child Node With ClassLabel=2, nexamples=323, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=278, classes=[(2, 0.8597122302158273), (1, 0.14028776978417265)]
#
# Creating tree # 15
# Creating Left Child Node With 6123 Examples, and Right Node with 23877 Examples
# Creating Left Child Node With 659 Examples, and Right Node with 5464 Examples
# Creating Left Child Node With 647 Examples, and Right Node with 12 Examples
# Creating Child Node With ClassLabel=2, nexamples=647, classes=[(2, 1.0)]
# Creating Left Child Node With 5 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=7, classes=[(2, 1.0)]
# Creating Left Child Node With 5060 Examples, and Right Node with 404 Examples
# Creating Left Child Node With 1908 Examples, and Right Node with 3152 Examples
# Creating Child Node With ClassLabel=1, nexamples=1908, classes=[(1, 0.7405660377358491), (2, 0.25943396226415094)]
# Creating Child Node With ClassLabel=1, nexamples=3152, classes=[(1, 0.9968274111675127), (0, 0.0031725888324873096)]
# Creating Child Node With ClassLabel=0, nexamples=404, classes=[(0, 1.0)]
# Creating Left Child Node With 7268 Examples, and Right Node with 16609 Examples
# Creating Left Child Node With 2596 Examples, and Right Node with 4672 Examples
# Creating Left Child Node With 2380 Examples, and Right Node with 216 Examples
# Creating Child Node With ClassLabel=0, nexamples=2380, classes=[(0, 0.9882352941176471), (2, 0.011764705882352941)]
# Creating Child Node With ClassLabel=2, nexamples=216, classes=[(2, 1.0)]
# Creating Left Child Node With 2267 Examples, and Right Node with 2405 Examples
# Creating Child Node With ClassLabel=1, nexamples=2267, classes=[(1, 0.9042787825319806), (0, 0.09572121746801941)]
# Creating Child Node With ClassLabel=0, nexamples=2405, classes=[(0, 0.9542619542619543), (1, 0.04573804573804574)]
# Creating Left Child Node With 14016 Examples, and Right Node with 2593 Examples
# Creating Left Child Node With 9583 Examples, and Right Node with 4433 Examples
# Creating Child Node With ClassLabel=0, nexamples=9583, classes=[(0, 0.4927475738286549), (2, 0.48606908066367527), (1, 0.021183345507669833)]
# Creating Child Node With ClassLabel=2, nexamples=4433, classes=[(2, 0.890818858560794), (1, 0.10918114143920596)]
# Creating Child Node With ClassLabel=1, nexamples=2593, classes=[(1, 1.0)]
#
# Creating tree # 16
# Creating Left Child Node With 14128 Examples, and Right Node with 15872 Examples
# Creating Left Child Node With 6411 Examples, and Right Node with 7717 Examples
# Creating Left Child Node With 572 Examples, and Right Node with 5839 Examples
# Creating Left Child Node With 304 Examples, and Right Node with 268 Examples
# Creating Child Node With ClassLabel=1, nexamples=304, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=268, classes=[(2, 1.0)]
# Creating Left Child Node With 5655 Examples, and Right Node with 184 Examples
# Creating Child Node With ClassLabel=1, nexamples=5655, classes=[(1, 0.9971706454465075), (0, 0.0028293545534924846)]
# Creating Child Node With ClassLabel=0, nexamples=184, classes=[(0, 1.0)]
# Creating Left Child Node With 2396 Examples, and Right Node with 5321 Examples
# Creating Left Child Node With 2158 Examples, and Right Node with 238 Examples
# Creating Child Node With ClassLabel=1, nexamples=2158, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=238, classes=[(1, 0.9957983193277311), (2, 0.004201680672268907)]
# Creating Left Child Node With 646 Examples, and Right Node with 4675 Examples
# Creating Child Node With ClassLabel=2, nexamples=646, classes=[(2, 0.8869969040247678), (0, 0.1130030959752322)]
# Creating Child Node With ClassLabel=0, nexamples=4675, classes=[(0, 0.8235294117647058), (1, 0.1441711229946524), (2, 0.032299465240641714)]
# Creating Left Child Node With 6407 Examples, and Right Node with 9465 Examples
# Creating Left Child Node With 1226 Examples, and Right Node with 5181 Examples
# Creating Left Child Node With 1226 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=1226, classes=[(2, 0.5057096247960848), (1, 0.49429037520391517)]
# Creating Left Child Node With 5181 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=5181, classes=[(2, 0.9998069870681335), (1, 0.00019301293186643504)]
# Creating Left Child Node With 5424 Examples, and Right Node with 4041 Examples
# Creating Left Child Node With 1795 Examples, and Right Node with 3629 Examples
# Creating Child Node With ClassLabel=0, nexamples=1795, classes=[(0, 0.984958217270195), (2, 0.015041782729805013)]
# Creating Child Node With ClassLabel=2, nexamples=3629, classes=[(2, 0.8635987875447781), (0, 0.13640121245522183)]
# Creating Left Child Node With 1099 Examples, and Right Node with 2942 Examples
# Creating Child Node With ClassLabel=0, nexamples=1099, classes=[(0, 0.6524112829845314), (1, 0.3466787989080983), (2, 0.0009099181073703367)]
# Creating Child Node With ClassLabel=0, nexamples=2942, classes=[(0, 0.9847042828008158), (2, 0.015295717199184228)]
#
# Creating tree # 17
# Creating Left Child Node With 24395 Examples, and Right Node with 5605 Examples
# Creating Left Child Node With 9419 Examples, and Right Node with 14976 Examples
# Creating Left Child Node With 5355 Examples, and Right Node with 4064 Examples
# Creating Child Node With ClassLabel=1, nexamples=5355, classes=[(1, 1.0)]
# Creating Left Child Node With 87 Examples, and Right Node with 3977 Examples
# Creating Child Node With ClassLabel=1, nexamples=87, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=3977, classes=[(2, 0.930600955494091), (1, 0.04601458385717878), (0, 0.023384460648730197)]
# Creating Left Child Node With 7229 Examples, and Right Node with 7747 Examples
# Creating Left Child Node With 3458 Examples, and Right Node with 3771 Examples
# Creating Child Node With ClassLabel=1, nexamples=3458, classes=[(1, 0.6078658183921342), (0, 0.38027761711972236), (2, 0.011856564488143435)]
# Creating Child Node With ClassLabel=0, nexamples=3771, classes=[(0, 0.9809069212410502), (1, 0.01909307875894988)]
# Creating Left Child Node With 4160 Examples, and Right Node with 3587 Examples
# Creating Child Node With ClassLabel=1, nexamples=4160, classes=[(1, 0.4425480769230769), (0, 0.3269230769230769), (2, 0.23052884615384617)]
# Creating Child Node With ClassLabel=2, nexamples=3587, classes=[(2, 0.8996375801505436), (1, 0.10036241984945637)]
# Creating Left Child Node With 3015 Examples, and Right Node with 2590 Examples
# Creating Left Child Node With 2154 Examples, and Right Node with 861 Examples
# Creating Child Node With ClassLabel=0, nexamples=2154, classes=[(0, 1.0)]
# Creating Left Child Node With 829 Examples, and Right Node with 32 Examples
# Creating Child Node With ClassLabel=0, nexamples=829, classes=[(0, 0.9047044632086851), (2, 0.09529553679131483)]
# Creating Child Node With ClassLabel=2, nexamples=32, classes=[(2, 1.0)]
# Creating Left Child Node With 1927 Examples, and Right Node with 663 Examples
# Creating Left Child Node With 1799 Examples, and Right Node with 128 Examples
# Creating Child Node With ClassLabel=2, nexamples=1799, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=128, classes=[(2, 0.7734375), (0, 0.2265625)]
# Creating Left Child Node With 663 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=663, classes=[(0, 0.9049773755656109), (2, 0.09502262443438914)]
#
# Creating tree # 18
# Creating Left Child Node With 10555 Examples, and Right Node with 19445 Examples
# Creating Left Child Node With 7959 Examples, and Right Node with 2596 Examples
# Creating Left Child Node With 1480 Examples, and Right Node with 6479 Examples
# Creating Left Child Node With 858 Examples, and Right Node with 622 Examples
# Creating Child Node With ClassLabel=1, nexamples=858, classes=[(1, 0.5710955710955711), (0, 0.4289044289044289)]
# Creating Child Node With ClassLabel=0, nexamples=622, classes=[(0, 0.9517684887459807), (1, 0.04823151125401929)]
# Creating Left Child Node With 5995 Examples, and Right Node with 484 Examples
# Creating Child Node With ClassLabel=1, nexamples=5995, classes=[(1, 0.9029190992493745), (2, 0.09074228523769808), (0, 0.00633861551292744)]
# Creating Child Node With ClassLabel=0, nexamples=484, classes=[(0, 0.5475206611570248), (2, 0.4524793388429752)]
# Creating Child Node With ClassLabel=0, nexamples=2596, classes=[(0, 1.0)]
# Creating Left Child Node With 9912 Examples, and Right Node with 9533 Examples
# Creating Left Child Node With 6751 Examples, and Right Node with 3161 Examples
# Creating Left Child Node With 4292 Examples, and Right Node with 2459 Examples
# Creating Child Node With ClassLabel=2, nexamples=4292, classes=[(2, 0.5719944082013048), (0, 0.42800559179869524)]
# Creating Child Node With ClassLabel=0, nexamples=2459, classes=[(0, 1.0)]
# Creating Left Child Node With 2372 Examples, and Right Node with 789 Examples
# Creating Child Node With ClassLabel=2, nexamples=2372, classes=[(2, 0.7976391231028668), (0, 0.20236087689713322)]
# Creating Child Node With ClassLabel=2, nexamples=789, classes=[(2, 0.9961977186311787), (0, 0.0038022813688212928)]
# Creating Left Child Node With 3736 Examples, and Right Node with 5797 Examples
# Creating Left Child Node With 2372 Examples, and Right Node with 1364 Examples
# Creating Child Node With ClassLabel=0, nexamples=2372, classes=[(0, 0.5741989881956155), (2, 0.30522765598650925), (1, 0.1205733558178752)]
# Creating Child Node With ClassLabel=2, nexamples=1364, classes=[(2, 1.0)]
# Creating Left Child Node With 3998 Examples, and Right Node with 1799 Examples
# Creating Child Node With ClassLabel=1, nexamples=3998, classes=[(1, 0.9442221110555278), (2, 0.055777888944472234)]
# Creating Child Node With ClassLabel=2, nexamples=1799, classes=[(2, 0.9966648137854364), (1, 0.0033351862145636463)]
#
# Creating tree # 19
# Creating Left Child Node With 24420 Examples, and Right Node with 5580 Examples
# Creating Left Child Node With 12942 Examples, and Right Node with 11478 Examples
# Creating Left Child Node With 5267 Examples, and Right Node with 7675 Examples
# Creating Left Child Node With 833 Examples, and Right Node with 4434 Examples
# Creating Child Node With ClassLabel=0, nexamples=833, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=4434, classes=[(2, 0.7537212449255751), (0, 0.2219215155615697), (1, 0.02435723951285521)]
# Creating Left Child Node With 2236 Examples, and Right Node with 5439 Examples
# Creating Child Node With ClassLabel=1, nexamples=2236, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=5439, classes=[(0, 0.6227247655819085), (1, 0.35282220996506714), (2, 0.02445302445302445)]
# Creating Left Child Node With 5246 Examples, and Right Node with 6232 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 5245 Examples
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5245, classes=[(1, 0.9986653956148713), (2, 0.001334604385128694)]
# Creating Left Child Node With 3268 Examples, and Right Node with 2964 Examples
# Creating Child Node With ClassLabel=2, nexamples=3268, classes=[(2, 0.8699510403916769), (0, 0.13004895960832313)]
# Creating Child Node With ClassLabel=2, nexamples=2964, classes=[(2, 0.8404183535762483), (1, 0.1595816464237517)]
# Creating Left Child Node With 1785 Examples, and Right Node with 3795 Examples
# Creating Left Child Node With 8 Examples, and Right Node with 1777 Examples
# Creating Child Node With ClassLabel=2, nexamples=8, classes=[(2, 1.0)]
# Creating Left Child Node With 25 Examples, and Right Node with 1752 Examples
# Creating Child Node With ClassLabel=1, nexamples=25, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1752, classes=[(0, 0.9994292237442922), (1, 0.0005707762557077625)]
# Creating Left Child Node With 3017 Examples, and Right Node with 778 Examples
# Creating Left Child Node With 654 Examples, and Right Node with 2363 Examples
# Creating Child Node With ClassLabel=0, nexamples=654, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2363, classes=[(0, 0.8319932289462547), (2, 0.16800677105374523)]
# Creating Child Node With ClassLabel=2, nexamples=778, classes=[(2, 1.0)]
#
# Creating tree # 20
# Creating Left Child Node With 11111 Examples, and Right Node with 18889 Examples
# Creating Left Child Node With 3490 Examples, and Right Node with 7621 Examples
# Creating Left Child Node With 830 Examples, and Right Node with 2660 Examples
# Creating Left Child Node With 367 Examples, and Right Node with 463 Examples
# Creating Child Node With ClassLabel=2, nexamples=367, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=463, classes=[(0, 0.958963282937365), (2, 0.04103671706263499)]
# Creating Left Child Node With 1273 Examples, and Right Node with 1387 Examples
# Creating Child Node With ClassLabel=0, nexamples=1273, classes=[(0, 0.9120188531029065), (1, 0.08798114689709348)]
# Creating Child Node With ClassLabel=0, nexamples=1387, classes=[(0, 1.0)]
# Creating Left Child Node With 3146 Examples, and Right Node with 4475 Examples
# Creating Left Child Node With 1444 Examples, and Right Node with 1702 Examples
# Creating Child Node With ClassLabel=0, nexamples=1444, classes=[(0, 0.9279778393351801), (2, 0.07202216066481995)]
# Creating Child Node With ClassLabel=0, nexamples=1702, classes=[(0, 1.0)]
# Creating Left Child Node With 2894 Examples, and Right Node with 1581 Examples
# Creating Child Node With ClassLabel=2, nexamples=2894, classes=[(2, 0.9986178299930891), (0, 0.00138217000691085)]
# Creating Child Node With ClassLabel=2, nexamples=1581, classes=[(2, 0.9108159392789373), (0, 0.08918406072106262)]
# Creating Left Child Node With 8464 Examples, and Right Node with 10425 Examples
# Creating Left Child Node With 4145 Examples, and Right Node with 4319 Examples
# Creating Left Child Node With 2839 Examples, and Right Node with 1306 Examples
# Creating Child Node With ClassLabel=0, nexamples=2839, classes=[(0, 0.9165199013737232), (1, 0.06164142303628038), (2, 0.021838675589996477)]
# Creating Child Node With ClassLabel=1, nexamples=1306, classes=[(1, 0.8660030627871363), (0, 0.1339969372128637)]
# Creating Left Child Node With 1427 Examples, and Right Node with 2892 Examples
# Creating Child Node With ClassLabel=2, nexamples=1427, classes=[(2, 0.5213735108619482), (1, 0.47862648913805184)]
# Creating Child Node With ClassLabel=1, nexamples=2892, classes=[(1, 0.983402489626556), (2, 0.016597510373443983)]
# Creating Left Child Node With 8299 Examples, and Right Node with 2126 Examples
# Creating Left Child Node With 1835 Examples, and Right Node with 6464 Examples
# Creating Child Node With ClassLabel=1, nexamples=1835, classes=[(1, 0.9956403269754769), (0, 0.004359673024523161)]
# Creating Child Node With ClassLabel=2, nexamples=6464, classes=[(2, 0.6692450495049505), (1, 0.17048267326732675), (0, 0.16027227722772278)]
# Creating Child Node With ClassLabel=1, nexamples=2126, classes=[(1, 1.0)]

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9883     0   117  10000
# 1            280  9720     0  10000
# 2            158    58  9784  10000
# All        10321  9778  9901  30000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.9795666666666667

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print (Ytest.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (15000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4936     0    64   5000
# 1           135  4865     0   5000
# 2            78    31  4891   5000
# All        5149  4896  4955  15000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Ytest))
acc = np.sum(tlabels == plabels) / len(Ypt)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.9794666666666667

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
# %pdb
ntrees=rfc.ntrees
nrows=int(ntrees/2)
ncols=2
i=0
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i+1);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, V_train, Y_train, V_test = train_test_split(X, Y, train_size=0.8)
print(X_train.shape, V_train.shape, Y_train.shape, V_test.shape)
# Out:
# (24000, 2) (6000, 2) (24000,) (6000,)

# %%
rfc = rf.RandomForest(weaklearner="Conic", usebagging= True)
rfc.train(X_train,Y_train, V_train, V_test)
# rfc.train(X_train,Y_train)
# Out:
# Creating Classifier with 10 trees.
# Accuracy of Classifier with 10 trees is 98.25.
# Creating Classifier with 12 trees.
# Accuracy of Classifier with 12 trees is 97.65.
# Creating Classifier with 14 trees.
# Accuracy of Classifier with 14 trees is 98.3.
# Creating Classifier with 16 trees.
# Accuracy of Classifier with 16 trees is 98.08333333333333.
# Creating Classifier with 18 trees.
# Accuracy of Classifier with 18 trees is 97.46666666666667.
# Creating Classifier with 20 trees.
# Accuracy of Classifier with 20 trees is 98.35000000000001.
# Creating Classifier with 22 trees.
# Accuracy of Classifier with 22 trees is 98.48333333333333.
# Creating Classifier with 24 trees.
# Accuracy of Classifier with 24 trees is 97.58333333333333.
# Creating Classifier with 26 trees.
# Accuracy of Classifier with 26 trees is 97.58333333333333.
# Creating Classifier with 28 trees.
# Accuracy of Classifier with 28 trees is 98.73333333333333.
# Creating Classifier with 30 trees.
# Accuracy of Classifier with 30 trees is 98.38333333333334.
# Validation Comple. Optimal Parameters: Trees =  28 with Accuracy 0.9873333333333333
#
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 9382 Examples, and Right Node with 5018 Examples
# Creating Left Child Node With 3657 Examples, and Right Node with 5725 Examples
# Creating Left Child Node With 450 Examples, and Right Node with 3207 Examples
# Creating Left Child Node With 449 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=1, nexamples=449, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
# Creating Left Child Node With 3207 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=3207, classes=[(1, 0.9996881821016527), (0, 0.0003118178983473651)]
# Creating Left Child Node With 4483 Examples, and Right Node with 1242 Examples
# Creating Left Child Node With 353 Examples, and Right Node with 4130 Examples
# Creating Child Node With ClassLabel=2, nexamples=353, classes=[(2, 0.7478753541076487), (0, 0.2521246458923513)]
# Creating Child Node With ClassLabel=0, nexamples=4130, classes=[(0, 0.6946731234866829), (1, 0.27263922518159805), (2, 0.03268765133171913)]
# Creating Child Node With ClassLabel=2, nexamples=1242, classes=[(2, 1.0)]
# Creating Left Child Node With 3088 Examples, and Right Node with 1930 Examples
# Creating Left Child Node With 1905 Examples, and Right Node with 1183 Examples
# Creating Left Child Node With 59 Examples, and Right Node with 1846 Examples
# Creating Child Node With ClassLabel=2, nexamples=59, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1846, classes=[(0, 0.9404117009750813), (2, 0.059588299024918745)]
# Creating Left Child Node With 171 Examples, and Right Node with 1012 Examples
# Creating Child Node With ClassLabel=2, nexamples=171, classes=[(2, 0.5497076023391813), (0, 0.4502923976608187)]
# Creating Child Node With ClassLabel=2, nexamples=1012, classes=[(2, 1.0)]
# Creating Left Child Node With 234 Examples, and Right Node with 1696 Examples
# Creating Left Child Node With 234 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=234, classes=[(2, 0.9188034188034188), (0, 0.0811965811965812)]
# Creating Left Child Node With 1695 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=2, nexamples=1695, classes=[(2, 0.9946902654867257), (0, 0.00471976401179941), (1, 0.0005899705014749262)]
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 12989 Examples, and Right Node with 1411 Examples
# Creating Left Child Node With 3856 Examples, and Right Node with 9133 Examples
# Creating Left Child Node With 2760 Examples, and Right Node with 1096 Examples
# Creating Left Child Node With 894 Examples, and Right Node with 1866 Examples
# Creating Child Node With ClassLabel=2, nexamples=894, classes=[(2, 0.7997762863534675), (0, 0.20022371364653244)]
# Creating Child Node With ClassLabel=0, nexamples=1866, classes=[(0, 0.9892818863879957), (2, 0.00964630225080386), (1, 0.0010718113612004287)]
# Creating Left Child Node With 186 Examples, and Right Node with 910 Examples
# Creating Child Node With ClassLabel=2, nexamples=186, classes=[(2, 0.8709677419354839), (0, 0.12903225806451613)]
# Creating Child Node With ClassLabel=2, nexamples=910, classes=[(2, 1.0)]
# Creating Left Child Node With 2187 Examples, and Right Node with 6946 Examples
# Creating Left Child Node With 735 Examples, and Right Node with 1452 Examples
# Creating Child Node With ClassLabel=0, nexamples=735, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1452, classes=[(1, 0.7913223140495868), (0, 0.20730027548209368), (2, 0.0013774104683195593)]
# Creating Left Child Node With 4306 Examples, and Right Node with 2640 Examples
# Creating Child Node With ClassLabel=2, nexamples=4306, classes=[(2, 0.45030190431955414), (0, 0.3423130515559684), (1, 0.20738504412447747)]
# Creating Child Node With ClassLabel=1, nexamples=2640, classes=[(1, 0.6166666666666667), (2, 0.38333333333333336)]
# Creating Left Child Node With 1035 Examples, and Right Node with 376 Examples
# Creating Left Child Node With 635 Examples, and Right Node with 400 Examples
# Creating Child Node With ClassLabel=1, nexamples=635, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 400 Examples
# Creating Child Node With ClassLabel=1, nexamples=400, classes=[(1, 0.9575), (0, 0.0425)]
# Creating Left Child Node With 76 Examples, and Right Node with 300 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 76 Examples
# Creating Child Node With ClassLabel=1, nexamples=76, classes=[(1, 0.7763157894736842), (0, 0.2236842105263158)]
# Creating Child Node With ClassLabel=0, nexamples=300, classes=[(0, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 9153 Examples, and Right Node with 5247 Examples
# Creating Left Child Node With 4319 Examples, and Right Node with 4834 Examples
# Creating Left Child Node With 920 Examples, and Right Node with 3399 Examples
# Creating Left Child Node With 252 Examples, and Right Node with 668 Examples
# Creating Child Node With ClassLabel=0, nexamples=252, classes=[(0, 0.996031746031746), (2, 0.003968253968253968)]
# Creating Child Node With ClassLabel=2, nexamples=668, classes=[(2, 1.0)]
# Creating Left Child Node With 2099 Examples, and Right Node with 1300 Examples
# Creating Child Node With ClassLabel=2, nexamples=2099, classes=[(2, 0.800381133873273), (1, 0.19961886612672702)]
# Creating Child Node With ClassLabel=2, nexamples=1300, classes=[(2, 0.9992307692307693), (1, 0.0007692307692307692)]
# Creating Left Child Node With 2762 Examples, and Right Node with 2072 Examples
# Creating Left Child Node With 400 Examples, and Right Node with 2362 Examples
# Creating Child Node With ClassLabel=1, nexamples=400, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2362, classes=[(0, 0.9339542760372566), (1, 0.06604572396274344)]
# Creating Left Child Node With 563 Examples, and Right Node with 1509 Examples
# Creating Child Node With ClassLabel=1, nexamples=563, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1509, classes=[(2, 0.5427435387673957), (0, 0.4532803180914513), (1, 0.003976143141153081)]
# Creating Left Child Node With 3484 Examples, and Right Node with 1763 Examples
# Creating Left Child Node With 2994 Examples, and Right Node with 490 Examples
# Creating Left Child Node With 350 Examples, and Right Node with 2644 Examples
# Creating Child Node With ClassLabel=2, nexamples=350, classes=[(2, 0.5742857142857143), (1, 0.4257142857142857)]
# Creating Child Node With ClassLabel=1, nexamples=2644, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=490, classes=[(0, 1.0)]
# Creating Left Child Node With 336 Examples, and Right Node with 1427 Examples
# Creating Child Node With ClassLabel=1, nexamples=336, classes=[(1, 1.0)]
# Creating Left Child Node With 1362 Examples, and Right Node with 65 Examples
# Creating Child Node With ClassLabel=0, nexamples=1362, classes=[(0, 0.8333333333333334), (2, 0.10352422907488987), (1, 0.0631424375917768)]
# Creating Child Node With ClassLabel=1, nexamples=65, classes=[(1, 0.9692307692307692), (0, 0.03076923076923077)]
#
# Creating tree # 4
# Creating Left Child Node With 4663 Examples, and Right Node with 9737 Examples
# Creating Left Child Node With 1907 Examples, and Right Node with 2756 Examples
# Creating Left Child Node With 796 Examples, and Right Node with 1111 Examples
# Creating Left Child Node With 37 Examples, and Right Node with 759 Examples
# Creating Child Node With ClassLabel=2, nexamples=37, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=759, classes=[(1, 1.0)]
# Creating Left Child Node With 769 Examples, and Right Node with 342 Examples
# Creating Child Node With ClassLabel=1, nexamples=769, classes=[(1, 0.9960988296488946), (2, 0.0039011703511053317)]
# Creating Child Node With ClassLabel=2, nexamples=342, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 2756 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 2756 Examples
# Creating Child Node With ClassLabel=0, nexamples=2756, classes=[(0, 0.5849056603773585), (1, 0.41509433962264153)]
# Creating Left Child Node With 3568 Examples, and Right Node with 6169 Examples
# Creating Left Child Node With 2746 Examples, and Right Node with 822 Examples
# Creating Left Child Node With 638 Examples, and Right Node with 2108 Examples
# Creating Child Node With ClassLabel=0, nexamples=638, classes=[(0, 0.5893416927899686), (2, 0.4106583072100313)]
# Creating Child Node With ClassLabel=0, nexamples=2108, classes=[(0, 0.7879506641366224), (2, 0.2120493358633776)]
# Creating Child Node With ClassLabel=2, nexamples=822, classes=[(2, 1.0)]
# Creating Left Child Node With 695 Examples, and Right Node with 5474 Examples
# Creating Left Child Node With 245 Examples, and Right Node with 450 Examples
# Creating Child Node With ClassLabel=1, nexamples=245, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=450, classes=[(0, 1.0)]
# Creating Left Child Node With 4660 Examples, and Right Node with 814 Examples
# Creating Child Node With ClassLabel=2, nexamples=4660, classes=[(2, 0.47124463519313303), (1, 0.4034334763948498), (0, 0.12532188841201716)]
# Creating Child Node With ClassLabel=2, nexamples=814, classes=[(2, 0.8624078624078624), (0, 0.1375921375921376)]
#
# Creating tree # 5
# Creating Left Child Node With 12550 Examples, and Right Node with 1850 Examples
# Creating Left Child Node With 9688 Examples, and Right Node with 2862 Examples
# Creating Left Child Node With 3097 Examples, and Right Node with 6591 Examples
# Creating Left Child Node With 2751 Examples, and Right Node with 346 Examples
# Creating Child Node With ClassLabel=1, nexamples=2751, classes=[(1, 0.9861868411486732), (0, 0.007633587786259542), (2, 0.0061795710650672485)]
# Creating Child Node With ClassLabel=2, nexamples=346, classes=[(2, 0.791907514450867), (0, 0.17052023121387283), (1, 0.03757225433526012)]
# Creating Left Child Node With 1570 Examples, and Right Node with 5021 Examples
# Creating Child Node With ClassLabel=1, nexamples=1570, classes=[(1, 0.9197452229299363), (2, 0.08025477707006369)]
# Creating Child Node With ClassLabel=2, nexamples=5021, classes=[(2, 0.6456881099382593), (0, 0.24975104560844452), (1, 0.10456084445329615)]
# Creating Left Child Node With 144 Examples, and Right Node with 2718 Examples
# Creating Child Node With ClassLabel=2, nexamples=144, classes=[(2, 1.0)]
# Creating Left Child Node With 1676 Examples, and Right Node with 1042 Examples
# Creating Child Node With ClassLabel=0, nexamples=1676, classes=[(0, 0.8550119331742243), (1, 0.08890214797136038), (2, 0.05608591885441527)]
# Creating Child Node With ClassLabel=0, nexamples=1042, classes=[(0, 0.5239923224568138), (2, 0.4760076775431862)]
# Creating Left Child Node With 446 Examples, and Right Node with 1404 Examples
# Creating Left Child Node With 187 Examples, and Right Node with 259 Examples
# Creating Left Child Node With 48 Examples, and Right Node with 139 Examples
# Creating Child Node With ClassLabel=2, nexamples=48, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=139, classes=[(0, 0.9496402877697842), (2, 0.050359712230215826)]
# Creating Child Node With ClassLabel=2, nexamples=259, classes=[(2, 1.0)]
# Creating Left Child Node With 795 Examples, and Right Node with 609 Examples
# Creating Left Child Node With 14 Examples, and Right Node with 781 Examples
# Creating Child Node With ClassLabel=2, nexamples=14, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=781, classes=[(0, 0.9436619718309859), (2, 0.056338028169014086)]
# Creating Child Node With ClassLabel=0, nexamples=609, classes=[(0, 1.0)]
#
# Creating tree # 6
# Creating Left Child Node With 10215 Examples, and Right Node with 4185 Examples
# Creating Left Child Node With 6624 Examples, and Right Node with 3591 Examples
# Creating Left Child Node With 3806 Examples, and Right Node with 2818 Examples
# Creating Left Child Node With 585 Examples, and Right Node with 3221 Examples
# Creating Child Node With ClassLabel=1, nexamples=585, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3221, classes=[(0, 0.7615647314498603), (1, 0.17975783918037877), (2, 0.05867742936976095)]
# Creating Left Child Node With 2720 Examples, and Right Node with 98 Examples
# Creating Child Node With ClassLabel=1, nexamples=2720, classes=[(1, 0.9522058823529411), (2, 0.02977941176470588), (0, 0.01801470588235294)]
# Creating Child Node With ClassLabel=0, nexamples=98, classes=[(0, 1.0)]
# Creating Left Child Node With 3078 Examples, and Right Node with 513 Examples
# Creating Left Child Node With 594 Examples, and Right Node with 2484 Examples
# Creating Child Node With ClassLabel=1, nexamples=594, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2484, classes=[(2, 0.857085346215781), (1, 0.1320450885668277), (0, 0.010869565217391304)]
# Creating Left Child Node With 458 Examples, and Right Node with 55 Examples
# Creating Child Node With ClassLabel=0, nexamples=458, classes=[(0, 0.7794759825327511), (1, 0.1965065502183406), (2, 0.024017467248908297)]
# Creating Child Node With ClassLabel=2, nexamples=55, classes=[(2, 1.0)]
# Creating Left Child Node With 2154 Examples, and Right Node with 2031 Examples
# Creating Left Child Node With 709 Examples, and Right Node with 1445 Examples
# Creating Left Child Node With 283 Examples, and Right Node with 426 Examples
# Creating Child Node With ClassLabel=2, nexamples=283, classes=[(2, 0.9964664310954063), (0, 0.0035335689045936395)]
# Creating Child Node With ClassLabel=0, nexamples=426, classes=[(0, 1.0)]
# Creating Left Child Node With 1197 Examples, and Right Node with 248 Examples
# Creating Child Node With ClassLabel=0, nexamples=1197, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=248, classes=[(0, 0.9153225806451613), (2, 0.0846774193548387)]
# Creating Left Child Node With 1987 Examples, and Right Node with 44 Examples
# Creating Child Node With ClassLabel=2, nexamples=1987, classes=[(2, 1.0)]
# Creating Left Child Node With 31 Examples, and Right Node with 13 Examples
# Creating Child Node With ClassLabel=2, nexamples=31, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=13, classes=[(1, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 11569 Examples, and Right Node with 2831 Examples
# Creating Left Child Node With 1533 Examples, and Right Node with 10036 Examples
# Creating Left Child Node With 383 Examples, and Right Node with 1150 Examples
# Creating Left Child Node With 274 Examples, and Right Node with 109 Examples
# Creating Child Node With ClassLabel=1, nexamples=274, classes=[(1, 0.9124087591240876), (2, 0.08759124087591241)]
# Creating Child Node With ClassLabel=0, nexamples=109, classes=[(0, 0.9357798165137615), (1, 0.06422018348623854)]
# Creating Left Child Node With 48 Examples, and Right Node with 1102 Examples
# Creating Child Node With ClassLabel=2, nexamples=48, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1102, classes=[(1, 1.0)]
# Creating Left Child Node With 1552 Examples, and Right Node with 8484 Examples
# Creating Left Child Node With 801 Examples, and Right Node with 751 Examples
# Creating Child Node With ClassLabel=0, nexamples=801, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=751, classes=[(1, 0.9680426098535286), (0, 0.03195739014647137)]
# Creating Left Child Node With 6673 Examples, and Right Node with 1811 Examples
# Creating Child Node With ClassLabel=0, nexamples=6673, classes=[(0, 0.5881912183425746), (2, 0.39547429941555523), (1, 0.016334482241870223)]
# Creating Child Node With ClassLabel=2, nexamples=1811, classes=[(2, 0.6946438431805633), (1, 0.2909994478188846), (0, 0.01435670900055218)]
# Creating Left Child Node With 791 Examples, and Right Node with 2040 Examples
# Creating Child Node With ClassLabel=2, nexamples=791, classes=[(2, 1.0)]
# Creating Left Child Node With 1998 Examples, and Right Node with 42 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 1996 Examples
# Creating Child Node With ClassLabel=2, nexamples=2, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1996, classes=[(1, 1.0)]
# Creating Left Child Node With 41 Examples, and Right Node with 1 Examples
# Creating Child Node With ClassLabel=2, nexamples=41, classes=[(2, 0.8048780487804879), (1, 0.1951219512195122)]
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 10559 Examples, and Right Node with 3841 Examples
# Creating Left Child Node With 3177 Examples, and Right Node with 7382 Examples
# Creating Left Child Node With 2505 Examples, and Right Node with 672 Examples
# Creating Left Child Node With 307 Examples, and Right Node with 2198 Examples
# Creating Child Node With ClassLabel=1, nexamples=307, classes=[(1, 0.9120521172638436), (2, 0.08794788273615635)]
# Creating Child Node With ClassLabel=1, nexamples=2198, classes=[(1, 0.935395814376706), (0, 0.0646041856232939)]
# Creating Left Child Node With 367 Examples, and Right Node with 305 Examples
# Creating Child Node With ClassLabel=2, nexamples=367, classes=[(2, 0.8119891008174387), (1, 0.1880108991825613)]
# Creating Child Node With ClassLabel=1, nexamples=305, classes=[(1, 1.0)]
# Creating Left Child Node With 3810 Examples, and Right Node with 3572 Examples
# Creating Left Child Node With 2690 Examples, and Right Node with 1120 Examples
# Creating Child Node With ClassLabel=2, nexamples=2690, classes=[(2, 0.737546468401487), (0, 0.2620817843866171), (1, 0.0003717472118959108)]
# Creating Child Node With ClassLabel=0, nexamples=1120, classes=[(0, 0.8625), (1, 0.12946428571428573), (2, 0.008035714285714285)]
# Creating Left Child Node With 1846 Examples, and Right Node with 1726 Examples
# Creating Child Node With ClassLabel=0, nexamples=1846, classes=[(0, 0.7036836403033586), (2, 0.2551462621885157), (1, 0.041170097508125676)]
# Creating Child Node With ClassLabel=1, nexamples=1726, classes=[(1, 0.9982618771726536), (0, 0.0011587485515643105), (2, 0.0005793742757821553)]
# Creating Left Child Node With 2905 Examples, and Right Node with 936 Examples
# Creating Left Child Node With 2459 Examples, and Right Node with 446 Examples
# Creating Left Child Node With 2245 Examples, and Right Node with 214 Examples
# Creating Child Node With ClassLabel=0, nexamples=2245, classes=[(0, 0.7527839643652561), (2, 0.24721603563474387)]
# Creating Child Node With ClassLabel=2, nexamples=214, classes=[(2, 0.9719626168224299), (1, 0.028037383177570093)]
# Creating Left Child Node With 11 Examples, and Right Node with 435 Examples
# Creating Child Node With ClassLabel=0, nexamples=11, classes=[(0, 0.5454545454545454), (2, 0.45454545454545453)]
# Creating Child Node With ClassLabel=2, nexamples=435, classes=[(2, 1.0)]
# Creating Left Child Node With 456 Examples, and Right Node with 480 Examples
# Creating Child Node With ClassLabel=2, nexamples=456, classes=[(2, 1.0)]
# Creating Left Child Node With 394 Examples, and Right Node with 86 Examples
# Creating Child Node With ClassLabel=2, nexamples=394, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=86, classes=[(1, 1.0)]
#
# Creating tree # 9
# Creating Left Child Node With 12463 Examples, and Right Node with 1937 Examples
# Creating Left Child Node With 5709 Examples, and Right Node with 6754 Examples
# Creating Left Child Node With 1934 Examples, and Right Node with 3775 Examples
# Creating Left Child Node With 180 Examples, and Right Node with 1754 Examples
# Creating Child Node With ClassLabel=1, nexamples=180, classes=[(1, 0.9166666666666666), (0, 0.08333333333333333)]
# Creating Child Node With ClassLabel=2, nexamples=1754, classes=[(2, 0.9503990877993158), (0, 0.049600912200684154)]
# Creating Left Child Node With 3366 Examples, and Right Node with 409 Examples
# Creating Child Node With ClassLabel=0, nexamples=3366, classes=[(0, 0.9884135472370766), (2, 0.0112893642305407), (1, 0.00029708853238265005)]
# Creating Child Node With ClassLabel=0, nexamples=409, classes=[(0, 0.6014669926650367), (1, 0.3765281173594132), (2, 0.022004889975550123)]
# Creating Left Child Node With 3096 Examples, and Right Node with 3658 Examples
# Creating Left Child Node With 1059 Examples, and Right Node with 2037 Examples
# Creating Child Node With ClassLabel=1, nexamples=1059, classes=[(1, 0.7025495750708215), (2, 0.295561850802644), (0, 0.0018885741265344666)]
# Creating Child Node With ClassLabel=2, nexamples=2037, classes=[(2, 0.9513991163475699), (1, 0.048109965635738834), (0, 0.0004909180166912126)]
# Creating Left Child Node With 1860 Examples, and Right Node with 1798 Examples
# Creating Child Node With ClassLabel=0, nexamples=1860, classes=[(0, 0.5650537634408602), (2, 0.3924731182795699), (1, 0.04247311827956989)]
# Creating Child Node With ClassLabel=1, nexamples=1798, classes=[(1, 0.92880978865406), (2, 0.07119021134593993)]
# Creating Left Child Node With 85 Examples, and Right Node with 1852 Examples
# Creating Child Node With ClassLabel=0, nexamples=85, classes=[(0, 1.0)]
# Creating Left Child Node With 646 Examples, and Right Node with 1206 Examples
# Creating Left Child Node With 42 Examples, and Right Node with 604 Examples
# Creating Child Node With ClassLabel=1, nexamples=42, classes=[(1, 0.5476190476190477), (0, 0.4523809523809524)]
# Creating Child Node With ClassLabel=1, nexamples=604, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1206 Examples
# Creating Child Node With ClassLabel=1, nexamples=1206, classes=[(1, 0.9975124378109452), (0, 0.0024875621890547263)]
#
# Creating tree # 10
# Creating Left Child Node With 11216 Examples, and Right Node with 3184 Examples
# Creating Left Child Node With 8149 Examples, and Right Node with 3067 Examples
# Creating Left Child Node With 6809 Examples, and Right Node with 1340 Examples
# Creating Left Child Node With 5302 Examples, and Right Node with 1507 Examples
# Creating Child Node With ClassLabel=1, nexamples=5302, classes=[(1, 0.8081855903432666), (2, 0.16710675216899284), (0, 0.024707657487740474)]
# Creating Child Node With ClassLabel=2, nexamples=1507, classes=[(2, 0.7352355673523556), (1, 0.2276045122760451), (0, 0.0371599203715992)]
# Creating Left Child Node With 1288 Examples, and Right Node with 52 Examples
# Creating Child Node With ClassLabel=0, nexamples=1288, classes=[(0, 0.9208074534161491), (1, 0.059006211180124224), (2, 0.020186335403726708)]
# Creating Child Node With ClassLabel=1, nexamples=52, classes=[(1, 0.9423076923076923), (0, 0.057692307692307696)]
# Creating Left Child Node With 1456 Examples, and Right Node with 1611 Examples
# Creating Left Child Node With 362 Examples, and Right Node with 1094 Examples
# Creating Child Node With ClassLabel=0, nexamples=362, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1094, classes=[(0, 0.9844606946983546), (2, 0.015539305301645339)]
# Creating Left Child Node With 1091 Examples, and Right Node with 520 Examples
# Creating Child Node With ClassLabel=2, nexamples=1091, classes=[(2, 0.9734188817598534), (0, 0.026581118240146653)]
# Creating Child Node With ClassLabel=0, nexamples=520, classes=[(0, 0.6173076923076923), (2, 0.38269230769230766)]
# Creating Left Child Node With 2382 Examples, and Right Node with 802 Examples
# Creating Left Child Node With 402 Examples, and Right Node with 1980 Examples
# Creating Child Node With ClassLabel=0, nexamples=402, classes=[(0, 1.0)]
# Creating Left Child Node With 982 Examples, and Right Node with 998 Examples
# Creating Child Node With ClassLabel=2, nexamples=982, classes=[(2, 0.5529531568228105), (0, 0.4470468431771894)]
# Creating Child Node With ClassLabel=2, nexamples=998, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=802, classes=[(0, 1.0)]
#
# Creating tree # 11
# Creating Left Child Node With 10587 Examples, and Right Node with 3813 Examples
# Creating Left Child Node With 7200 Examples, and Right Node with 3387 Examples
# Creating Left Child Node With 2284 Examples, and Right Node with 4916 Examples
# Creating Left Child Node With 2163 Examples, and Right Node with 121 Examples
# Creating Child Node With ClassLabel=0, nexamples=2163, classes=[(0, 0.9893666204345816), (2, 0.009708737864077669), (1, 0.0009246417013407304)]
# Creating Child Node With ClassLabel=1, nexamples=121, classes=[(1, 1.0)]
# Creating Left Child Node With 3638 Examples, and Right Node with 1278 Examples
# Creating Child Node With ClassLabel=2, nexamples=3638, classes=[(2, 0.740241891148983), (0, 0.19268829026937878), (1, 0.06706981858163827)]
# Creating Child Node With ClassLabel=0, nexamples=1278, classes=[(0, 0.9882629107981221), (1, 0.010954616588419406), (2, 0.000782472613458529)]
# Creating Left Child Node With 2131 Examples, and Right Node with 1256 Examples
# Creating Left Child Node With 1040 Examples, and Right Node with 1091 Examples
# Creating Child Node With ClassLabel=1, nexamples=1040, classes=[(1, 0.9961538461538462), (2, 0.0038461538461538464)]
# Creating Child Node With ClassLabel=1, nexamples=1091, classes=[(1, 0.7259395050412466), (2, 0.27406049495875345)]
# Creating Left Child Node With 680 Examples, and Right Node with 576 Examples
# Creating Child Node With ClassLabel=1, nexamples=680, classes=[(1, 0.8235294117647058), (0, 0.175), (2, 0.0014705882352941176)]
# Creating Child Node With ClassLabel=0, nexamples=576, classes=[(0, 0.9270833333333334), (2, 0.07291666666666667)]
# Creating Left Child Node With 1743 Examples, and Right Node with 2070 Examples
# Creating Child Node With ClassLabel=1, nexamples=1743, classes=[(1, 1.0)]
# Creating Left Child Node With 267 Examples, and Right Node with 1803 Examples
# Creating Child Node With ClassLabel=1, nexamples=267, classes=[(1, 1.0)]
# Creating Left Child Node With 753 Examples, and Right Node with 1050 Examples
# Creating Child Node With ClassLabel=2, nexamples=753, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1050, classes=[(2, 0.9676190476190476), (0, 0.03238095238095238)]
#
# Creating tree # 12
# Creating Left Child Node With 6976 Examples, and Right Node with 7424 Examples
# Creating Left Child Node With 3807 Examples, and Right Node with 3169 Examples
# Creating Left Child Node With 2576 Examples, and Right Node with 1231 Examples
# Creating Left Child Node With 1567 Examples, and Right Node with 1009 Examples
# Creating Child Node With ClassLabel=0, nexamples=1567, classes=[(0, 0.7594128908742821), (2, 0.13529036375239312), (1, 0.10529674537332483)]
# Creating Child Node With ClassLabel=1, nexamples=1009, classes=[(1, 0.688800792864222), (0, 0.311199207135778)]
# Creating Child Node With ClassLabel=1, nexamples=1231, classes=[(1, 1.0)]
# Creating Left Child Node With 834 Examples, and Right Node with 2335 Examples
# Creating Left Child Node With 834 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=834, classes=[(2, 0.9976019184652278), (0, 0.001199040767386091), (1, 0.001199040767386091)]
# Creating Left Child Node With 1670 Examples, and Right Node with 665 Examples
# Creating Child Node With ClassLabel=1, nexamples=1670, classes=[(1, 0.9994011976047904), (2, 0.0005988023952095808)]
# Creating Child Node With ClassLabel=2, nexamples=665, classes=[(2, 0.9458646616541353), (1, 0.05413533834586466)]
# Creating Left Child Node With 3468 Examples, and Right Node with 3956 Examples
# Creating Left Child Node With 1758 Examples, and Right Node with 1710 Examples
# Creating Left Child Node With 1296 Examples, and Right Node with 462 Examples
# Creating Child Node With ClassLabel=1, nexamples=1296, classes=[(1, 0.7160493827160493), (0, 0.2839506172839506)]
# Creating Child Node With ClassLabel=0, nexamples=462, classes=[(0, 1.0)]
# Creating Left Child Node With 1685 Examples, and Right Node with 25 Examples
# Creating Child Node With ClassLabel=0, nexamples=1685, classes=[(0, 0.9994065281899109), (2, 0.0005934718100890207)]
# Creating Child Node With ClassLabel=2, nexamples=25, classes=[(2, 1.0)]
# Creating Left Child Node With 2588 Examples, and Right Node with 1368 Examples
# Creating Left Child Node With 2513 Examples, and Right Node with 75 Examples
# Creating Child Node With ClassLabel=2, nexamples=2513, classes=[(2, 0.6717071229606049), (0, 0.32829287703939514)]
# Creating Child Node With ClassLabel=2, nexamples=75, classes=[(2, 1.0)]
# Creating Left Child Node With 1368 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=1368, classes=[(2, 0.9568713450292398), (1, 0.04312865497076023)]
#
# Creating tree # 13
# Creating Left Child Node With 11019 Examples, and Right Node with 3381 Examples
# Creating Left Child Node With 4787 Examples, and Right Node with 6232 Examples
# Creating Left Child Node With 4548 Examples, and Right Node with 239 Examples
# Creating Left Child Node With 3268 Examples, and Right Node with 1280 Examples
# Creating Child Node With ClassLabel=1, nexamples=3268, classes=[(1, 0.5085679314565483), (0, 0.4868421052631579), (2, 0.004589963280293758)]
# Creating Child Node With ClassLabel=0, nexamples=1280, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=239, classes=[(2, 1.0)]
# Creating Left Child Node With 4583 Examples, and Right Node with 1649 Examples
# Creating Left Child Node With 2800 Examples, and Right Node with 1783 Examples
# Creating Child Node With ClassLabel=0, nexamples=2800, classes=[(0, 0.6610714285714285), (2, 0.29035714285714287), (1, 0.04857142857142857)]
# Creating Child Node With ClassLabel=2, nexamples=1783, classes=[(2, 0.9943914750420639), (0, 0.005608524957936063)]
# Creating Left Child Node With 671 Examples, and Right Node with 978 Examples
# Creating Child Node With ClassLabel=2, nexamples=671, classes=[(2, 0.8971684053651267), (0, 0.10283159463487332)]
# Creating Child Node With ClassLabel=1, nexamples=978, classes=[(1, 1.0)]
# Creating Left Child Node With 2182 Examples, and Right Node with 1199 Examples
# Creating Left Child Node With 146 Examples, and Right Node with 2036 Examples
# Creating Left Child Node With 13 Examples, and Right Node with 133 Examples
# Creating Child Node With ClassLabel=1, nexamples=13, classes=[(1, 0.9230769230769231), (2, 0.07692307692307693)]
# Creating Child Node With ClassLabel=2, nexamples=133, classes=[(2, 1.0)]
# Creating Left Child Node With 1922 Examples, and Right Node with 114 Examples
# Creating Child Node With ClassLabel=1, nexamples=1922, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=114, classes=[(1, 0.9912280701754386), (2, 0.008771929824561403)]
# Creating Left Child Node With 5 Examples, and Right Node with 1194 Examples
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1194, classes=[(2, 1.0)]
#
# Creating tree # 14
# Creating Left Child Node With 3438 Examples, and Right Node with 10962 Examples
# Creating Left Child Node With 2125 Examples, and Right Node with 1313 Examples
# Creating Left Child Node With 1127 Examples, and Right Node with 998 Examples
# Creating Left Child Node With 970 Examples, and Right Node with 157 Examples
# Creating Child Node With ClassLabel=0, nexamples=970, classes=[(0, 0.9927835051546392), (2, 0.007216494845360825)]
# Creating Child Node With ClassLabel=2, nexamples=157, classes=[(2, 0.9872611464968153), (0, 0.012738853503184714)]
# Creating Child Node With ClassLabel=2, nexamples=998, classes=[(2, 1.0)]
# Creating Left Child Node With 1311 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=2, nexamples=1311, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=2, classes=[(1, 1.0)]
# Creating Left Child Node With 9059 Examples, and Right Node with 1903 Examples
# Creating Left Child Node With 7199 Examples, and Right Node with 1860 Examples
# Creating Left Child Node With 5394 Examples, and Right Node with 1805 Examples
# Creating Child Node With ClassLabel=0, nexamples=5394, classes=[(0, 0.5413422321097516), (2, 0.24416017797552836), (1, 0.21449758991472007)]
# Creating Child Node With ClassLabel=1, nexamples=1805, classes=[(1, 0.9761772853185595), (2, 0.023822714681440444)]
# Creating Left Child Node With 1854 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=1, nexamples=1854, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=6, classes=[(2, 1.0)]
# Creating Left Child Node With 792 Examples, and Right Node with 1111 Examples
# Creating Child Node With ClassLabel=2, nexamples=792, classes=[(2, 1.0)]
# Creating Left Child Node With 231 Examples, and Right Node with 880 Examples
# Creating Child Node With ClassLabel=0, nexamples=231, classes=[(0, 0.9523809523809523), (2, 0.047619047619047616)]
# Creating Child Node With ClassLabel=0, nexamples=880, classes=[(0, 0.8147727272727273), (2, 0.18522727272727274)]
#
# Creating tree # 15
# Creating Left Child Node With 10071 Examples, and Right Node with 4329 Examples
# Creating Left Child Node With 6056 Examples, and Right Node with 4015 Examples
# Creating Left Child Node With 4872 Examples, and Right Node with 1184 Examples
# Creating Left Child Node With 1895 Examples, and Right Node with 2977 Examples
# Creating Child Node With ClassLabel=0, nexamples=1895, classes=[(0, 0.8928759894459103), (1, 0.10712401055408971)]
# Creating Child Node With ClassLabel=1, nexamples=2977, classes=[(1, 0.9724554921061471), (0, 0.02720859926100101), (2, 0.0003359086328518643)]
# Creating Left Child Node With 647 Examples, and Right Node with 537 Examples
# Creating Child Node With ClassLabel=1, nexamples=647, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=537, classes=[(2, 0.9553072625698324), (0, 0.035381750465549346), (1, 0.00931098696461825)]
# Creating Left Child Node With 1948 Examples, and Right Node with 2067 Examples
# Creating Left Child Node With 1252 Examples, and Right Node with 696 Examples
# Creating Child Node With ClassLabel=0, nexamples=1252, classes=[(0, 0.6373801916932907), (2, 0.2963258785942492), (1, 0.06629392971246006)]
# Creating Child Node With ClassLabel=1, nexamples=696, classes=[(1, 0.9971264367816092), (0, 0.0028735632183908046)]
# Creating Left Child Node With 1967 Examples, and Right Node with 100 Examples
# Creating Child Node With ClassLabel=2, nexamples=1967, classes=[(2, 0.8652770716827657), (1, 0.13116420945602442), (0, 0.0035587188612099642)]
# Creating Child Node With ClassLabel=0, nexamples=100, classes=[(0, 0.89), (2, 0.11)]
# Creating Left Child Node With 1183 Examples, and Right Node with 3146 Examples
# Creating Left Child Node With 1183 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 277 Examples, and Right Node with 906 Examples
# Creating Child Node With ClassLabel=2, nexamples=277, classes=[(2, 0.9747292418772563), (0, 0.02527075812274368)]
# Creating Child Node With ClassLabel=2, nexamples=906, classes=[(2, 1.0)]
# Creating Left Child Node With 2648 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 1243 Examples, and Right Node with 1405 Examples
# Creating Child Node With ClassLabel=0, nexamples=1243, classes=[(0, 0.6154465004022526), (2, 0.3563958165728077), (1, 0.02815768302493966)]
# Creating Child Node With ClassLabel=0, nexamples=1405, classes=[(0, 0.9693950177935943), (2, 0.0298932384341637), (1, 0.0007117437722419929)]
# Creating Left Child Node With 466 Examples, and Right Node with 32 Examples
# Creating Child Node With ClassLabel=2, nexamples=466, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=32, classes=[(0, 1.0)]
#
# Creating tree # 16
# Creating Left Child Node With 7729 Examples, and Right Node with 6671 Examples
# Creating Left Child Node With 1974 Examples, and Right Node with 5755 Examples
# Creating Left Child Node With 154 Examples, and Right Node with 1820 Examples
# Creating Child Node With ClassLabel=2, nexamples=154, classes=[(2, 1.0)]
# Creating Left Child Node With 847 Examples, and Right Node with 973 Examples
# Creating Child Node With ClassLabel=0, nexamples=847, classes=[(0, 0.987012987012987), (1, 0.012987012987012988)]
# Creating Child Node With ClassLabel=0, nexamples=973, classes=[(0, 0.9938335046248715), (2, 0.006166495375128468)]
# Creating Left Child Node With 531 Examples, and Right Node with 5224 Examples
# Creating Child Node With ClassLabel=1, nexamples=531, classes=[(1, 1.0)]
# Creating Left Child Node With 3253 Examples, and Right Node with 1971 Examples
# Creating Child Node With ClassLabel=2, nexamples=3253, classes=[(2, 0.9794036274208423), (1, 0.020288964033200123), (0, 0.0003074085459575776)]
# Creating Child Node With ClassLabel=2, nexamples=1971, classes=[(2, 0.36580416032470825), (0, 0.32470826991374935), (1, 0.30948756976154235)]
# Creating Left Child Node With 3029 Examples, and Right Node with 3642 Examples
# Creating Left Child Node With 2557 Examples, and Right Node with 472 Examples
# Creating Left Child Node With 21 Examples, and Right Node with 2536 Examples
# Creating Child Node With ClassLabel=2, nexamples=21, classes=[(2, 0.9523809523809523), (1, 0.047619047619047616)]
# Creating Child Node With ClassLabel=1, nexamples=2536, classes=[(1, 0.9589905362776026), (0, 0.04100946372239748)]
# Creating Left Child Node With 112 Examples, and Right Node with 360 Examples
# Creating Child Node With ClassLabel=1, nexamples=112, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=360, classes=[(2, 1.0)]
# Creating Left Child Node With 3120 Examples, and Right Node with 522 Examples
# Creating Left Child Node With 1924 Examples, and Right Node with 1196 Examples
# Creating Child Node With ClassLabel=0, nexamples=1924, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1196, classes=[(1, 0.41638795986622074), (0, 0.3202341137123746), (2, 0.2633779264214047)]
# Creating Child Node With ClassLabel=1, nexamples=522, classes=[(1, 1.0)]
#
# Creating tree # 17
# Creating Left Child Node With 11408 Examples, and Right Node with 2992 Examples
# Creating Left Child Node With 5710 Examples, and Right Node with 5698 Examples
# Creating Left Child Node With 4764 Examples, and Right Node with 946 Examples
# Creating Left Child Node With 3657 Examples, and Right Node with 1107 Examples
# Creating Child Node With ClassLabel=1, nexamples=3657, classes=[(1, 0.9857806945583811), (2, 0.014219305441618812)]
# Creating Child Node With ClassLabel=2, nexamples=1107, classes=[(2, 0.8879855465221319), (1, 0.1120144534778681)]
# Creating Left Child Node With 98 Examples, and Right Node with 848 Examples
# Creating Child Node With ClassLabel=0, nexamples=98, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=848, classes=[(2, 0.9893867924528302), (0, 0.01061320754716981)]
# Creating Left Child Node With 4477 Examples, and Right Node with 1221 Examples
# Creating Left Child Node With 2123 Examples, and Right Node with 2354 Examples
# Creating Child Node With ClassLabel=0, nexamples=2123, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2354, classes=[(2, 0.4872557349192863), (0, 0.451571792693288), (1, 0.06117247238742566)]
# Creating Left Child Node With 396 Examples, and Right Node with 825 Examples
# Creating Child Node With ClassLabel=0, nexamples=396, classes=[(0, 0.8459595959595959), (2, 0.15404040404040403)]
# Creating Child Node With ClassLabel=1, nexamples=825, classes=[(1, 1.0)]
# Creating Left Child Node With 2079 Examples, and Right Node with 913 Examples
# Creating Left Child Node With 366 Examples, and Right Node with 1713 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 365 Examples
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=365, classes=[(0, 1.0)]
# Creating Left Child Node With 1624 Examples, and Right Node with 89 Examples
# Creating Child Node With ClassLabel=2, nexamples=1624, classes=[(2, 0.999384236453202), (0, 0.0006157635467980296)]
# Creating Child Node With ClassLabel=1, nexamples=89, classes=[(1, 1.0)]
# Creating Left Child Node With 309 Examples, and Right Node with 604 Examples
# Creating Child Node With ClassLabel=0, nexamples=309, classes=[(0, 1.0)]
# Creating Left Child Node With 251 Examples, and Right Node with 353 Examples
# Creating Child Node With ClassLabel=0, nexamples=251, classes=[(0, 0.7051792828685259), (2, 0.2948207171314741)]
# Creating Child Node With ClassLabel=0, nexamples=353, classes=[(0, 1.0)]
#
# Creating tree # 18
# Creating Left Child Node With 3483 Examples, and Right Node with 10917 Examples
# Creating Left Child Node With 1728 Examples, and Right Node with 1755 Examples
# Creating Left Child Node With 1726 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=0, nexamples=1726, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2, classes=[(0, 0.5), (2, 0.5)]
# Creating Left Child Node With 232 Examples, and Right Node with 1523 Examples
# Creating Left Child Node With 68 Examples, and Right Node with 164 Examples
# Creating Child Node With ClassLabel=0, nexamples=68, classes=[(0, 0.9117647058823529), (2, 0.08823529411764706)]
# Creating Child Node With ClassLabel=0, nexamples=164, classes=[(0, 1.0)]
# Creating Left Child Node With 1439 Examples, and Right Node with 84 Examples
# Creating Child Node With ClassLabel=1, nexamples=1439, classes=[(1, 0.9993050729673384), (0, 0.0006949270326615705)]
# Creating Child Node With ClassLabel=1, nexamples=84, classes=[(1, 0.8809523809523809), (0, 0.11904761904761904)]
# Creating Left Child Node With 7578 Examples, and Right Node with 3339 Examples
# Creating Left Child Node With 5230 Examples, and Right Node with 2348 Examples
# Creating Left Child Node With 4588 Examples, and Right Node with 642 Examples
# Creating Child Node With ClassLabel=0, nexamples=4588, classes=[(0, 0.6224934612031386), (2, 0.35091543156059285), (1, 0.02659110723626853)]
# Creating Child Node With ClassLabel=1, nexamples=642, classes=[(1, 1.0)]
# Creating Left Child Node With 1771 Examples, and Right Node with 577 Examples
# Creating Child Node With ClassLabel=1, nexamples=1771, classes=[(1, 0.9881422924901185), (2, 0.011857707509881422)]
# Creating Child Node With ClassLabel=2, nexamples=577, classes=[(2, 1.0)]
# Creating Left Child Node With 1657 Examples, and Right Node with 1682 Examples
# Creating Left Child Node With 369 Examples, and Right Node with 1288 Examples
# Creating Child Node With ClassLabel=2, nexamples=369, classes=[(2, 0.9186991869918699), (0, 0.08130081300813008)]
# Creating Child Node With ClassLabel=2, nexamples=1288, classes=[(2, 1.0)]
# Creating Left Child Node With 725 Examples, and Right Node with 957 Examples
# Creating Child Node With ClassLabel=1, nexamples=725, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=957, classes=[(2, 1.0)]
#
# Creating tree # 19
# Creating Left Child Node With 3106 Examples, and Right Node with 11294 Examples
# Creating Left Child Node With 1442 Examples, and Right Node with 1664 Examples
# Creating Left Child Node With 673 Examples, and Right Node with 769 Examples
# Creating Child Node With ClassLabel=0, nexamples=673, classes=[(0, 1.0)]
# Creating Left Child Node With 628 Examples, and Right Node with 141 Examples
# Creating Child Node With ClassLabel=1, nexamples=628, classes=[(1, 0.821656050955414), (0, 0.17197452229299362), (2, 0.006369426751592357)]
# Creating Child Node With ClassLabel=0, nexamples=141, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1664, classes=[(1, 1.0)]
# Creating Left Child Node With 6542 Examples, and Right Node with 4752 Examples
# Creating Left Child Node With 5344 Examples, and Right Node with 1198 Examples
# Creating Left Child Node With 2341 Examples, and Right Node with 3003 Examples
# Creating Child Node With ClassLabel=0, nexamples=2341, classes=[(0, 0.8868005126014523), (2, 0.11319948739854763)]
# Creating Child Node With ClassLabel=2, nexamples=3003, classes=[(2, 0.7335997335997336), (0, 0.24342324342324342), (1, 0.022977022977022976)]
# Creating Left Child Node With 58 Examples, and Right Node with 1140 Examples
# Creating Child Node With ClassLabel=0, nexamples=58, classes=[(0, 0.6206896551724138), (2, 0.3793103448275862)]
# Creating Child Node With ClassLabel=2, nexamples=1140, classes=[(2, 1.0)]
# Creating Left Child Node With 1246 Examples, and Right Node with 3506 Examples
# Creating Left Child Node With 963 Examples, and Right Node with 283 Examples
# Creating Child Node With ClassLabel=0, nexamples=963, classes=[(0, 0.6043613707165109), (2, 0.3956386292834891)]
# Creating Child Node With ClassLabel=2, nexamples=283, classes=[(2, 1.0)]
# Creating Left Child Node With 2526 Examples, and Right Node with 980 Examples
# Creating Child Node With ClassLabel=1, nexamples=2526, classes=[(1, 0.836104513064133), (0, 0.16270783847980996), (2, 0.0011876484560570072)]
# Creating Child Node With ClassLabel=2, nexamples=980, classes=[(2, 0.5316326530612245), (1, 0.4683673469387755)]
#
# Creating tree # 20
# Creating Left Child Node With 2067 Examples, and Right Node with 12333 Examples
# Creating Left Child Node With 1738 Examples, and Right Node with 329 Examples
# Creating Left Child Node With 1680 Examples, and Right Node with 58 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1680 Examples
# Creating Child Node With ClassLabel=1, nexamples=1680, classes=[(1, 0.9994047619047619), (2, 0.0005952380952380953)]
# Creating Left Child Node With 51 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=1, nexamples=51, classes=[(1, 0.6862745098039216), (2, 0.3137254901960784)]
# Creating Child Node With ClassLabel=1, nexamples=7, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=329, classes=[(2, 1.0)]
# Creating Left Child Node With 5957 Examples, and Right Node with 6376 Examples
# Creating Left Child Node With 1703 Examples, and Right Node with 4254 Examples
# Creating Child Node With ClassLabel=1, nexamples=1703, classes=[(1, 1.0)]
# Creating Left Child Node With 1066 Examples, and Right Node with 3188 Examples
# Creating Child Node With ClassLabel=2, nexamples=1066, classes=[(2, 0.5787992495309568), (1, 0.25422138836772984), (0, 0.1669793621013133)]
# Creating Child Node With ClassLabel=0, nexamples=3188, classes=[(0, 0.6094730238393977), (1, 0.27007528230865746), (2, 0.12045169385194479)]
# Creating Left Child Node With 709 Examples, and Right Node with 5667 Examples
# Creating Left Child Node With 573 Examples, and Right Node with 136 Examples
# Creating Child Node With ClassLabel=0, nexamples=573, classes=[(0, 0.7486910994764397), (1, 0.2513089005235602)]
# Creating Child Node With ClassLabel=1, nexamples=136, classes=[(1, 1.0)]
# Creating Left Child Node With 2223 Examples, and Right Node with 3444 Examples
# Creating Child Node With ClassLabel=0, nexamples=2223, classes=[(0, 0.9154295996401259), (2, 0.08457040035987404)]
# Creating Child Node With ClassLabel=2, nexamples=3444, classes=[(2, 0.9503484320557491), (0, 0.04732868757259001), (1, 0.0023228803716608595)]
#
# Creating tree # 21
# Creating Left Child Node With 3269 Examples, and Right Node with 11131 Examples
# Creating Left Child Node With 1788 Examples, and Right Node with 1481 Examples
# Creating Left Child Node With 1717 Examples, and Right Node with 71 Examples
# ...
# Creating Left Child Node With 6125 Examples, and Right Node with 4811 Examples
# Creating Left Child Node With 593 Examples, and Right Node with 5532 Examples
# Creating Left Child Node With 469 Examples, and Right Node with 124 Examples
# Creating Child Node With ClassLabel=0, nexamples=469, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=124, classes=[(1, 1.0)]
# Creating Left Child Node With 1856 Examples, and Right Node with 3676 Examples
# Creating Child Node With ClassLabel=2, nexamples=1856, classes=[(2, 0.796875), (1, 0.18857758620689655), (0, 0.014547413793103448)]
# Creating Child Node With ClassLabel=1, nexamples=3676, classes=[(1, 0.9515778019586507), (2, 0.03509249183895539), (0, 0.013329706202393906)]
# Creating Left Child Node With 4097 Examples, and Right Node with 714 Examples
# Creating Left Child Node With 822 Examples, and Right Node with 3275 Examples
# Creating Child Node With ClassLabel=0, nexamples=822, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3275, classes=[(0, 0.5126717557251909), (2, 0.46045801526717556), (1, 0.026870229007633587)]
# Creating Child Node With ClassLabel=1, nexamples=714, classes=[(1, 1.0)]
# Creating Left Child Node With 1924 Examples, and Right Node with 1540 Examples
# Creating Left Child Node With 1666 Examples, and Right Node with 258 Examples
# Creating Left Child Node With 1567 Examples, and Right Node with 99 Examples
# Creating Child Node With ClassLabel=0, nexamples=1567, classes=[(0, 0.8302488832163369), (2, 0.16975111678366306)]
# Creating Child Node With ClassLabel=2, nexamples=99, classes=[(2, 0.9797979797979798), (0, 0.020202020202020204)]
# Creating Left Child Node With 202 Examples, and Right Node with 56 Examples
# Creating Child Node With ClassLabel=2, nexamples=202, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=56, classes=[(1, 0.9821428571428571), (2, 0.017857142857142856)]
# Creating Left Child Node With 201 Examples, and Right Node with 1339 Examples
# Creating Child Node With ClassLabel=0, nexamples=201, classes=[(0, 1.0)]
# Creating Left Child Node With 1044 Examples, and Right Node with 295 Examples
# Creating Child Node With ClassLabel=2, nexamples=1044, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=295, classes=[(0, 0.8271186440677966), (2, 0.17288135593220338)]
#
# Creating tree # 23
# Creating Left Child Node With 12180 Examples, and Right Node with 2220 Examples
# Creating Left Child Node With 4607 Examples, and Right Node with 7573 Examples
# Creating Left Child Node With 1364 Examples, and Right Node with 3243 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1364 Examples
# Creating Child Node With ClassLabel=0, nexamples=1364, classes=[(0, 0.9479472140762464), (1, 0.05205278592375367)]
# Creating Left Child Node With 1472 Examples, and Right Node with 1771 Examples
# Creating Child Node With ClassLabel=0, nexamples=1472, classes=[(0, 0.6827445652173914), (1, 0.3172554347826087)]
# Creating Child Node With ClassLabel=1, nexamples=1771, classes=[(1, 0.9271597967250141), (2, 0.0722755505364201), (0, 0.000564652738565782)]
# Creating Left Child Node With 6973 Examples, and Right Node with 600 Examples
# Creating Left Child Node With 2649 Examples, and Right Node with 4324 Examples
# Creating Child Node With ClassLabel=2, nexamples=2649, classes=[(2, 0.873914684786712), (1, 0.10985277463193659), (0, 0.016232540581351453)]
# Creating Child Node With ClassLabel=2, nexamples=4324, classes=[(2, 0.543709528214616), (0, 0.4544403330249769), (1, 0.0018501387604070306)]
# Creating Left Child Node With 173 Examples, and Right Node with 427 Examples
# Creating Child Node With ClassLabel=0, nexamples=173, classes=[(0, 0.9017341040462428), (1, 0.09826589595375723)]
# Creating Child Node With ClassLabel=1, nexamples=427, classes=[(1, 0.9929742388758782), (0, 0.00702576112412178)]
# Creating Left Child Node With 1751 Examples, and Right Node with 469 Examples
# Creating Child Node With ClassLabel=1, nexamples=1751, classes=[(1, 1.0)]
# Creating Left Child Node With 469 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 469 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=469, classes=[(0, 0.6247334754797441), (1, 0.3091684434968017), (2, 0.06609808102345416)]
#
# Creating tree # 24
# Creating Left Child Node With 3246 Examples, and Right Node with 11154 Examples
# Creating Left Child Node With 1493 Examples, and Right Node with 1753 Examples
# Creating Left Child Node With 1283 Examples, and Right Node with 210 Examples
# Creating Left Child Node With 938 Examples, and Right Node with 345 Examples
# Creating Child Node With ClassLabel=0, nexamples=938, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=345, classes=[(0, 0.9884057971014493), (1, 0.011594202898550725)]
# Creating Left Child Node With 0 Examples, and Right Node with 210 Examples
# Creating Child Node With ClassLabel=0, nexamples=210, classes=[(0, 0.9476190476190476), (2, 0.05238095238095238)]
# Creating Child Node With ClassLabel=2, nexamples=1753, classes=[(2, 1.0)]
# Creating Left Child Node With 9416 Examples, and Right Node with 1738 Examples
# Creating Left Child Node With 6971 Examples, and Right Node with 2445 Examples
# Creating Left Child Node With 2152 Examples, and Right Node with 4819 Examples
# Creating Child Node With ClassLabel=1, nexamples=2152, classes=[(1, 0.979089219330855), (2, 0.020910780669144983)]
# Creating Child Node With ClassLabel=1, nexamples=4819, classes=[(1, 0.557584561112264), (0, 0.40734592239053746), (2, 0.03506951649719859)]
# Creating Left Child Node With 898 Examples, and Right Node with 1547 Examples
# Creating Child Node With ClassLabel=2, nexamples=898, classes=[(2, 0.9944320712694877), (1, 0.005567928730512249)]
# Creating Child Node With ClassLabel=0, nexamples=1547, classes=[(0, 0.8358112475759535), (2, 0.16418875242404654)]
# Creating Left Child Node With 1685 Examples, and Right Node with 53 Examples
# Creating Child Node With ClassLabel=2, nexamples=1685, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=53, classes=[(0, 1.0)]
#
# Creating tree # 25
# Creating Left Child Node With 8318 Examples, and Right Node with 6082 Examples
# Creating Left Child Node With 6449 Examples, and Right Node with 1869 Examples
# Creating Left Child Node With 2330 Examples, and Right Node with 4119 Examples
# Creating Left Child Node With 388 Examples, and Right Node with 1942 Examples
# Creating Child Node With ClassLabel=2, nexamples=388, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1942, classes=[(0, 0.6045314109165808), (2, 0.25231719876416064), (1, 0.1431513903192585)]
# Creating Left Child Node With 1635 Examples, and Right Node with 2484 Examples
# Creating Child Node With ClassLabel=1, nexamples=1635, classes=[(1, 0.981039755351682), (2, 0.018960244648318043)]
# Creating Child Node With ClassLabel=2, nexamples=2484, classes=[(2, 0.6892109500805152), (1, 0.19122383252818034), (0, 0.11956521739130435)]
# Creating Left Child Node With 1780 Examples, and Right Node with 89 Examples
# Creating Left Child Node With 780 Examples, and Right Node with 1000 Examples
# Creating Child Node With ClassLabel=2, nexamples=780, classes=[(2, 0.958974358974359), (0, 0.041025641025641026)]
# Creating Child Node With ClassLabel=2, nexamples=1000, classes=[(2, 1.0)]
# Creating Left Child Node With 89 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=1, nexamples=89, classes=[(1, 0.9550561797752809), (2, 0.0449438202247191)]
# Creating Left Child Node With 2513 Examples, and Right Node with 3569 Examples
# Creating Left Child Node With 1166 Examples, and Right Node with 1347 Examples
# Creating Left Child Node With 1005 Examples, and Right Node with 161 Examples
# Creating Child Node With ClassLabel=0, nexamples=1005, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=161, classes=[(1, 0.9627329192546584), (0, 0.037267080745341616)]
# Creating Left Child Node With 634 Examples, and Right Node with 713 Examples
# Creating Child Node With ClassLabel=0, nexamples=634, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=713, classes=[(0, 0.9228611500701263), (2, 0.07713884992987377)]
# Creating Left Child Node With 2192 Examples, and Right Node with 1377 Examples
# Creating Left Child Node With 1842 Examples, and Right Node with 350 Examples
# Creating Child Node With ClassLabel=1, nexamples=1842, classes=[(1, 0.9576547231270358), (0, 0.02823018458197611), (2, 0.014115092290988056)]
# Creating Child Node With ClassLabel=1, nexamples=350, classes=[(1, 0.5685714285714286), (2, 0.43142857142857144)]
# Creating Left Child Node With 1257 Examples, and Right Node with 120 Examples
# Creating Child Node With ClassLabel=0, nexamples=1257, classes=[(0, 0.781225139220366), (1, 0.19968178202068418), (2, 0.01909307875894988)]
# Creating Child Node With ClassLabel=2, nexamples=120, classes=[(2, 1.0)]
#
# Creating tree # 26
# Creating Left Child Node With 12249 Examples, and Right Node with 2151 Examples
# Creating Left Child Node With 8468 Examples, and Right Node with 3781 Examples
# Creating Left Child Node With 4070 Examples, and Right Node with 4398 Examples
# Creating Left Child Node With 1830 Examples, and Right Node with 2240 Examples
# Creating Child Node With ClassLabel=2, nexamples=1830, classes=[(2, 0.5934426229508196), (0, 0.39562841530054643), (1, 0.01092896174863388)]
# Creating Child Node With ClassLabel=2, nexamples=2240, classes=[(2, 0.9991071428571429), (0, 0.0008928571428571428)]
# Creating Left Child Node With 2475 Examples, and Right Node with 1923 Examples
# Creating Child Node With ClassLabel=0, nexamples=2475, classes=[(0, 0.48444444444444446), (2, 0.3486868686868687), (1, 0.16686868686868686)]
# Creating Child Node With ClassLabel=1, nexamples=1923, classes=[(1, 0.9719188767550702), (2, 0.028081123244929798)]
# Creating Left Child Node With 963 Examples, and Right Node with 2818 Examples
# Creating Left Child Node With 452 Examples, and Right Node with 511 Examples
# Creating Child Node With ClassLabel=0, nexamples=452, classes=[(0, 0.6969026548672567), (1, 0.3030973451327434)]
# Creating Child Node With ClassLabel=1, nexamples=511, classes=[(1, 1.0)]
# Creating Left Child Node With 2280 Examples, and Right Node with 538 Examples
# Creating Child Node With ClassLabel=0, nexamples=2280, classes=[(0, 0.7666666666666667), (2, 0.23333333333333334)]
# Creating Child Node With ClassLabel=0, nexamples=538, classes=[(0, 1.0)]
# Creating Left Child Node With 746 Examples, and Right Node with 1405 Examples
# Creating Left Child Node With 129 Examples, and Right Node with 617 Examples
# Creating Left Child Node With 26 Examples, and Right Node with 103 Examples
# Creating Child Node With ClassLabel=1, nexamples=26, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=103, classes=[(0, 1.0)]
# Creating Left Child Node With 156 Examples, and Right Node with 461 Examples
# Creating Child Node With ClassLabel=1, nexamples=156, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=461, classes=[(1, 0.7158351409978309), (0, 0.279826464208243), (2, 0.004338394793926247)]
# Creating Left Child Node With 57 Examples, and Right Node with 1348 Examples
# Creating Left Child Node With 57 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=57, classes=[(2, 0.6666666666666666), (1, 0.3333333333333333)]
# Creating Child Node With ClassLabel=1, nexamples=1348, classes=[(1, 1.0)]
#
# Creating tree # 27
# Creating Left Child Node With 11708 Examples, and Right Node with 2692 Examples
# Creating Left Child Node With 4777 Examples, and Right Node with 6931 Examples
# Creating Left Child Node With 3390 Examples, and Right Node with 1387 Examples
# Creating Left Child Node With 1959 Examples, and Right Node with 1431 Examples
# Creating Child Node With ClassLabel=2, nexamples=1959, classes=[(2, 0.6130678917815212), (0, 0.33843797856049007), (1, 0.04849412965798877)]
# Creating Child Node With ClassLabel=2, nexamples=1431, classes=[(2, 0.973445143256464), (0, 0.026554856743535988)]
# Creating Left Child Node With 482 Examples, and Right Node with 905 Examples
# Creating Child Node With ClassLabel=2, nexamples=482, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=905, classes=[(1, 1.0)]
# Creating Left Child Node With 4124 Examples, and Right Node with 2807 Examples
# Creating Left Child Node With 3313 Examples, and Right Node with 811 Examples
# Creating Child Node With ClassLabel=1, nexamples=3313, classes=[(1, 0.8143676426199818), (0, 0.18533051614850587), (2, 0.00030184123151222455)]
# Creating Child Node With ClassLabel=0, nexamples=811, classes=[(0, 0.9408138101109741), (2, 0.059186189889025895)]
# Creating Left Child Node With 2763 Examples, and Right Node with 44 Examples
# Creating Child Node With ClassLabel=0, nexamples=2763, classes=[(0, 0.9753890698516106), (2, 0.024249004705030764), (1, 0.0003619254433586681)]
# Creating Child Node With ClassLabel=1, nexamples=44, classes=[(1, 1.0)]
# Creating Left Child Node With 1812 Examples, and Right Node with 880 Examples
# Creating Left Child Node With 489 Examples, and Right Node with 1323 Examples
# Creating Left Child Node With 205 Examples, and Right Node with 284 Examples
# Creating Child Node With ClassLabel=1, nexamples=205, classes=[(1, 0.8829268292682927), (2, 0.11707317073170732)]
# Creating Child Node With ClassLabel=2, nexamples=284, classes=[(2, 0.9683098591549296), (1, 0.03169014084507042)]
# Creating Left Child Node With 1323 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=1323, classes=[(2, 0.99848828420257), (0, 0.0015117157974300832)]
# Creating Child Node With ClassLabel=1, nexamples=880, classes=[(1, 1.0)]
#
# Creating tree # 28
# Creating Left Child Node With 8207 Examples, and Right Node with 6193 Examples
# Creating Left Child Node With 4942 Examples, and Right Node with 3265 Examples
# Creating Left Child Node With 3658 Examples, and Right Node with 1284 Examples
# Creating Left Child Node With 2618 Examples, and Right Node with 1040 Examples
# Creating Child Node With ClassLabel=2, nexamples=2618, classes=[(2, 0.5870893812070282), (0, 0.3834988540870894), (1, 0.029411764705882353)]
# Creating Child Node With ClassLabel=1, nexamples=1040, classes=[(1, 0.9855769230769231), (2, 0.011538461538461539), (0, 0.0028846153846153848)]
# Creating Child Node With ClassLabel=1, nexamples=1284, classes=[(1, 1.0)]
# Creating Left Child Node With 294 Examples, and Right Node with 2971 Examples
# Creating Child Node With ClassLabel=0, nexamples=294, classes=[(0, 1.0)]
# Creating Left Child Node With 20 Examples, and Right Node with 2951 Examples
# Creating Child Node With ClassLabel=1, nexamples=20, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2951, classes=[(2, 0.9939003727549983), (0, 0.005421890884445951), (1, 0.0006777363605557439)]
# Creating Left Child Node With 3358 Examples, and Right Node with 2835 Examples
# Creating Left Child Node With 1351 Examples, and Right Node with 2007 Examples
# Creating Left Child Node With 1345 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=0, nexamples=1345, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=6, classes=[(2, 1.0)]
# Creating Left Child Node With 1283 Examples, and Right Node with 724 Examples
# Creating Child Node With ClassLabel=0, nexamples=1283, classes=[(0, 0.9867498051441933), (1, 0.013250194855806703)]
# Creating Child Node With ClassLabel=0, nexamples=724, classes=[(0, 0.7486187845303868), (2, 0.2513812154696133)]
# Creating Left Child Node With 2684 Examples, and Right Node with 151 Examples
# Creating Left Child Node With 2161 Examples, and Right Node with 523 Examples
# Creating Child Node With ClassLabel=1, nexamples=2161, classes=[(1, 0.995835261453031), (2, 0.0041647385469689956)]
# Creating Child Node With ClassLabel=0, nexamples=523, classes=[(0, 0.6615678776290631), (1, 0.3384321223709369)]
# Creating Child Node With ClassLabel=2, nexamples=151, classes=[(2, 1.0)]
