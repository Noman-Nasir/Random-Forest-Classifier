# %% [markdown]
# # Assignment No 4c
# ###### *Sibt ul Hussain*
# ----
# ## Goal
#
# Your goal in this assigment is to implement and test different variants of Random Forests.For this part you will be implementing randomized version of **Randomized Linear** weak learner based Random Forest, i.e. you will be randomly selecting a pair of  features from all set of features and than randomly selecting the parameters for a generic equation of line,i.e. $ax+by+c=0$.
#
# ## TODO:
#
# **Complete the child class LinearWeakLearner in file `weaklearner.py` by writing the missing code.**
#
# **Note** Please note that you are allowed to use only those libraries which we have discussed in the class, i.e. numpy, scipy, pandas.
#
# ## Submission Instructions
# You are required to submit the original notebook file on the Slate (with .ipynb extension), with complete set of outputs. Students failing to do so will get zero marks.
#
# *Please read each step carefully and understand it fully before proceeding with code writing*
#
# ## Plagiarism
# Any form of plagiarism will not be tolerated and result in 0 marks.

# %%
# !pip install nose
# %load_ext autoreload
# %autoreload 2
# Out:
# Collecting nose
#   Downloading https://files.pythonhosted.org/packages/15/d8/dd071918c040f50fa1cf80da16423af51ff8ce4a0f2399b7bf8de45ac3d9/nose-1.3.7-py3-none-any.whl (154kB)
#      |████████████████████████████████| 163kB 2.8MB/s
# Installing collected packages: nose
# Successfully installed nose-1.3.7

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/'Colab Notebooks'/'Assignment 4'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Colab Notebooks/Assignment 4

# %%
# %pylab inline
import scipy.stats
from collections import defaultdict  # default dictionary 
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)

import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import tools as t # set of tools for plotting, data splitting, etc..
import time

# %%
# Create some dummy data for testing
np.random.seed(seed=99)

# %% [markdown]
# ## Let's cook some data up for a multi-class classification problem...

# %%
#generate training and testing set...by sampling from mutli-variate Gaussian
cp=5
nclasses=2
mean1 = [-cp,-cp]
mean2 = [cp,cp]
mean3 = [cp,-cp]
mean4 = [-cp,cp]
cov = [[3.0,0.0],[0.0,3.0]] 

#create some points for the training set...
nexamples=2000
x1 = np.random.multivariate_normal(mean1,cov,nexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,nexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,nexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,nexamples//4)

X=np.vstack((x1,x2,x3,x4))
Y=np.vstack((1*np.ones((nexamples//4,1)),2*np.ones((nexamples//4,1)),3*np.ones((nexamples//4,1)),4*np.ones((nexamples//4,1))))


plt.scatter(x1[:,0],x1[:,1], c='r', s=100)
plt.scatter(x2[:,0],x2[:,1], c='g', s=100)            
plt.scatter(x3[:,0],x3[:,1], c='b', s=100)
plt.scatter(x4[:,0],x4[:,1], c='y', s=100)            



plt.title("Multi-class Classification")
plt.xlabel("feature $x_1$")
plt.ylabel("feature $x_2$")
plt.legend(['r','g','b','y'])
fig_ml_in_10 = plt.gcf()
plt.savefig('multi-linear-class.svg',format='svg')
#create some points for the training set..

ntexamples=1000
x1 = np.random.multivariate_normal(mean1,cov,ntexamples//4)
x2 = np.random.multivariate_normal(mean2,cov,ntexamples//4)
x3 = np.random.multivariate_normal(mean3,cov,ntexamples//4)
x4 = np.random.multivariate_normal(mean4,cov,ntexamples//4)

Xt=np.vstack((x1,x2,x3,x4))
Yt=np.vstack((1*np.ones((ntexamples//4,1)),2*np.ones((ntexamples//4,1)),3*np.ones((ntexamples//4,1)),4*np.ones((ntexamples//4,1))))

# %%
import randomForest as rf

# %%
rfc=rf.RandomForest(weaklearner='Linear')

# %%
print (X.shape, Y.shape)
# Out:
# (2000, 2) (2000, 1)

# %%
# %pdb
rfc.train(X,Y)
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 963 Examples, and Right Node with 1037 Examples
# Creating Left Child Node With 476 Examples, and Right Node with 487 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 476 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 476 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=476, classes=[(2.0, 0.9978991596638656), (3.0, 0.0021008403361344537)]
# Creating Child Node With ClassLabel=3.0, nexamples=487, classes=[(3.0, 1.0)]
# Creating Left Child Node With 536 Examples, and Right Node with 501 Examples
# Creating Left Child Node With 39 Examples, and Right Node with 497 Examples
# Creating Left Child Node With 19 Examples, and Right Node with 20 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=19, classes=[(2.0, 0.9473684210526315), (4.0, 0.05263157894736842)]
# Creating Child Node With ClassLabel=4.0, nexamples=20, classes=[(4.0, 0.65), (1.0, 0.35)]
# Creating Left Child Node With 6 Examples, and Right Node with 491 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=4.0, nexamples=491, classes=[(4.0, 0.9898167006109979), (1.0, 0.008146639511201629), (2.0, 0.002036659877800407)]
# Creating Left Child Node With 14 Examples, and Right Node with 487 Examples
# Creating Left Child Node With 3 Examples, and Right Node with 11 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=11, classes=[(3.0, 0.8181818181818182), (1.0, 0.18181818181818182)]
# Creating Child Node With ClassLabel=1.0, nexamples=487, classes=[(1.0, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 504 Examples, and Right Node with 497 Examples
# Creating Left Child Node With 503 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 501 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=501, classes=[(4.0, 0.9900199600798403), (2.0, 0.005988023952095809), (1.0, 0.003992015968063872)]
# Creating Child Node With ClassLabel=1.0, nexamples=2, classes=[(1.0, 0.5), (4.0, 0.5)]
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
# Creating Left Child Node With 1 Examples, and Right Node with 496 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
# Creating Left Child Node With 108 Examples, and Right Node with 388 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=108, classes=[(1.0, 0.9907407407407407), (4.0, 0.009259259259259259)]
# Creating Child Node With ClassLabel=1.0, nexamples=388, classes=[(1.0, 1.0)]
# Creating Left Child Node With 492 Examples, and Right Node with 507 Examples
# Creating Left Child Node With 47 Examples, and Right Node with 445 Examples
# Creating Left Child Node With 33 Examples, and Right Node with 14 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=33, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=14, classes=[(2.0, 0.5), (3.0, 0.5)]
# Creating Child Node With ClassLabel=2.0, nexamples=445, classes=[(2.0, 1.0)]
# Creating Left Child Node With 6 Examples, and Right Node with 501 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(2.0, 1.0)]
# Creating Left Child Node With 494 Examples, and Right Node with 7 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=494, classes=[(3.0, 0.9959514170040485), (1.0, 0.004048582995951417)]
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 0.8571428571428571), (3.0, 0.14285714285714285)]
#
# Creating tree # 3
# Creating Left Child Node With 907 Examples, and Right Node with 1093 Examples
# Creating Left Child Node With 408 Examples, and Right Node with 499 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=408, classes=[(3.0, 1.0)]
# Creating Left Child Node With 486 Examples, and Right Node with 13 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=486, classes=[(2.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 13 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=13, classes=[(2.0, 0.9230769230769231), (3.0, 0.07692307692307693)]
# Creating Left Child Node With 485 Examples, and Right Node with 608 Examples
# Creating Left Child Node With 485 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 485 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=485, classes=[(4.0, 0.9958762886597938), (2.0, 0.004123711340206186)]
# Creating Left Child Node With 93 Examples, and Right Node with 515 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 92 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=92, classes=[(3.0, 0.9782608695652174), (1.0, 0.021739130434782608)]
# Creating Left Child Node With 17 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=17, classes=[(4.0, 0.8823529411764706), (1.0, 0.11764705882352941)]
# Creating Child Node With ClassLabel=1.0, nexamples=498, classes=[(1.0, 0.9959839357429718), (4.0, 0.004016064257028112)]
#
# Creating tree # 4
# Creating Left Child Node With 896 Examples, and Right Node with 1104 Examples
# Creating Left Child Node With 396 Examples, and Right Node with 500 Examples
# Creating Left Child Node With 396 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 389 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=7, classes=[(2.0, 0.5714285714285714), (3.0, 0.42857142857142855)]
# Creating Child Node With ClassLabel=2.0, nexamples=389, classes=[(2.0, 1.0)]
# Creating Left Child Node With 3 Examples, and Right Node with 497 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=3, classes=[(2.0, 1.0)]
# Creating Left Child Node With 497 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=497, classes=[(3.0, 0.9959758551307847), (1.0, 0.004024144869215292)]
# Creating Left Child Node With 642 Examples, and Right Node with 462 Examples
# Creating Left Child Node With 104 Examples, and Right Node with 538 Examples
# Creating Left Child Node With 85 Examples, and Right Node with 19 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=85, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=4.0, nexamples=19, classes=[(4.0, 0.5263157894736842), (2.0, 0.47368421052631576)]
# Creating Left Child Node With 519 Examples, and Right Node with 19 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=519, classes=[(4.0, 0.9441233140655106), (1.0, 0.036608863198458574), (2.0, 0.019267822736030827)]
# Creating Child Node With ClassLabel=1.0, nexamples=19, classes=[(1.0, 1.0)]
# Creating Left Child Node With 3 Examples, and Right Node with 459 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 0.6666666666666666), (1.0, 0.3333333333333333)]
# Creating Child Node With ClassLabel=1.0, nexamples=459, classes=[(1.0, 1.0)]
#
# Creating tree # 5
# Creating Left Child Node With 989 Examples, and Right Node with 1011 Examples
# Creating Left Child Node With 563 Examples, and Right Node with 426 Examples
# Creating Left Child Node With 47 Examples, and Right Node with 516 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 40 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=7, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=40, classes=[(2.0, 1.0)]
# Creating Left Child Node With 6 Examples, and Right Node with 510 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=6, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=510, classes=[(3.0, 0.9666666666666667), (1.0, 0.03137254901960784), (2.0, 0.00196078431372549)]
# Creating Child Node With ClassLabel=2.0, nexamples=426, classes=[(2.0, 1.0)]
# Creating Left Child Node With 527 Examples, and Right Node with 484 Examples
# Creating Left Child Node With 25 Examples, and Right Node with 502 Examples
# Creating Left Child Node With 22 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=22, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=4.0, nexamples=3, classes=[(4.0, 0.6666666666666666), (2.0, 0.3333333333333333)]
# Creating Left Child Node With 500 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=500, classes=[(4.0, 0.992), (1.0, 0.004), (2.0, 0.004)]
# Creating Child Node With ClassLabel=2.0, nexamples=2, classes=[(2.0, 1.0)]
# Creating Left Child Node With 22 Examples, and Right Node with 462 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 18 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 0.75), (4.0, 0.25)]
# Creating Child Node With ClassLabel=1.0, nexamples=18, classes=[(1.0, 0.9444444444444444), (4.0, 0.05555555555555555)]
# Creating Child Node With ClassLabel=1.0, nexamples=462, classes=[(1.0, 1.0)]
#
# Creating tree # 6
# Creating Left Child Node With 999 Examples, and Right Node with 1001 Examples
# Creating Left Child Node With 499 Examples, and Right Node with 500 Examples
# Creating Left Child Node With 496 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=496, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=3, classes=[(3.0, 1.0)]
# Creating Left Child Node With 1 Examples, and Right Node with 499 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=1, classes=[(2.0, 1.0)]
# Creating Left Child Node With 1 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=1, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=498, classes=[(3.0, 0.9959839357429718), (1.0, 0.004016064257028112)]
# Creating Left Child Node With 502 Examples, and Right Node with 499 Examples
# Creating Left Child Node With 502 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 502 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=502, classes=[(4.0, 0.9900398406374502), (2.0, 0.00597609561752988), (1.0, 0.00398406374501992)]
# Creating Left Child Node With 38 Examples, and Right Node with 461 Examples
# Creating Left Child Node With 1 Examples, and Right Node with 37 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
# Creating Child Node With ClassLabel=1.0, nexamples=37, classes=[(1.0, 0.9459459459459459), (4.0, 0.05405405405405406)]
# Creating Child Node With ClassLabel=1.0, nexamples=461, classes=[(1.0, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 503 Examples, and Right Node with 1497 Examples
# Creating Left Child Node With 496 Examples, and Right Node with 7 Examples
# Creating Left Child Node With 485 Examples, and Right Node with 11 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=485, classes=[(2.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 11 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=11, classes=[(4.0, 0.9090909090909091), (2.0, 0.09090909090909091)]
# Creating Child Node With ClassLabel=3.0, nexamples=7, classes=[(3.0, 1.0)]
# Creating Left Child Node With 507 Examples, and Right Node with 990 Examples
# Creating Left Child Node With 9 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=9, classes=[(2.0, 1.0)]
# Creating Left Child Node With 3 Examples, and Right Node with 495 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=3, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=495, classes=[(3.0, 0.9959595959595959), (1.0, 0.00404040404040404)]
# Creating Left Child Node With 584 Examples, and Right Node with 406 Examples
# Creating Left Child Node With 92 Examples, and Right Node with 492 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=92, classes=[(1.0, 0.9782608695652174), (4.0, 0.021739130434782608)]
# Creating Child Node With ClassLabel=4.0, nexamples=492, classes=[(4.0, 0.991869918699187), (1.0, 0.0040650406504065045), (2.0, 0.0040650406504065045)]
# Creating Child Node With ClassLabel=1.0, nexamples=406, classes=[(1.0, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 991 Examples, and Right Node with 1009 Examples
# Creating Left Child Node With 471 Examples, and Right Node with 520 Examples
# Creating Left Child Node With 382 Examples, and Right Node with 89 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=382, classes=[(4.0, 1.0)]
# Creating Left Child Node With 72 Examples, and Right Node with 17 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=72, classes=[(4.0, 0.9722222222222222), (1.0, 0.027777777777777776)]
# Creating Child Node With ClassLabel=1.0, nexamples=17, classes=[(1.0, 0.8823529411764706), (4.0, 0.11764705882352941)]
# Creating Left Child Node With 39 Examples, and Right Node with 481 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 37 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=2, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=37, classes=[(3.0, 0.9459459459459459), (1.0, 0.05405405405405406)]
# Creating Child Node With ClassLabel=1.0, nexamples=481, classes=[(1.0, 1.0)]
# Creating Left Child Node With 548 Examples, and Right Node with 461 Examples
# Creating Left Child Node With 61 Examples, and Right Node with 487 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 38 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=23, classes=[(2.0, 0.5217391304347826), (3.0, 0.4782608695652174)]
# Creating Child Node With ClassLabel=4.0, nexamples=38, classes=[(4.0, 0.9473684210526315), (2.0, 0.05263157894736842)]
# Creating Left Child Node With 476 Examples, and Right Node with 11 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=476, classes=[(2.0, 1.0)]
# Creating Child Node With ClassLabel=4.0, nexamples=11, classes=[(4.0, 0.9090909090909091), (2.0, 0.09090909090909091)]
# Creating Left Child Node With 452 Examples, and Right Node with 9 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=452, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=9, classes=[(2.0, 1.0)]
#
# Creating tree # 9
# Creating Left Child Node With 503 Examples, and Right Node with 1497 Examples
# Creating Left Child Node With 484 Examples, and Right Node with 19 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 477 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=7, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=2.0, nexamples=477, classes=[(2.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 19 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=11, classes=[(4.0, 0.9090909090909091), (2.0, 0.09090909090909091)]
# Creating Child Node With ClassLabel=2.0, nexamples=8, classes=[(2.0, 1.0)]
# Creating Left Child Node With 507 Examples, and Right Node with 990 Examples
# Creating Left Child Node With 11 Examples, and Right Node with 496 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=11, classes=[(2.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 496 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=496, classes=[(3.0, 0.9939516129032258), (1.0, 0.004032258064516129), (2.0, 0.0020161290322580645)]
# Creating Left Child Node With 493 Examples, and Right Node with 497 Examples
# Creating Left Child Node With 447 Examples, and Right Node with 46 Examples
# Creating Child Node With ClassLabel=4.0, nexamples=447, classes=[(4.0, 0.9955257270693513), (2.0, 0.0044742729306487695)]
# Creating Child Node With ClassLabel=4.0, nexamples=46, classes=[(4.0, 0.9347826086956522), (1.0, 0.06521739130434782)]
# Creating Left Child Node With 0 Examples, and Right Node with 497 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=497, classes=[(1.0, 0.9959758551307847), (4.0, 0.004024144869215292)]
#
# Creating tree # 10
# Creating Left Child Node With 1001 Examples, and Right Node with 999 Examples
# Creating Left Child Node With 503 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 502 Examples, and Right Node with 1 Examples
# Creating Left Child Node With 2 Examples, and Right Node with 500 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=2, classes=[(2.0, 0.5), (4.0, 0.5)]
# Creating Child Node With ClassLabel=4.0, nexamples=500, classes=[(4.0, 0.992), (1.0, 0.004), (2.0, 0.004)]
# Creating Child Node With ClassLabel=4.0, nexamples=1, classes=[(4.0, 1.0)]
# Creating Left Child Node With 100 Examples, and Right Node with 398 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 96 Examples
# Creating Child Node With ClassLabel=1.0, nexamples=4, classes=[(1.0, 0.75), (4.0, 0.25)]
# Creating Child Node With ClassLabel=1.0, nexamples=96, classes=[(1.0, 0.9895833333333334), (4.0, 0.010416666666666666)]
# Creating Child Node With ClassLabel=1.0, nexamples=398, classes=[(1.0, 1.0)]
# Creating Left Child Node With 501 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 15 Examples, and Right Node with 486 Examples
# Creating Left Child Node With 7 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=3.0, nexamples=7, classes=[(3.0, 1.0)]
# Creating Child Node With ClassLabel=3.0, nexamples=8, classes=[(3.0, 0.75), (1.0, 0.25)]
# Creating Child Node With ClassLabel=3.0, nexamples=486, classes=[(3.0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 498 Examples
# Creating Child Node With ClassLabel=2.0, nexamples=498, classes=[(2.0, 0.9979919678714859), (3.0, 0.002008032128514056)]

# %%
len(rfc.trees)
# Out:
# 10

# %%
# %pdb
# Training Confusion Matrix...
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (2000, 1) 2000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        496    0    2    2   500
# 2.0          0  497    0    3   500
# 3.0          0    1  499    0   500
# 4.0          2    0    0  498   500
# All        498  498  501  503  2000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.995

# %%
#It might take time, a little longer than the desired
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('training-boundary-rf-rlinear-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Testing Confusion Matrix...
Ypt=rfc.predict(Xt)
print (Yt.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Yt)
# Out:
# (1000, 1) 1000
# Predicted  1.0  2.0  3.0  4.0   All
# Actual
# 1.0        250    0    0    0   250
# 2.0          0  248    1    1   250
# 3.0          1    1  248    0   250
# 4.0          1    0    0  249   250
# All        252  249  249  250  1000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Yt))
acc = np.sum(tlabels == plabels) / len(Yt)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.995

# %%
t.plot_decision_regions(X,np.squeeze(Y), clf=rfc,res=0.1);
plt.savefig('testing-boundary-rf-raa-10trees.svg',format='svg')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#plt.style.use('ggplot')
#matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)
# %pdb
t.plot_points_range(rfc,X,Y,10000)
# Out:
# (10000, 2)
# [1.0, 2.0, 3.0, 4.0]

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
#@title Default title text
ntrees=rfc.ntrees
nrows=int(ntrees/2)
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,20))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,np.squeeze(Y),clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# #### What Can You conclude

# %% [markdown]
# ## Lets Run on Nonlinear Data, The Spherical Examples...

# %%
#Get Training Data from a spherical distribution and ...
X,Y=t.get_spherical_data(N=10000)

# %%
print (X.shape, Y.shape)
# Out:
# (30000, 2) (30000,)

# %%
#Get Test Data 
Xtest,Ytest=t.get_spherical_data(N=5000)

# %%
rfc=rf.RandomForest(weaklearner='Linear',usebagging=False,ntrees=20)
rfc.train(X,Y[:,np.newaxis])
# Out:
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 25158 Examples, and Right Node with 4842 Examples
# Creating Left Child Node With 13707 Examples, and Right Node with 11451 Examples
# Creating Left Child Node With 5089 Examples, and Right Node with 8618 Examples
# Creating Left Child Node With 4954 Examples, and Right Node with 135 Examples
# Creating Child Node With ClassLabel=1, nexamples=4954, classes=[(1, 0.9989907145740815), (0, 0.0008074283407347598), (2, 0.00020185708518368994)]
# Creating Child Node With ClassLabel=2, nexamples=135, classes=[(2, 1.0)]
# Creating Left Child Node With 5640 Examples, and Right Node with 2978 Examples
# Creating Child Node With ClassLabel=0, nexamples=5640, classes=[(0, 0.4888297872340426), (2, 0.46382978723404256), (1, 0.04734042553191489)]
# Creating Child Node With ClassLabel=0, nexamples=2978, classes=[(0, 0.8529214237743452), (1, 0.1470785762256548)]
# Creating Left Child Node With 8893 Examples, and Right Node with 2558 Examples
# Creating Left Child Node With 6817 Examples, and Right Node with 2076 Examples
# Creating Child Node With ClassLabel=1, nexamples=6817, classes=[(1, 0.6042247322869297), (2, 0.39577526771307026)]
# Creating Child Node With ClassLabel=2, nexamples=2076, classes=[(2, 1.0)]
# Creating Left Child Node With 1914 Examples, and Right Node with 644 Examples
# Creating Child Node With ClassLabel=2, nexamples=1914, classes=[(2, 0.9864158829676071), (0, 0.013584117032392894)]
# Creating Child Node With ClassLabel=2, nexamples=644, classes=[(2, 0.656832298136646), (0, 0.34316770186335405)]
# Creating Left Child Node With 4616 Examples, and Right Node with 226 Examples
# Creating Left Child Node With 1808 Examples, and Right Node with 2808 Examples
# Creating Left Child Node With 1161 Examples, and Right Node with 647 Examples
# Creating Child Node With ClassLabel=0, nexamples=1161, classes=[(0, 0.9991386735572783), (1, 0.0008613264427217916)]
# Creating Child Node With ClassLabel=0, nexamples=647, classes=[(0, 0.9969088098918083), (2, 0.0030911901081916537)]
# Creating Left Child Node With 26 Examples, and Right Node with 2782 Examples
# Creating Child Node With ClassLabel=2, nexamples=26, classes=[(2, 0.8461538461538461), (0, 0.15384615384615385)]
# Creating Child Node With ClassLabel=0, nexamples=2782, classes=[(0, 0.9500359453630481), (2, 0.04996405463695183)]
# Creating Child Node With ClassLabel=1, nexamples=226, classes=[(1, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 7492 Examples, and Right Node with 22508 Examples
# Creating Left Child Node With 5292 Examples, and Right Node with 2200 Examples
# Creating Left Child Node With 2465 Examples, and Right Node with 2827 Examples
# Creating Child Node With ClassLabel=1, nexamples=2465, classes=[(1, 1.0)]
# Creating Left Child Node With 2505 Examples, and Right Node with 322 Examples
# Creating Child Node With ClassLabel=1, nexamples=2505, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=322, classes=[(2, 0.9813664596273292), (1, 0.018633540372670808)]
# Creating Left Child Node With 2200 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 2200 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=2200, classes=[(2, 0.9959090909090909), (1, 0.004090909090909091)]
# Creating Left Child Node With 20633 Examples, and Right Node with 1875 Examples
# Creating Left Child Node With 12982 Examples, and Right Node with 7651 Examples
# Creating Left Child Node With 11709 Examples, and Right Node with 1273 Examples
# Creating Child Node With ClassLabel=0, nexamples=11709, classes=[(0, 0.537193611751644), (2, 0.4617815355709283), (1, 0.0010248526774276198)]
# Creating Child Node With ClassLabel=0, nexamples=1273, classes=[(0, 1.0)]
# Creating Left Child Node With 5406 Examples, and Right Node with 2245 Examples
# Creating Child Node With ClassLabel=1, nexamples=5406, classes=[(1, 0.5786163522012578), (0, 0.3973362930077691), (2, 0.024047354790972992)]
# Creating Child Node With ClassLabel=2, nexamples=2245, classes=[(2, 0.8712694877505568), (0, 0.1287305122494432)]
# Creating Child Node With ClassLabel=1, nexamples=1875, classes=[(1, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 7251 Examples, and Right Node with 22749 Examples
# Creating Left Child Node With 3095 Examples, and Right Node with 4156 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3095 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3095 Examples
# Creating Child Node With ClassLabel=1, nexamples=3095, classes=[(1, 0.7130856219709208), (0, 0.28691437802907915)]
# Creating Left Child Node With 3842 Examples, and Right Node with 314 Examples
# Creating Left Child Node With 48 Examples, and Right Node with 3794 Examples
# Creating Child Node With ClassLabel=1, nexamples=48, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3794, classes=[(0, 0.9957828149710068), (2, 0.003953610964681075), (1, 0.0002635740643120717)]
# Creating Child Node With ClassLabel=1, nexamples=314, classes=[(1, 1.0)]
# Creating Left Child Node With 8162 Examples, and Right Node with 14587 Examples
# Creating Left Child Node With 6399 Examples, and Right Node with 1763 Examples
# Creating Left Child Node With 1094 Examples, and Right Node with 5305 Examples
# Creating Child Node With ClassLabel=2, nexamples=1094, classes=[(2, 0.7422303473491774), (1, 0.2577696526508227)]
# Creating Child Node With ClassLabel=2, nexamples=5305, classes=[(2, 0.9153628652214891), (0, 0.08350612629594723), (1, 0.0011310084825636192)]
# Creating Left Child Node With 155 Examples, and Right Node with 1608 Examples
# Creating Child Node With ClassLabel=0, nexamples=155, classes=[(0, 0.6193548387096774), (2, 0.38064516129032255)]
# Creating Child Node With ClassLabel=0, nexamples=1608, classes=[(0, 0.9900497512437811), (2, 0.009950248756218905)]
# Creating Left Child Node With 2246 Examples, and Right Node with 12341 Examples
# Creating Left Child Node With 23 Examples, and Right Node with 2223 Examples
# Creating Child Node With ClassLabel=0, nexamples=23, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2223, classes=[(2, 1.0)]
# Creating Left Child Node With 1515 Examples, and Right Node with 10826 Examples
# Creating Child Node With ClassLabel=2, nexamples=1515, classes=[(2, 0.5716171617161716), (1, 0.4283828382838284)]
# Creating Child Node With ClassLabel=1, nexamples=10826, classes=[(1, 0.5997598374284131), (0, 0.29373729909477186), (2, 0.10650286347681508)]
#
# Creating tree # 4
# Creating Left Child Node With 21318 Examples, and Right Node with 8682 Examples
# Creating Left Child Node With 15978 Examples, and Right Node with 5340 Examples
# Creating Left Child Node With 4195 Examples, and Right Node with 11783 Examples
# Creating Left Child Node With 4189 Examples, and Right Node with 6 Examples
# Creating Child Node With ClassLabel=1, nexamples=4189, classes=[(1, 0.9980902363332538), (0, 0.0009548818333731201), (2, 0.0009548818333731201)]
# Creating Child Node With ClassLabel=2, nexamples=6, classes=[(2, 1.0)]
# Creating Left Child Node With 10444 Examples, and Right Node with 1339 Examples
# Creating Child Node With ClassLabel=0, nexamples=10444, classes=[(0, 0.641325162772884), (2, 0.322769054002298), (1, 0.03590578322481808)]
# Creating Child Node With ClassLabel=1, nexamples=1339, classes=[(1, 1.0)]
# Creating Left Child Node With 4093 Examples, and Right Node with 1247 Examples
# Creating Child Node With ClassLabel=1, nexamples=4093, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1247 Examples
# Creating Child Node With ClassLabel=2, nexamples=1247, classes=[(2, 0.9951884522854851), (1, 0.0048115477145148355)]
# Creating Left Child Node With 4731 Examples, and Right Node with 3951 Examples
# Creating Left Child Node With 4597 Examples, and Right Node with 134 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 4597 Examples
# Creating Child Node With ClassLabel=2, nexamples=4597, classes=[(2, 0.998042201435719), (1, 0.0013051990428540352), (0, 0.0006525995214270176)]
# Creating Left Child Node With 89 Examples, and Right Node with 45 Examples
# Creating Child Node With ClassLabel=2, nexamples=89, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=45, classes=[(2, 0.5111111111111111), (0, 0.4888888888888889)]
# Creating Left Child Node With 1239 Examples, and Right Node with 2712 Examples
# Creating Left Child Node With 628 Examples, and Right Node with 611 Examples
# Creating Child Node With ClassLabel=0, nexamples=628, classes=[(0, 0.9617834394904459), (2, 0.03821656050955414)]
# Creating Child Node With ClassLabel=0, nexamples=611, classes=[(0, 1.0)]
# Creating Left Child Node With 716 Examples, and Right Node with 1996 Examples
# Creating Child Node With ClassLabel=2, nexamples=716, classes=[(2, 0.8477653631284916), (0, 0.15223463687150837)]
# Creating Child Node With ClassLabel=0, nexamples=1996, classes=[(0, 0.9764529058116233), (2, 0.023547094188376753)]
#
# Creating tree # 5
# Creating Left Child Node With 7039 Examples, and Right Node with 22961 Examples
# Creating Left Child Node With 4804 Examples, and Right Node with 2235 Examples
# Creating Left Child Node With 3382 Examples, and Right Node with 1422 Examples
# Creating Child Node With ClassLabel=1, nexamples=3382, classes=[(1, 1.0)]
# Creating Left Child Node With 1107 Examples, and Right Node with 315 Examples
# Creating Child Node With ClassLabel=1, nexamples=1107, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=315, classes=[(0, 0.9079365079365079), (1, 0.09206349206349207)]
# Creating Left Child Node With 2085 Examples, and Right Node with 150 Examples
# Creating Left Child Node With 854 Examples, and Right Node with 1231 Examples
# Creating Child Node With ClassLabel=2, nexamples=854, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1231, classes=[(1, 0.9163281884646629), (2, 0.08367181153533712)]
# Creating Child Node With ClassLabel=2, nexamples=150, classes=[(2, 1.0)]
# Creating Left Child Node With 5458 Examples, and Right Node with 17503 Examples
# Creating Left Child Node With 4909 Examples, and Right Node with 549 Examples
# Creating Left Child Node With 1874 Examples, and Right Node with 3035 Examples
# Creating Child Node With ClassLabel=0, nexamples=1874, classes=[(0, 0.884204909284952), (2, 0.11579509071504802)]
# Creating Child Node With ClassLabel=0, nexamples=3035, classes=[(0, 0.9983525535420099), (1, 0.0016474464579901153)]
# Creating Left Child Node With 540 Examples, and Right Node with 9 Examples
# Creating Child Node With ClassLabel=1, nexamples=540, classes=[(1, 0.5166666666666667), (0, 0.48333333333333334)]
# Creating Child Node With ClassLabel=1, nexamples=9, classes=[(1, 1.0)]
# Creating Left Child Node With 11321 Examples, and Right Node with 6182 Examples
# Creating Left Child Node With 6294 Examples, and Right Node with 5027 Examples
# Creating Child Node With ClassLabel=0, nexamples=6294, classes=[(0, 0.6024785510009533), (2, 0.3676517318080712), (1, 0.02986971719097553)]
# Creating Child Node With ClassLabel=1, nexamples=5027, classes=[(1, 0.770041774418142), (2, 0.22916252237915258), (0, 0.0007957032027053909)]
# Creating Left Child Node With 4650 Examples, and Right Node with 1532 Examples
# Creating Child Node With ClassLabel=2, nexamples=4650, classes=[(2, 0.9995698924731182), (1, 0.00043010752688172043)]
# Creating Child Node With ClassLabel=0, nexamples=1532, classes=[(0, 0.6331592689295039), (2, 0.3668407310704961)]
#
# Creating tree # 6
# Creating Left Child Node With 24916 Examples, and Right Node with 5084 Examples
# Creating Left Child Node With 13881 Examples, and Right Node with 11035 Examples
# Creating Left Child Node With 7608 Examples, and Right Node with 6273 Examples
# Creating Left Child Node With 2935 Examples, and Right Node with 4673 Examples
# Creating Child Node With ClassLabel=0, nexamples=2935, classes=[(0, 0.6398637137989779), (2, 0.20136286201022147), (1, 0.15877342419080068)]
# Creating Child Node With ClassLabel=1, nexamples=4673, classes=[(1, 0.545687994864113), (0, 0.4264926171624224), (2, 0.027819387973464584)]
# Creating Left Child Node With 109 Examples, and Right Node with 6164 Examples
# Creating Child Node With ClassLabel=2, nexamples=109, classes=[(2, 0.944954128440367), (1, 0.05504587155963303)]
# Creating Child Node With ClassLabel=1, nexamples=6164, classes=[(1, 0.9643088903309539), (0, 0.035691109669046074)]
# Creating Left Child Node With 8532 Examples, and Right Node with 2503 Examples
# Creating Left Child Node With 4236 Examples, and Right Node with 4296 Examples
# Creating Child Node With ClassLabel=0, nexamples=4236, classes=[(0, 0.7901322001888574), (2, 0.12417374881964117), (1, 0.08569405099150142)]
# Creating Child Node With ClassLabel=2, nexamples=4296, classes=[(2, 0.6105679702048417), (0, 0.3894320297951583)]
# Creating Left Child Node With 1536 Examples, and Right Node with 967 Examples
# Creating Child Node With ClassLabel=2, nexamples=1536, classes=[(2, 0.5631510416666666), (1, 0.4368489583333333)]
# Creating Child Node With ClassLabel=2, nexamples=967, classes=[(2, 1.0)]
# Creating Left Child Node With 4406 Examples, and Right Node with 678 Examples
# Creating Left Child Node With 2979 Examples, and Right Node with 1427 Examples
# Creating Child Node With ClassLabel=2, nexamples=2979, classes=[(2, 1.0)]
# Creating Left Child Node With 715 Examples, and Right Node with 712 Examples
# Creating Child Node With ClassLabel=2, nexamples=715, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=712, classes=[(2, 0.7036516853932584), (0, 0.29634831460674155)]
# Creating Child Node With ClassLabel=0, nexamples=678, classes=[(0, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 5161 Examples, and Right Node with 24839 Examples
# Creating Left Child Node With 1443 Examples, and Right Node with 3718 Examples
# Creating Left Child Node With 1331 Examples, and Right Node with 112 Examples
# Creating Left Child Node With 1106 Examples, and Right Node with 225 Examples
# Creating Child Node With ClassLabel=0, nexamples=1106, classes=[(0, 0.6844484629294756), (1, 0.3155515370705244)]
# Creating Child Node With ClassLabel=0, nexamples=225, classes=[(0, 0.8488888888888889), (2, 0.1511111111111111)]
# Creating Child Node With ClassLabel=1, nexamples=112, classes=[(1, 1.0)]
# Creating Left Child Node With 3705 Examples, and Right Node with 13 Examples
# Creating Left Child Node With 1493 Examples, and Right Node with 2212 Examples
# Creating Child Node With ClassLabel=0, nexamples=1493, classes=[(0, 0.999330207635633), (1, 0.0006697923643670462)]
# Creating Child Node With ClassLabel=0, nexamples=2212, classes=[(0, 0.9579566003616636), (2, 0.042043399638336344)]
# Creating Child Node With ClassLabel=1, nexamples=13, classes=[(1, 1.0)]
# Creating Left Child Node With 8994 Examples, and Right Node with 15845 Examples
# Creating Left Child Node With 4129 Examples, and Right Node with 4865 Examples
# Creating Left Child Node With 2896 Examples, and Right Node with 1233 Examples
# Creating Child Node With ClassLabel=0, nexamples=2896, classes=[(0, 0.9913674033149171), (2, 0.008632596685082873)]
# Creating Child Node With ClassLabel=0, nexamples=1233, classes=[(0, 0.7137064071370641), (1, 0.28629359286293593)]
# Creating Left Child Node With 4709 Examples, and Right Node with 156 Examples
# Creating Child Node With ClassLabel=1, nexamples=4709, classes=[(1, 0.9520067954979826), (0, 0.046719048630282436), (2, 0.0012741558717349756)]
# Creating Child Node With ClassLabel=2, nexamples=156, classes=[(2, 0.9294871794871795), (1, 0.07051282051282051)]
# Creating Left Child Node With 4176 Examples, and Right Node with 11669 Examples
# Creating Left Child Node With 1715 Examples, and Right Node with 2461 Examples
# Creating Child Node With ClassLabel=0, nexamples=1715, classes=[(0, 0.5988338192419825), (1, 0.3253644314868805), (2, 0.07580174927113703)]
# Creating Child Node With ClassLabel=2, nexamples=2461, classes=[(2, 0.9995936611133686), (1, 0.0004063388866314506)]
# Creating Left Child Node With 5458 Examples, and Right Node with 6211 Examples
# Creating Child Node With ClassLabel=1, nexamples=5458, classes=[(1, 0.7385489190179553), (2, 0.2614510809820447)]
# Creating Child Node With ClassLabel=2, nexamples=6211, classes=[(2, 0.9145065206891), (0, 0.07132506842698438), (1, 0.014168410883915633)]
#
# Creating tree # 8
# Creating Left Child Node With 21857 Examples, and Right Node with 8143 Examples
# Creating Left Child Node With 5994 Examples, and Right Node with 15863 Examples
# Creating Left Child Node With 998 Examples, and Right Node with 4996 Examples
# Creating Left Child Node With 70 Examples, and Right Node with 928 Examples
# Creating Child Node With ClassLabel=0, nexamples=70, classes=[(0, 0.5), (1, 0.5)]
# Creating Child Node With ClassLabel=1, nexamples=928, classes=[(1, 0.8178879310344828), (0, 0.18211206896551724)]
# Creating Left Child Node With 4967 Examples, and Right Node with 29 Examples
# Creating Child Node With ClassLabel=0, nexamples=4967, classes=[(0, 0.9553050130863701), (2, 0.04368834306422388), (1, 0.0010066438494060802)]
# Creating Child Node With ClassLabel=1, nexamples=29, classes=[(1, 1.0)]
# Creating Left Child Node With 9564 Examples, and Right Node with 6299 Examples
# Creating Left Child Node With 4298 Examples, and Right Node with 5266 Examples
# Creating Child Node With ClassLabel=2, nexamples=4298, classes=[(2, 0.5637505816658911), (0, 0.4346207538389949), (1, 0.0016286644951140066)]
# Creating Child Node With ClassLabel=1, nexamples=5266, classes=[(1, 0.59684770224079), (0, 0.3784656285605773), (2, 0.024686669198632737)]
# Creating Left Child Node With 5540 Examples, and Right Node with 759 Examples
# Creating Child Node With ClassLabel=2, nexamples=5540, classes=[(2, 0.9489169675090253), (0, 0.03808664259927798), (1, 0.012996389891696752)]
# Creating Child Node With ClassLabel=0, nexamples=759, classes=[(0, 1.0)]
# Creating Left Child Node With 1870 Examples, and Right Node with 6273 Examples
# Creating Child Node With ClassLabel=2, nexamples=1870, classes=[(2, 1.0)]
# Creating Left Child Node With 102 Examples, and Right Node with 6171 Examples
# Creating Child Node With ClassLabel=2, nexamples=102, classes=[(2, 1.0)]
# Creating Left Child Node With 4100 Examples, and Right Node with 2071 Examples
# Creating Child Node With ClassLabel=1, nexamples=4100, classes=[(1, 0.9997560975609756), (2, 0.00024390243902439024)]
# Creating Child Node With ClassLabel=1, nexamples=2071, classes=[(1, 0.8937711250603573), (0, 0.10622887493964268)]
#
# Creating tree # 9
# Creating Left Child Node With 19720 Examples, and Right Node with 10280 Examples
# Creating Left Child Node With 8573 Examples, and Right Node with 11147 Examples
# Creating Left Child Node With 5652 Examples, and Right Node with 2921 Examples
# Creating Left Child Node With 3728 Examples, and Right Node with 1924 Examples
# Creating Child Node With ClassLabel=1, nexamples=3728, classes=[(1, 0.9723712446351931), (2, 0.027628755364806867)]
# Creating Child Node With ClassLabel=1, nexamples=1924, classes=[(1, 0.9984407484407485), (0, 0.0015592515592515593)]
# Creating Child Node With ClassLabel=2, nexamples=2921, classes=[(2, 1.0)]
# Creating Left Child Node With 4894 Examples, and Right Node with 6253 Examples
# Creating Left Child Node With 1967 Examples, and Right Node with 2927 Examples
# Creating Child Node With ClassLabel=1, nexamples=1967, classes=[(1, 0.6354855109303508), (0, 0.36451448906964923)]
# Creating Child Node With ClassLabel=0, nexamples=2927, classes=[(0, 0.8015032456440041), (1, 0.1984967543559959)]
# Creating Left Child Node With 4005 Examples, and Right Node with 2248 Examples
# Creating Child Node With ClassLabel=2, nexamples=4005, classes=[(2, 0.5008739076154807), (0, 0.4324594257178527), (1, 0.06666666666666667)]
# Creating Child Node With ClassLabel=1, nexamples=2248, classes=[(1, 0.972864768683274), (2, 0.027135231316725978)]
# Creating Left Child Node With 1841 Examples, and Right Node with 8439 Examples
# Creating Left Child Node With 179 Examples, and Right Node with 1662 Examples
# Creating Left Child Node With 164 Examples, and Right Node with 15 Examples
# Creating Child Node With ClassLabel=1, nexamples=164, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=15, classes=[(0, 0.6666666666666666), (1, 0.3333333333333333)]
# Creating Child Node With ClassLabel=0, nexamples=1662, classes=[(0, 1.0)]
# Creating Left Child Node With 1119 Examples, and Right Node with 7320 Examples
# Creating Left Child Node With 16 Examples, and Right Node with 1103 Examples
# Creating Child Node With ClassLabel=2, nexamples=16, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1103, classes=[(0, 0.9981867633726201), (2, 0.001813236627379873)]
# Creating Left Child Node With 4238 Examples, and Right Node with 3082 Examples
# Creating Child Node With ClassLabel=2, nexamples=4238, classes=[(2, 0.9941009910335064), (0, 0.005899008966493629)]
# Creating Child Node With ClassLabel=0, nexamples=3082, classes=[(0, 0.7800129785853342), (2, 0.2199870214146658)]
#
# Creating tree # 10
# Creating Left Child Node With 20002 Examples, and Right Node with 9998 Examples
# Creating Left Child Node With 6249 Examples, and Right Node with 13753 Examples
# Creating Left Child Node With 5230 Examples, and Right Node with 1019 Examples
# Creating Left Child Node With 1209 Examples, and Right Node with 4021 Examples
# Creating Child Node With ClassLabel=2, nexamples=1209, classes=[(2, 0.9139784946236559), (1, 0.08602150537634409)]
# Creating Child Node With ClassLabel=1, nexamples=4021, classes=[(1, 0.9970156677443422), (2, 0.0029843322556577967)]
# Creating Left Child Node With 1015 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=2, nexamples=1015, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=4, classes=[(1, 1.0)]
# Creating Left Child Node With 8611 Examples, and Right Node with 5142 Examples
# Creating Left Child Node With 4298 Examples, and Right Node with 4313 Examples
# Creating Child Node With ClassLabel=2, nexamples=4298, classes=[(2, 0.5362959516053979), (0, 0.401582131223825), (1, 0.062121917170777106)]
# Creating Child Node With ClassLabel=0, nexamples=4313, classes=[(0, 0.8101089728727104), (1, 0.18989102712728959)]
# Creating Left Child Node With 142 Examples, and Right Node with 5000 Examples
# Creating Child Node With ClassLabel=2, nexamples=142, classes=[(2, 0.9577464788732394), (1, 0.04225352112676056)]
# Creating Child Node With ClassLabel=1, nexamples=5000, classes=[(1, 0.956), (0, 0.044)]
# Creating Left Child Node With 2242 Examples, and Right Node with 7756 Examples
# Creating Left Child Node With 2242 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 2238 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=2, nexamples=2238, classes=[(2, 0.9991063449508489), (1, 0.0008936550491510277)]
# Creating Child Node With ClassLabel=0, nexamples=4, classes=[(0, 1.0)]
# Creating Left Child Node With 3694 Examples, and Right Node with 4062 Examples
# Creating Left Child Node With 2918 Examples, and Right Node with 776 Examples
# Creating Child Node With ClassLabel=2, nexamples=2918, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=776, classes=[(0, 0.8015463917525774), (2, 0.19845360824742267)]
# Creating Left Child Node With 38 Examples, and Right Node with 4024 Examples
# Creating Child Node With ClassLabel=0, nexamples=38, classes=[(0, 0.7631578947368421), (1, 0.23684210526315788)]
# Creating Child Node With ClassLabel=0, nexamples=4024, classes=[(0, 0.970427435387674), (2, 0.029572564612326043)]
#
# Creating tree # 11
# Creating Left Child Node With 8588 Examples, and Right Node with 21412 Examples
# Creating Left Child Node With 6482 Examples, and Right Node with 2106 Examples
# Creating Left Child Node With 830 Examples, and Right Node with 5652 Examples
# Creating Child Node With ClassLabel=2, nexamples=830, classes=[(2, 1.0)]
# Creating Left Child Node With 3304 Examples, and Right Node with 2348 Examples
# Creating Child Node With ClassLabel=1, nexamples=3304, classes=[(1, 0.9688256658595642), (2, 0.031174334140435835)]
# Creating Child Node With ClassLabel=1, nexamples=2348, classes=[(1, 0.9987223168654173), (0, 0.0012776831345826234)]
# Creating Left Child Node With 0 Examples, and Right Node with 2106 Examples
# Creating Left Child Node With 2106 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=2106, classes=[(2, 0.9990503323836657), (0, 0.000949667616334283)]
# Creating Left Child Node With 1738 Examples, and Right Node with 19674 Examples
# Creating Left Child Node With 1734 Examples, and Right Node with 4 Examples
# Creating Child Node With ClassLabel=1, nexamples=1734, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=4, classes=[(0, 1.0)]
# Creating Left Child Node With 15192 Examples, and Right Node with 4482 Examples
# Creating Left Child Node With 9195 Examples, and Right Node with 5997 Examples
# Creating Child Node With ClassLabel=2, nexamples=9195, classes=[(2, 0.588036976617727), (0, 0.4112017400761283), (1, 0.0007612833061446438)]
# Creating Child Node With ClassLabel=1, nexamples=5997, classes=[(1, 0.408037352009338), (0, 0.3324995831248958), (2, 0.2594630648657662)]
# Creating Left Child Node With 265 Examples, and Right Node with 4217 Examples
# Creating Child Node With ClassLabel=1, nexamples=265, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=4217, classes=[(0, 0.9997628645956841), (1, 0.00023713540431586437)]
#
# Creating tree # 12
# Creating Left Child Node With 21318 Examples, and Right Node with 8682 Examples
# Creating Left Child Node With 15808 Examples, and Right Node with 5510 Examples
# Creating Left Child Node With 5289 Examples, and Right Node with 10519 Examples
# Creating Left Child Node With 393 Examples, and Right Node with 4896 Examples
# Creating Child Node With ClassLabel=1, nexamples=393, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=4896, classes=[(1, 0.8570261437908496), (2, 0.14215686274509803), (0, 0.0008169934640522876)]
# Creating Left Child Node With 8424 Examples, and Right Node with 2095 Examples
# Creating Child Node With ClassLabel=0, nexamples=8424, classes=[(0, 0.5775166191832859), (2, 0.4001661918328585), (1, 0.02231718898385565)]
# Creating Child Node With ClassLabel=0, nexamples=2095, classes=[(0, 0.8730310262529833), (1, 0.1269689737470167)]
# Creating Left Child Node With 452 Examples, and Right Node with 5058 Examples
# Creating Child Node With ClassLabel=2, nexamples=452, classes=[(2, 1.0)]
# Creating Left Child Node With 975 Examples, and Right Node with 4083 Examples
# Creating Child Node With ClassLabel=1, nexamples=975, classes=[(1, 0.8943589743589744), (2, 0.10564102564102563)]
# Creating Child Node With ClassLabel=1, nexamples=4083, classes=[(1, 0.9990203281900564), (0, 0.0009796718099436689)]
# Creating Left Child Node With 3059 Examples, and Right Node with 5623 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3059 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3059 Examples
# Creating Child Node With ClassLabel=2, nexamples=3059, classes=[(2, 0.9980385746976136), (1, 0.001961425302386401)]
# Creating Left Child Node With 2700 Examples, and Right Node with 2923 Examples
# Creating Left Child Node With 172 Examples, and Right Node with 2528 Examples
# Creating Child Node With ClassLabel=0, nexamples=172, classes=[(0, 0.9534883720930233), (2, 0.046511627906976744)]
# Creating Child Node With ClassLabel=2, nexamples=2528, classes=[(2, 0.9165348101265823), (0, 0.08346518987341772)]
# Creating Child Node With ClassLabel=0, nexamples=2923, classes=[(0, 1.0)]
#
# Creating tree # 13
# Creating Left Child Node With 8588 Examples, and Right Node with 21412 Examples
# Creating Left Child Node With 2349 Examples, and Right Node with 6239 Examples
# Creating Left Child Node With 402 Examples, and Right Node with 1947 Examples
# Creating Left Child Node With 402 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=402, classes=[(2, 0.9850746268656716), (1, 0.014925373134328358)]
# Creating Child Node With ClassLabel=2, nexamples=1947, classes=[(2, 1.0)]
# Creating Left Child Node With 5543 Examples, and Right Node with 696 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 5543 Examples
# Creating Child Node With ClassLabel=1, nexamples=5543, classes=[(1, 0.9994587768356485), (0, 0.0005412231643514342)]
# Creating Left Child Node With 0 Examples, and Right Node with 696 Examples
# Creating Child Node With ClassLabel=2, nexamples=696, classes=[(2, 0.9971264367816092), (0, 0.0028735632183908046)]
# Creating Left Child Node With 15755 Examples, and Right Node with 5657 Examples
# Creating Left Child Node With 3426 Examples, and Right Node with 12329 Examples
# Creating Left Child Node With 3336 Examples, and Right Node with 90 Examples
# Creating Child Node With ClassLabel=0, nexamples=3336, classes=[(0, 0.9955035971223022), (2, 0.004196642685851319), (1, 0.00029976019184652276)]
# Creating Child Node With ClassLabel=1, nexamples=90, classes=[(1, 1.0)]
# Creating Left Child Node With 10014 Examples, and Right Node with 2315 Examples
# Creating Child Node With ClassLabel=2, nexamples=10014, classes=[(2, 0.6785500299580587), (1, 0.24505692031156381), (0, 0.07639304973037747)]
# Creating Child Node With ClassLabel=0, nexamples=2315, classes=[(0, 0.9334773218142549), (2, 0.06652267818574514)]
# Creating Left Child Node With 4014 Examples, and Right Node with 1643 Examples
# Creating Left Child Node With 1385 Examples, and Right Node with 2629 Examples
# Creating Child Node With ClassLabel=0, nexamples=1385, classes=[(0, 0.8122743682310469), (1, 0.18772563176895307)]
# Creating Child Node With ClassLabel=0, nexamples=2629, classes=[(0, 0.99771776340814), (1, 0.002282236591860023)]
# Creating Child Node With ClassLabel=1, nexamples=1643, classes=[(1, 1.0)]
#
# Creating tree # 14
# Creating Left Child Node With 5084 Examples, and Right Node with 24916 Examples
# Creating Left Child Node With 4406 Examples, and Right Node with 678 Examples
# Creating Left Child Node With 209 Examples, and Right Node with 4197 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 209 Examples
# Creating Child Node With ClassLabel=0, nexamples=209, classes=[(0, 0.8899521531100478), (2, 0.11004784688995216)]
# Creating Left Child Node With 2979 Examples, and Right Node with 1218 Examples
# Creating Child Node With ClassLabel=2, nexamples=2979, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1218, classes=[(2, 0.9794745484400657), (0, 0.020525451559934318)]
# Creating Child Node With ClassLabel=0, nexamples=678, classes=[(0, 1.0)]
# Creating Left Child Node With 5476 Examples, and Right Node with 19440 Examples
# Creating Left Child Node With 2340 Examples, and Right Node with 3136 Examples
# Creating Left Child Node With 181 Examples, and Right Node with 2159 Examples
# Creating Child Node With ClassLabel=2, nexamples=181, classes=[(2, 0.569060773480663), (1, 0.430939226519337)]
# Creating Child Node With ClassLabel=1, nexamples=2159, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 3136 Examples
# Creating Child Node With ClassLabel=1, nexamples=3136, classes=[(1, 0.9996811224489796), (0, 0.00031887755102040814)]
# Creating Left Child Node With 14235 Examples, and Right Node with 5205 Examples
# Creating Left Child Node With 9926 Examples, and Right Node with 4309 Examples
# Creating Child Node With ClassLabel=2, nexamples=9926, classes=[(2, 0.5616562562965948), (0, 0.2472294982873262), (1, 0.191114245416079)]
# Creating Child Node With ClassLabel=0, nexamples=4309, classes=[(0, 0.9545138083081921), (2, 0.029473195637038756), (1, 0.016012996054769087)]
# Creating Left Child Node With 2544 Examples, and Right Node with 2661 Examples
# Creating Child Node With ClassLabel=1, nexamples=2544, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2661, classes=[(0, 0.9556557685080797), (1, 0.04434423149192033)]
#
# Creating tree # 15
# Creating Left Child Node With 5161 Examples, and Right Node with 24839 Examples
# Creating Left Child Node With 474 Examples, and Right Node with 4687 Examples
# Creating Child Node With ClassLabel=1, nexamples=474, classes=[(1, 1.0)]
# Creating Left Child Node With 3836 Examples, and Right Node with 851 Examples
# Creating Left Child Node With 958 Examples, and Right Node with 2878 Examples
# Creating Child Node With ClassLabel=0, nexamples=958, classes=[(0, 0.9989561586638831), (1, 0.0010438413361169101)]
# Creating Child Node With ClassLabel=0, nexamples=2878, classes=[(0, 0.9558721334259903), (2, 0.04412786657400973)]
# Creating Child Node With ClassLabel=0, nexamples=851, classes=[(0, 1.0)]
# Creating Left Child Node With 10804 Examples, and Right Node with 14035 Examples
# Creating Left Child Node With 4468 Examples, and Right Node with 6336 Examples
# Creating Left Child Node With 3697 Examples, and Right Node with 771 Examples
# Creating Child Node With ClassLabel=1, nexamples=3697, classes=[(1, 0.8328374357587233), (2, 0.1671625642412767)]
# Creating Child Node With ClassLabel=2, nexamples=771, classes=[(2, 1.0)]
# Creating Left Child Node With 1449 Examples, and Right Node with 4887 Examples
# Creating Child Node With ClassLabel=2, nexamples=1449, classes=[(2, 0.9503105590062112), (1, 0.049689440993788817)]
# Creating Child Node With ClassLabel=2, nexamples=4887, classes=[(2, 0.9093513402905669), (0, 0.09064865970943319)]
# Creating Left Child Node With 4728 Examples, and Right Node with 9307 Examples
# Creating Left Child Node With 1832 Examples, and Right Node with 2896 Examples
# Creating Child Node With ClassLabel=2, nexamples=1832, classes=[(2, 0.990174672489083), (0, 0.009279475982532752), (1, 0.0005458515283842794)]
# Creating Child Node With ClassLabel=1, nexamples=2896, classes=[(1, 0.42748618784530384), (0, 0.41609116022099446), (2, 0.15642265193370167)]
# Creating Left Child Node With 4418 Examples, and Right Node with 4889 Examples
# Creating Child Node With ClassLabel=1, nexamples=4418, classes=[(1, 0.9103666817564509), (2, 0.08963331824354911)]
# Creating Child Node With ClassLabel=0, nexamples=4889, classes=[(0, 0.7723460830435672), (1, 0.2276539169564328)]
#
# Creating tree # 16
# Creating Left Child Node With 19720 Examples, and Right Node with 10280 Examples
# Creating Left Child Node With 7891 Examples, and Right Node with 11829 Examples
# Creating Left Child Node With 5274 Examples, and Right Node with 2617 Examples
# Creating Left Child Node With 2278 Examples, and Right Node with 2996 Examples
# Creating Child Node With ClassLabel=1, nexamples=2278, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2996, classes=[(2, 0.9649532710280374), (1, 0.035046728971962614)]
# Creating Left Child Node With 2453 Examples, and Right Node with 164 Examples
# Creating Child Node With ClassLabel=1, nexamples=2453, classes=[(1, 0.9975540154912352), (2, 0.0024459845087647777)]
# Creating Child Node With ClassLabel=2, nexamples=164, classes=[(2, 1.0)]
# Creating Left Child Node With 9343 Examples, and Right Node with 2486 Examples
# Creating Left Child Node With 6262 Examples, and Right Node with 3081 Examples
# Creating Child Node With ClassLabel=0, nexamples=6262, classes=[(0, 0.6491536250399234), (2, 0.3208240178856595), (1, 0.030022357074417118)]
# Creating Child Node With ClassLabel=1, nexamples=3081, classes=[(1, 0.7633885102239533), (0, 0.23661148977604674)]
# Creating Left Child Node With 2465 Examples, and Right Node with 21 Examples
# Creating Child Node With ClassLabel=1, nexamples=2465, classes=[(1, 0.9983772819472616), (0, 0.0016227180527383367)]
# Creating Child Node With ClassLabel=2, nexamples=21, classes=[(2, 1.0)]
# Creating Left Child Node With 4618 Examples, and Right Node with 5662 Examples
# Creating Left Child Node With 4452 Examples, and Right Node with 166 Examples
# Creating Left Child Node With 1317 Examples, and Right Node with 3135 Examples
# Creating Child Node With ClassLabel=0, nexamples=1317, classes=[(0, 0.8701594533029613), (2, 0.12984054669703873)]
# Creating Child Node With ClassLabel=0, nexamples=3135, classes=[(0, 0.9837320574162679), (2, 0.01467304625199362), (1, 0.001594896331738437)]
# Creating Left Child Node With 164 Examples, and Right Node with 2 Examples
# Creating Child Node With ClassLabel=1, nexamples=164, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2, classes=[(0, 1.0)]
# Creating Left Child Node With 4978 Examples, and Right Node with 684 Examples
# Creating Left Child Node With 2402 Examples, and Right Node with 2576 Examples
# Creating Child Node With ClassLabel=2, nexamples=2402, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2576, classes=[(2, 0.8889751552795031), (0, 0.1110248447204969)]
# Creating Child Node With ClassLabel=0, nexamples=684, classes=[(0, 1.0)]
#
# Creating tree # 17
# Creating Left Child Node With 21318 Examples, and Right Node with 8682 Examples
# Creating Left Child Node With 12987 Examples, and Right Node with 8331 Examples
# Creating Left Child Node With 6654 Examples, and Right Node with 6333 Examples
# Creating Left Child Node With 2521 Examples, and Right Node with 4133 Examples
# Creating Child Node With ClassLabel=1, nexamples=2521, classes=[(1, 0.5077350257834192), (2, 0.4922649742165807)]
# Creating Child Node With ClassLabel=1, nexamples=4133, classes=[(1, 0.9983063150254052), (0, 0.0009678199854827002), (2, 0.0007258649891120251)]
# Creating Left Child Node With 0 Examples, and Right Node with 6333 Examples
# Creating Child Node With ClassLabel=1, nexamples=6333, classes=[(1, 0.4864992894362861), (0, 0.46565608716248225), (2, 0.04784462340123164)]
# Creating Left Child Node With 2295 Examples, and Right Node with 6036 Examples
# Creating Left Child Node With 2061 Examples, and Right Node with 234 Examples
# Creating Child Node With ClassLabel=1, nexamples=2061, classes=[(1, 0.7040271712760796), (0, 0.29597282872392044)]
# Creating Child Node With ClassLabel=0, nexamples=234, classes=[(0, 1.0)]
# Creating Left Child Node With 2158 Examples, and Right Node with 3878 Examples
# Creating Child Node With ClassLabel=0, nexamples=2158, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=3878, classes=[(2, 0.7929345023207839), (0, 0.19262506446621971), (1, 0.01444043321299639)]
# Creating Left Child Node With 2123 Examples, and Right Node with 6559 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 2117 Examples
# Creating Child Node With ClassLabel=1, nexamples=6, classes=[(1, 1.0)]
# Creating Left Child Node With 2071 Examples, and Right Node with 46 Examples
# Creating Child Node With ClassLabel=2, nexamples=2071, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=46, classes=[(2, 0.8695652173913043), (0, 0.13043478260869565)]
# Creating Left Child Node With 3636 Examples, and Right Node with 2923 Examples
# Creating Left Child Node With 444 Examples, and Right Node with 3192 Examples
# Creating Child Node With ClassLabel=2, nexamples=444, classes=[(2, 0.6306306306306306), (0, 0.36936936936936937)]
# Creating Child Node With ClassLabel=2, nexamples=3192, classes=[(2, 0.9357769423558897), (0, 0.06422305764411028)]
# Creating Child Node With ClassLabel=0, nexamples=2923, classes=[(0, 1.0)]
#
# Creating tree # 18
# Creating Left Child Node With 21957 Examples, and Right Node with 8043 Examples
# Creating Left Child Node With 6450 Examples, and Right Node with 15507 Examples
# Creating Left Child Node With 2838 Examples, and Right Node with 3612 Examples
# Creating Left Child Node With 1018 Examples, and Right Node with 1820 Examples
# Creating Child Node With ClassLabel=0, nexamples=1018, classes=[(0, 0.9990176817288802), (1, 0.0009823182711198428)]
# Creating Child Node With ClassLabel=1, nexamples=1820, classes=[(1, 0.8351648351648352), (0, 0.16483516483516483)]
# Creating Left Child Node With 3364 Examples, and Right Node with 248 Examples
# Creating Child Node With ClassLabel=1, nexamples=3364, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=248, classes=[(2, 0.6854838709677419), (1, 0.31451612903225806)]
# Creating Left Child Node With 9765 Examples, and Right Node with 5742 Examples
# Creating Left Child Node With 2305 Examples, and Right Node with 7460 Examples
# Creating Child Node With ClassLabel=0, nexamples=2305, classes=[(0, 0.975704989154013), (2, 0.02212581344902386), (1, 0.0021691973969631237)]
# Creating Child Node With ClassLabel=0, nexamples=7460, classes=[(0, 0.4931635388739946), (2, 0.4816353887399464), (1, 0.02520107238605898)]
# Creating Left Child Node With 680 Examples, and Right Node with 5062 Examples
# Creating Child Node With ClassLabel=2, nexamples=680, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=5062, classes=[(1, 0.9555511655472145), (2, 0.043658632951402605), (0, 0.0007902015013828526)]
# Creating Left Child Node With 5403 Examples, and Right Node with 2640 Examples
# Creating Left Child Node With 4656 Examples, and Right Node with 747 Examples
# Creating Left Child Node With 1218 Examples, and Right Node with 3438 Examples
# Creating Child Node With ClassLabel=2, nexamples=1218, classes=[(2, 0.9942528735632183), (1, 0.005747126436781609)]
# Creating Child Node With ClassLabel=2, nexamples=3438, classes=[(2, 0.9927283304246655), (0, 0.007271669575334497)]
# Creating Left Child Node With 540 Examples, and Right Node with 207 Examples
# Creating Child Node With ClassLabel=2, nexamples=540, classes=[(2, 0.9722222222222222), (0, 0.027777777777777776)]
# Creating Child Node With ClassLabel=0, nexamples=207, classes=[(0, 1.0)]
# Creating Left Child Node With 1401 Examples, and Right Node with 1239 Examples
# Creating Left Child Node With 130 Examples, and Right Node with 1271 Examples
# Creating Child Node With ClassLabel=2, nexamples=130, classes=[(2, 0.9769230769230769), (0, 0.023076923076923078)]
# Creating Child Node With ClassLabel=0, nexamples=1271, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1239 Examples
# Creating Child Node With ClassLabel=0, nexamples=1239, classes=[(0, 0.9927360774818402), (2, 0.007263922518159807)]
#
# Creating tree # 19
# Creating Left Child Node With 9367 Examples, and Right Node with 20633 Examples
# Creating Left Child Node With 2439 Examples, and Right Node with 6928 Examples
# Creating Left Child Node With 2421 Examples, and Right Node with 18 Examples
# Creating Left Child Node With 649 Examples, and Right Node with 1772 Examples
# Creating Child Node With ClassLabel=2, nexamples=649, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=1772, classes=[(2, 0.9475169300225733), (0, 0.05248306997742664)]
# Creating Child Node With ClassLabel=0, nexamples=18, classes=[(0, 1.0)]
# Creating Left Child Node With 3293 Examples, and Right Node with 3635 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3293 Examples
# Creating Child Node With ClassLabel=1, nexamples=3293, classes=[(1, 0.9996963255390222), (0, 0.0003036744609778318)]
# Creating Left Child Node With 3013 Examples, and Right Node with 622 Examples
# Creating Child Node With ClassLabel=1, nexamples=3013, classes=[(1, 0.6903418519747759), (2, 0.309658148025224)]
# Creating Child Node With ClassLabel=2, nexamples=622, classes=[(2, 1.0)]
# Creating Left Child Node With 17027 Examples, and Right Node with 3606 Examples
# Creating Left Child Node With 4081 Examples, and Right Node with 12946 Examples
# Creating Left Child Node With 208 Examples, and Right Node with 3873 Examples
# Creating Child Node With ClassLabel=0, nexamples=208, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=3873, classes=[(0, 0.9935450555125226), (2, 0.006454944487477408)]
# Creating Left Child Node With 4540 Examples, and Right Node with 8406 Examples
# Creating Child Node With ClassLabel=0, nexamples=4540, classes=[(0, 0.8506607929515418), (2, 0.14933920704845816)]
# Creating Child Node With ClassLabel=2, nexamples=8406, classes=[(2, 0.6440637639781108), (1, 0.2256721389483702), (0, 0.1302640970735189)]
# Creating Left Child Node With 367 Examples, and Right Node with 3239 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 367 Examples
# Creating Child Node With ClassLabel=0, nexamples=367, classes=[(0, 0.8119891008174387), (1, 0.1880108991825613)]
# Creating Left Child Node With 2544 Examples, and Right Node with 695 Examples
# Creating Child Node With ClassLabel=1, nexamples=2544, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=695, classes=[(0, 0.8302158273381295), (1, 0.1697841726618705)]
#
# Creating tree # 20
# Creating Left Child Node With 22496 Examples, and Right Node with 7504 Examples
# Creating Left Child Node With 6928 Examples, and Right Node with 15568 Examples
# Creating Left Child Node With 1452 Examples, and Right Node with 5476 Examples
# Creating Child Node With ClassLabel=2, nexamples=1452, classes=[(2, 1.0)]
# Creating Left Child Node With 955 Examples, and Right Node with 4521 Examples
# Creating Child Node With ClassLabel=1, nexamples=955, classes=[(1, 0.8921465968586387), (2, 0.10785340314136126)]
# Creating Child Node With ClassLabel=1, nexamples=4521, classes=[(1, 0.9997788099977881), (0, 0.00022119000221190003)]
# Creating Left Child Node With 4532 Examples, and Right Node with 11036 Examples
# Creating Left Child Node With 1429 Examples, and Right Node with 3103 Examples
# Creating Child Node With ClassLabel=0, nexamples=1429, classes=[(0, 0.9965010496850945), (1, 0.0034989503149055285)]
# Creating Child Node With ClassLabel=1, nexamples=3103, classes=[(1, 0.8694811472768289), (0, 0.13051885272317112)]
# Creating Left Child Node With 6841 Examples, and Right Node with 4195 Examples
# Creating Child Node With ClassLabel=2, nexamples=6841, classes=[(2, 0.554304926180383), (0, 0.4446718316035667), (1, 0.001023242216050285)]
# Creating Child Node With ClassLabel=0, nexamples=4195, classes=[(0, 0.5117997616209774), (1, 0.4572109654350417), (2, 0.03098927294398093)]
# Creating Left Child Node With 3884 Examples, and Right Node with 3620 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 3884 Examples
# Creating Left Child Node With 1564 Examples, and Right Node with 2320 Examples
# Creating Child Node With ClassLabel=2, nexamples=1564, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=2320, classes=[(2, 0.9892241379310345), (0, 0.010775862068965518)]
# Creating Left Child Node With 865 Examples, and Right Node with 2755 Examples
# Creating Left Child Node With 623 Examples, and Right Node with 242 Examples
# Creating Child Node With ClassLabel=2, nexamples=623, classes=[(2, 0.5393258426966292), (0, 0.4606741573033708)]
# Creating Child Node With ClassLabel=2, nexamples=242, classes=[(2, 1.0)]
# Creating Left Child Node With 611 Examples, and Right Node with 2144 Examples
# Creating Child Node With ClassLabel=0, nexamples=611, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=2144, classes=[(0, 0.9598880597014925), (2, 0.04011194029850746)]

# %%
#Training Confusion Matrix
Yp=rfc.predict(X)
print (Y.shape, len(Yp))
t.print_confusion_matrix(Yp,Y)
# Out:
# (30000,) 30000
# Predicted      0     1     2    All
# Actual
# 0           9889     5   106  10000
# 1            192  9805     3  10000
# 2            221     7  9772  10000
# All        10302  9817  9881  30000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Yp))
tlabels = pd.Series(np.squeeze(Y))
acc = np.sum(tlabels == plabels) / len(Y)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.9822

# %%
#Testing Confusion Matrix
Ypt=rfc.predict(Xtest)
print (Ytest.shape, len(Ypt))
t.print_confusion_matrix(Ypt,Ytest)
# Out:
# (15000,) 15000
# Predicted     0     1     2    All
# Actual
# 0          4957     2    41   5000
# 1           100  4900     0   5000
# 2           113     1  4886   5000
# All        5170  4903  4927  15000

# %%
from nose.tools import assert_greater_equal
plabels = pd.Series(np.squeeze(Ypt))
tlabels = pd.Series(np.squeeze(Ytest))
acc = np.sum(tlabels == plabels) / len(Ytest)
print(acc)
assert_greater_equal(acc, 0.78)
# Out:
# 0.9828666666666667

# %%
t.plot_points_range(rfc,X,Y)
# Out:
# (10000, 2)
# [0, 1, 2]

# %%
t.plot_decision_regions(X,Y,rfc,res=0.1)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ### Lets Plot Per-Tree Decision Boundary

# %%
ntrees=rfc.ntrees
nrows=int(ntrees/2)
ncols=2
i=1
plt.subplots(nrows,ncols,figsize=(16,40))
for tree in rfc.trees:
    plt.subplot(nrows,ncols,i);
    t.plot_decision_regions(X,Y,clf=tree,res=0.1);
    plt.title('Tree #{}'.format(i))
    i=i+1
plt.tight_layout
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# <function matplotlib.pyplot.tight_layout>

# %% [markdown]
# ## TODO: Find Optimal Number of Trees for this data set, using cross validation...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, V_train, Y_train, V_test = train_test_split(X, Y, train_size=0.8)
print(X_train.shape, V_train.shape, Y_train.shape, V_test.shape)
# Out:
# (24000, 2) (6000, 2) (24000,) (6000,)

# %%
rfc = rf.RandomForest(weaklearner="Linear", usebagging= True)
rfc.train(X_train,Y_train, V_train, V_test)
# rfc.train(X_train,Y_train)
# Out:
# Creating Classifier with 10 trees.
# Accuracy of Classifier with 10 trees is 97.51666666666667.
# Creating Classifier with 12 trees.
# Accuracy of Classifier with 12 trees is 95.38333333333333.
# Creating Classifier with 14 trees.
# Accuracy of Classifier with 14 trees is 96.39999999999999.
# Creating Classifier with 16 trees.
# Accuracy of Classifier with 16 trees is 94.08333333333333.
# Creating Classifier with 18 trees.
# Accuracy of Classifier with 18 trees is 96.0.
# Creating Classifier with 20 trees.
# Accuracy of Classifier with 20 trees is 95.75.
# Creating Classifier with 22 trees.
# Accuracy of Classifier with 22 trees is 98.01666666666667.
# Creating Classifier with 24 trees.
# Accuracy of Classifier with 24 trees is 98.05.
# Creating Classifier with 26 trees.
# Accuracy of Classifier with 26 trees is 96.38333333333333.
# Creating Classifier with 28 trees.
# Accuracy of Classifier with 28 trees is 90.26666666666667.
# Creating Classifier with 30 trees.
# Accuracy of Classifier with 30 trees is 97.15.
# Validation Comple. Optimal Parameters: Trees =  24 with Accuracy 0.9805
#
# Building Classifier
#
# Creating tree # 1
# Creating Left Child Node With 4187 Examples, and Right Node with 10213 Examples
# Creating Left Child Node With 1570 Examples, and Right Node with 2617 Examples
# Creating Left Child Node With 1159 Examples, and Right Node with 411 Examples
# Creating Left Child Node With 895 Examples, and Right Node with 264 Examples
# Creating Child Node With ClassLabel=0, nexamples=895, classes=[(0, 0.6402234636871509), (2, 0.35977653631284917)]
# Creating Child Node With ClassLabel=0, nexamples=264, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 411 Examples
# Creating Child Node With ClassLabel=0, nexamples=411, classes=[(0, 0.9635036496350365), (2, 0.0364963503649635)]
# Creating Left Child Node With 937 Examples, and Right Node with 1680 Examples
# Creating Left Child Node With 761 Examples, and Right Node with 176 Examples
# Creating Child Node With ClassLabel=2, nexamples=761, classes=[(2, 0.988173455978975), (1, 0.011826544021024968)]
# Creating Child Node With ClassLabel=1, nexamples=176, classes=[(1, 0.7272727272727273), (2, 0.2727272727272727)]
# Creating Left Child Node With 1680 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=1680, classes=[(2, 0.9940476190476191), (0, 0.005952380952380952)]
# Creating Left Child Node With 2596 Examples, and Right Node with 7617 Examples
# Creating Left Child Node With 2462 Examples, and Right Node with 134 Examples
# Creating Left Child Node With 67 Examples, and Right Node with 2395 Examples
# Creating Child Node With ClassLabel=2, nexamples=67, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=2395, classes=[(1, 0.9987473903966597), (0, 0.0008350730688935282), (2, 0.0004175365344467641)]
# Creating Child Node With ClassLabel=2, nexamples=134, classes=[(2, 1.0)]
# Creating Left Child Node With 3932 Examples, and Right Node with 3685 Examples
# Creating Left Child Node With 1835 Examples, and Right Node with 2097 Examples
# Creating Child Node With ClassLabel=2, nexamples=1835, classes=[(2, 0.9286103542234332), (0, 0.0561307901907357), (1, 0.015258855585831062)]
# Creating Child Node With ClassLabel=0, nexamples=2097, classes=[(0, 0.9375298044825942), (1, 0.05913209346685742), (2, 0.0033381020505484026)]
# Creating Left Child Node With 2881 Examples, and Right Node with 804 Examples
# Creating Child Node With ClassLabel=0, nexamples=2881, classes=[(0, 0.48767788962165914), (1, 0.46129816036098575), (2, 0.05102395001735509)]
# Creating Child Node With ClassLabel=1, nexamples=804, classes=[(1, 1.0)]
#
# Creating tree # 2
# Creating Left Child Node With 11956 Examples, and Right Node with 2444 Examples
# Creating Left Child Node With 2351 Examples, and Right Node with 9605 Examples
# Creating Left Child Node With 567 Examples, and Right Node with 1784 Examples
# Creating Child Node With ClassLabel=1, nexamples=567, classes=[(1, 1.0)]
# Creating Left Child Node With 809 Examples, and Right Node with 975 Examples
# Creating Child Node With ClassLabel=1, nexamples=809, classes=[(1, 0.9456118665018541), (2, 0.054388133498145856)]
# Creating Child Node With ClassLabel=1, nexamples=975, classes=[(1, 1.0)]
# Creating Left Child Node With 1202 Examples, and Right Node with 8403 Examples
# Creating Left Child Node With 1183 Examples, and Right Node with 19 Examples
# Creating Child Node With ClassLabel=1, nexamples=1183, classes=[(1, 0.9087066779374472), (0, 0.09129332206255283)]
# Creating Child Node With ClassLabel=0, nexamples=19, classes=[(0, 1.0)]
# Creating Left Child Node With 2666 Examples, and Right Node with 5737 Examples
# Creating Child Node With ClassLabel=0, nexamples=2666, classes=[(0, 0.4932483120780195), (1, 0.44973743435858965), (2, 0.05701425356339085)]
# Creating Child Node With ClassLabel=0, nexamples=5737, classes=[(0, 0.5128115739933763), (2, 0.4554645284992156), (1, 0.031723897507408054)]
# Creating Left Child Node With 694 Examples, and Right Node with 1750 Examples
# Creating Left Child Node With 68 Examples, and Right Node with 626 Examples
# Creating Child Node With ClassLabel=2, nexamples=68, classes=[(2, 1.0)]
# Creating Left Child Node With 172 Examples, and Right Node with 454 Examples
# Creating Child Node With ClassLabel=2, nexamples=172, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=454, classes=[(0, 0.9096916299559471), (2, 0.09030837004405286)]
# Creating Child Node With ClassLabel=2, nexamples=1750, classes=[(2, 1.0)]
#
# Creating tree # 3
# Creating Left Child Node With 10281 Examples, and Right Node with 4119 Examples
# Creating Left Child Node With 3232 Examples, and Right Node with 7049 Examples
# Creating Left Child Node With 1381 Examples, and Right Node with 1851 Examples
# Creating Left Child Node With 735 Examples, and Right Node with 646 Examples
# Creating Child Node With ClassLabel=1, nexamples=735, classes=[(1, 0.8938775510204081), (0, 0.10612244897959183)]
# Creating Child Node With ClassLabel=0, nexamples=646, classes=[(0, 0.5619195046439629), (1, 0.43808049535603716)]
# Creating Left Child Node With 947 Examples, and Right Node with 904 Examples
# Creating Child Node With ClassLabel=0, nexamples=947, classes=[(0, 0.955649419218585), (1, 0.044350580781414996)]
# Creating Child Node With ClassLabel=0, nexamples=904, classes=[(0, 0.995575221238938), (2, 0.004424778761061947)]
# Creating Left Child Node With 2730 Examples, and Right Node with 4319 Examples
# Creating Left Child Node With 1942 Examples, and Right Node with 788 Examples
# Creating Child Node With ClassLabel=0, nexamples=1942, classes=[(0, 0.782183316168898), (2, 0.17353244078269825), (1, 0.044284243048403706)]
# Creating Child Node With ClassLabel=1, nexamples=788, classes=[(1, 0.9911167512690355), (0, 0.008883248730964468)]
# Creating Left Child Node With 3422 Examples, and Right Node with 897 Examples
# Creating Child Node With ClassLabel=2, nexamples=3422, classes=[(2, 0.8731735827001753), (1, 0.09994155464640561), (0, 0.026884862653419054)]
# Creating Child Node With ClassLabel=0, nexamples=897, classes=[(0, 1.0)]
# Creating Left Child Node With 2462 Examples, and Right Node with 1657 Examples
# Creating Left Child Node With 10 Examples, and Right Node with 2452 Examples
# Creating Child Node With ClassLabel=2, nexamples=10, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 2452 Examples
# Creating Child Node With ClassLabel=1, nexamples=2452, classes=[(1, 0.9995921696574225), (0, 0.0004078303425774878)]
# Creating Left Child Node With 946 Examples, and Right Node with 711 Examples
# Creating Left Child Node With 12 Examples, and Right Node with 934 Examples
# Creating Child Node With ClassLabel=1, nexamples=12, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=934, classes=[(2, 0.9978586723768736), (0, 0.0010706638115631692), (1, 0.0010706638115631692)]
# Creating Left Child Node With 258 Examples, and Right Node with 453 Examples
# Creating Child Node With ClassLabel=1, nexamples=258, classes=[(1, 0.8527131782945736), (2, 0.14728682170542637)]
# Creating Child Node With ClassLabel=2, nexamples=453, classes=[(2, 1.0)]
#
# Creating tree # 4
# Creating Left Child Node With 4460 Examples, and Right Node with 9940 Examples
# Creating Left Child Node With 3124 Examples, and Right Node with 1336 Examples
# Creating Left Child Node With 2707 Examples, and Right Node with 417 Examples
# Creating Left Child Node With 734 Examples, and Right Node with 1973 Examples
# Creating Child Node With ClassLabel=2, nexamples=734, classes=[(2, 0.9427792915531336), (1, 0.05722070844686648)]
# Creating Child Node With ClassLabel=2, nexamples=1973, classes=[(2, 1.0)]
# Creating Left Child Node With 49 Examples, and Right Node with 368 Examples
# Creating Child Node With ClassLabel=2, nexamples=49, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=368, classes=[(0, 0.9402173913043478), (2, 0.059782608695652176)]
# Creating Left Child Node With 485 Examples, and Right Node with 851 Examples
# Creating Child Node With ClassLabel=0, nexamples=485, classes=[(0, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 851 Examples
# Creating Child Node With ClassLabel=0, nexamples=851, classes=[(0, 0.9012925969447708), (2, 0.09870740305522914)]
# Creating Left Child Node With 3148 Examples, and Right Node with 6792 Examples
# Creating Left Child Node With 1740 Examples, and Right Node with 1408 Examples
# Creating Left Child Node With 757 Examples, and Right Node with 983 Examples
# Creating Child Node With ClassLabel=1, nexamples=757, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=983, classes=[(2, 0.5584944048830112), (1, 0.44150559511698884)]
# Creating Left Child Node With 1085 Examples, and Right Node with 323 Examples
# Creating Child Node With ClassLabel=1, nexamples=1085, classes=[(1, 0.9935483870967742), (0, 0.0064516129032258064)]
# Creating Child Node With ClassLabel=1, nexamples=323, classes=[(1, 0.9969040247678018), (2, 0.0030959752321981426)]
# Creating Left Child Node With 1922 Examples, and Right Node with 4870 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1922 Examples
# Creating Child Node With ClassLabel=1, nexamples=1922, classes=[(1, 0.9984391259105099), (0, 0.0015608740894901144)]
# Creating Left Child Node With 1300 Examples, and Right Node with 3570 Examples
# Creating Child Node With ClassLabel=0, nexamples=1300, classes=[(0, 0.8992307692307693), (1, 0.10076923076923076)]
# Creating Child Node With ClassLabel=0, nexamples=3570, classes=[(0, 0.5579831932773109), (2, 0.42016806722689076), (1, 0.021848739495798318)]
#
# Creating tree # 5
# Creating Left Child Node With 10437 Examples, and Right Node with 3963 Examples
# Creating Left Child Node With 6507 Examples, and Right Node with 3930 Examples
# Creating Left Child Node With 4939 Examples, and Right Node with 1568 Examples
# Creating Left Child Node With 2938 Examples, and Right Node with 2001 Examples
# Creating Child Node With ClassLabel=1, nexamples=2938, classes=[(1, 0.7896528250510552), (2, 0.2079646017699115), (0, 0.002382573179033356)]
# Creating Child Node With ClassLabel=0, nexamples=2001, classes=[(0, 0.5902048975512244), (1, 0.23888055972013994), (2, 0.17091454272863568)]
# Creating Left Child Node With 585 Examples, and Right Node with 983 Examples
# Creating Child Node With ClassLabel=2, nexamples=585, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=983, classes=[(2, 0.671414038657172), (1, 0.3285859613428281)]
# Creating Left Child Node With 2262 Examples, and Right Node with 1668 Examples
# Creating Left Child Node With 1449 Examples, and Right Node with 813 Examples
# Creating Child Node With ClassLabel=2, nexamples=1449, classes=[(2, 0.9993098688750862), (1, 0.0006901311249137336)]
# Creating Child Node With ClassLabel=2, nexamples=813, classes=[(2, 0.984009840098401), (0, 0.015990159901599015)]
# Creating Left Child Node With 1330 Examples, and Right Node with 338 Examples
# Creating Child Node With ClassLabel=0, nexamples=1330, classes=[(0, 0.7511278195488722), (2, 0.24887218045112783)]
# Creating Child Node With ClassLabel=0, nexamples=338, classes=[(0, 1.0)]
# Creating Left Child Node With 944 Examples, and Right Node with 3019 Examples
# Creating Left Child Node With 300 Examples, and Right Node with 644 Examples
# Creating Child Node With ClassLabel=0, nexamples=300, classes=[(0, 1.0)]
# Creating Left Child Node With 8 Examples, and Right Node with 636 Examples
# Creating Child Node With ClassLabel=0, nexamples=8, classes=[(0, 0.625), (2, 0.375)]
# Creating Child Node With ClassLabel=0, nexamples=636, classes=[(0, 0.9968553459119497), (1, 0.0031446540880503146)]
# Creating Left Child Node With 566 Examples, and Right Node with 2453 Examples
# Creating Left Child Node With 6 Examples, and Right Node with 560 Examples
# Creating Child Node With ClassLabel=1, nexamples=6, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=560, classes=[(0, 0.9553571428571429), (1, 0.04285714285714286), (2, 0.0017857142857142857)]
# Creating Left Child Node With 241 Examples, and Right Node with 2212 Examples
# Creating Child Node With ClassLabel=0, nexamples=241, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=2212, classes=[(1, 0.7495479204339964), (0, 0.2504520795660036)]
#
# Creating tree # 6
# Creating Left Child Node With 10508 Examples, and Right Node with 3892 Examples
# Creating Left Child Node With 2212 Examples, and Right Node with 8296 Examples
# Creating Left Child Node With 655 Examples, and Right Node with 1557 Examples
# Creating Left Child Node With 183 Examples, and Right Node with 472 Examples
# Creating Child Node With ClassLabel=0, nexamples=183, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=472, classes=[(1, 0.7033898305084746), (0, 0.2966101694915254)]
# Creating Left Child Node With 84 Examples, and Right Node with 1473 Examples
# Creating Child Node With ClassLabel=1, nexamples=84, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1473, classes=[(0, 1.0)]
# Creating Left Child Node With 1319 Examples, and Right Node with 6977 Examples
# Creating Child Node With ClassLabel=0, nexamples=1319, classes=[(0, 1.0)]
# Creating Left Child Node With 5868 Examples, and Right Node with 1109 Examples
# Creating Child Node With ClassLabel=2, nexamples=5868, classes=[(2, 0.6382072256305386), (1, 0.26397409679618267), (0, 0.0978186775732788)]
# Creating Child Node With ClassLabel=0, nexamples=1109, classes=[(0, 0.9287646528403968), (2, 0.07123534715960325)]
# Creating Left Child Node With 3210 Examples, and Right Node with 682 Examples
# Creating Left Child Node With 2953 Examples, and Right Node with 257 Examples
# Creating Left Child Node With 679 Examples, and Right Node with 2274 Examples
# Creating Child Node With ClassLabel=1, nexamples=679, classes=[(1, 0.8689248895434463), (0, 0.13107511045655376)]
# Creating Child Node With ClassLabel=1, nexamples=2274, classes=[(1, 0.9991204925241864), (0, 0.0008795074758135445)]
# Creating Child Node With ClassLabel=2, nexamples=257, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=682, classes=[(2, 1.0)]
#
# Creating tree # 7
# Creating Left Child Node With 12300 Examples, and Right Node with 2100 Examples
# Creating Left Child Node With 6142 Examples, and Right Node with 6158 Examples
# Creating Left Child Node With 1937 Examples, and Right Node with 4205 Examples
# Creating Left Child Node With 1251 Examples, and Right Node with 686 Examples
# Creating Child Node With ClassLabel=0, nexamples=1251, classes=[(0, 0.996802557953637), (2, 0.0031974420463629096)]
# Creating Child Node With ClassLabel=0, nexamples=686, classes=[(0, 0.9693877551020408), (1, 0.030612244897959183)]
# Creating Left Child Node With 1750 Examples, and Right Node with 2455 Examples
# Creating Child Node With ClassLabel=0, nexamples=1750, classes=[(0, 0.9474285714285714), (2, 0.052571428571428575)]
# Creating Child Node With ClassLabel=2, nexamples=2455, classes=[(2, 0.9372708757637475), (0, 0.06232179226069246), (1, 0.0004073319755600815)]
# Creating Left Child Node With 5228 Examples, and Right Node with 930 Examples
# Creating Left Child Node With 3819 Examples, and Right Node with 1409 Examples
# Creating Child Node With ClassLabel=1, nexamples=3819, classes=[(1, 0.6755695208169678), (2, 0.32312123592563496), (0, 0.0013092432573972245)]
# Creating Child Node With ClassLabel=2, nexamples=1409, classes=[(2, 0.7821149751596878), (0, 0.21788502484031227)]
# Creating Left Child Node With 0 Examples, and Right Node with 930 Examples
# Creating Child Node With ClassLabel=0, nexamples=930, classes=[(0, 0.843010752688172), (1, 0.12043010752688173), (2, 0.03655913978494624)]
# Creating Left Child Node With 1615 Examples, and Right Node with 485 Examples
# Creating Child Node With ClassLabel=1, nexamples=1615, classes=[(1, 1.0)]
# Creating Left Child Node With 21 Examples, and Right Node with 464 Examples
# Creating Child Node With ClassLabel=2, nexamples=21, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=464, classes=[(1, 1.0)]
#
# Creating tree # 8
# Creating Left Child Node With 9581 Examples, and Right Node with 4819 Examples
# Creating Left Child Node With 6374 Examples, and Right Node with 3207 Examples
# Creating Left Child Node With 5598 Examples, and Right Node with 776 Examples
# Creating Left Child Node With 4981 Examples, and Right Node with 617 Examples
# Creating Child Node With ClassLabel=0, nexamples=4981, classes=[(0, 0.5777956233688014), (2, 0.2525597269624573), (1, 0.1696446496687412)]
# Creating Child Node With ClassLabel=1, nexamples=617, classes=[(1, 0.9902755267423015), (0, 0.009724473257698542)]
# Creating Child Node With ClassLabel=1, nexamples=776, classes=[(1, 1.0)]
# Creating Left Child Node With 2191 Examples, and Right Node with 1016 Examples
# Creating Child Node With ClassLabel=1, nexamples=2191, classes=[(1, 1.0)]
# Creating Left Child Node With 255 Examples, and Right Node with 761 Examples
# Creating Child Node With ClassLabel=1, nexamples=255, classes=[(1, 0.9921568627450981), (2, 0.00784313725490196)]
# Creating Child Node With ClassLabel=2, nexamples=761, classes=[(2, 0.9172141918528253), (1, 0.08278580814717477)]
# Creating Left Child Node With 1584 Examples, and Right Node with 3235 Examples
# Creating Left Child Node With 1067 Examples, and Right Node with 517 Examples
# Creating Left Child Node With 757 Examples, and Right Node with 310 Examples
# Creating Child Node With ClassLabel=0, nexamples=757, classes=[(0, 0.9788639365918098), (2, 0.021136063408190225)]
# Creating Child Node With ClassLabel=0, nexamples=310, classes=[(0, 0.7483870967741936), (2, 0.25161290322580643)]
# Creating Child Node With ClassLabel=0, nexamples=517, classes=[(0, 1.0)]
# Creating Left Child Node With 2503 Examples, and Right Node with 732 Examples
# Creating Left Child Node With 952 Examples, and Right Node with 1551 Examples
# Creating Child Node With ClassLabel=2, nexamples=952, classes=[(2, 0.9663865546218487), (1, 0.03361344537815126)]
# Creating Child Node With ClassLabel=2, nexamples=1551, classes=[(2, 0.9896840747904577), (0, 0.010315925209542231)]
# Creating Left Child Node With 262 Examples, and Right Node with 470 Examples
# Creating Child Node With ClassLabel=2, nexamples=262, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=470, classes=[(0, 0.9127659574468086), (2, 0.08723404255319149)]
#
# Creating tree # 9
# Creating Left Child Node With 9616 Examples, and Right Node with 4784 Examples
# Creating Left Child Node With 5299 Examples, and Right Node with 4317 Examples
# Creating Left Child Node With 1481 Examples, and Right Node with 3818 Examples
# Creating Left Child Node With 176 Examples, and Right Node with 1305 Examples
# Creating Child Node With ClassLabel=2, nexamples=176, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1305, classes=[(1, 0.9632183908045977), (2, 0.0367816091954023)]
# Creating Left Child Node With 1888 Examples, and Right Node with 1930 Examples
# Creating Child Node With ClassLabel=0, nexamples=1888, classes=[(0, 0.8432203389830508), (1, 0.1541313559322034), (2, 0.0026483050847457626)]
# Creating Child Node With ClassLabel=1, nexamples=1930, classes=[(1, 0.6989637305699482), (0, 0.3010362694300518)]
# Creating Left Child Node With 1602 Examples, and Right Node with 2715 Examples
# Creating Left Child Node With 792 Examples, and Right Node with 810 Examples
# Creating Child Node With ClassLabel=0, nexamples=792, classes=[(0, 0.4633838383838384), (2, 0.4431818181818182), (1, 0.09343434343434344)]
# Creating Child Node With ClassLabel=2, nexamples=810, classes=[(2, 0.9938271604938271), (0, 0.006172839506172839)]
# Creating Left Child Node With 1931 Examples, and Right Node with 784 Examples
# Creating Child Node With ClassLabel=1, nexamples=1931, classes=[(1, 0.9580528223718281), (2, 0.038839979285344384), (0, 0.0031071983428275505)]
# Creating Child Node With ClassLabel=2, nexamples=784, classes=[(2, 1.0)]
# Creating Left Child Node With 2649 Examples, and Right Node with 2135 Examples
# Creating Left Child Node With 1445 Examples, and Right Node with 1204 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1445 Examples
# Creating Child Node With ClassLabel=2, nexamples=1445, classes=[(2, 0.9993079584775086), (1, 0.0006920415224913495)]
# Creating Left Child Node With 1095 Examples, and Right Node with 109 Examples
# Creating Child Node With ClassLabel=2, nexamples=1095, classes=[(2, 0.989041095890411), (0, 0.010958904109589041)]
# Creating Child Node With ClassLabel=0, nexamples=109, classes=[(0, 1.0)]
# Creating Left Child Node With 691 Examples, and Right Node with 1444 Examples
# Creating Left Child Node With 5 Examples, and Right Node with 686 Examples
# Creating Child Node With ClassLabel=1, nexamples=5, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=686, classes=[(0, 0.9985422740524781), (1, 0.0014577259475218659)]
# Creating Left Child Node With 278 Examples, and Right Node with 1166 Examples
# Creating Child Node With ClassLabel=0, nexamples=278, classes=[(0, 0.7338129496402878), (2, 0.26618705035971224)]
# Creating Child Node With ClassLabel=0, nexamples=1166, classes=[(0, 0.9974271012006861), (2, 0.002572898799313894)]
#
# Creating tree # 10
# Creating Left Child Node With 3925 Examples, and Right Node with 10475 Examples
# Creating Left Child Node With 1870 Examples, and Right Node with 2055 Examples
# Creating Left Child Node With 1575 Examples, and Right Node with 295 Examples
# Creating Left Child Node With 885 Examples, and Right Node with 690 Examples
# Creating Child Node With ClassLabel=0, nexamples=885, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=690, classes=[(0, 0.8115942028985508), (1, 0.18840579710144928)]
# Creating Left Child Node With 0 Examples, and Right Node with 295 Examples
# Creating Child Node With ClassLabel=1, nexamples=295, classes=[(1, 0.9694915254237289), (0, 0.030508474576271188)]
# Creating Left Child Node With 30 Examples, and Right Node with 2025 Examples
# Creating Child Node With ClassLabel=2, nexamples=30, classes=[(2, 1.0)]
# Creating Left Child Node With 426 Examples, and Right Node with 1599 Examples
# Creating Child Node With ClassLabel=1, nexamples=426, classes=[(1, 0.8004694835680751), (0, 0.19953051643192488)]
# Creating Child Node With ClassLabel=1, nexamples=1599, classes=[(1, 1.0)]
# Creating Left Child Node With 1895 Examples, and Right Node with 8580 Examples
# Creating Left Child Node With 358 Examples, and Right Node with 1537 Examples
# Creating Left Child Node With 109 Examples, and Right Node with 249 Examples
# Creating Child Node With ClassLabel=2, nexamples=109, classes=[(2, 0.7431192660550459), (0, 0.25688073394495414)]
# Creating Child Node With ClassLabel=0, nexamples=249, classes=[(0, 1.0)]
# Creating Left Child Node With 1445 Examples, and Right Node with 92 Examples
# Creating Child Node With ClassLabel=0, nexamples=1445, classes=[(0, 0.9826989619377162), (2, 0.01730103806228374)]
# Creating Child Node With ClassLabel=0, nexamples=92, classes=[(0, 1.0)]
# Creating Left Child Node With 2830 Examples, and Right Node with 5750 Examples
# Creating Left Child Node With 2631 Examples, and Right Node with 199 Examples
# Creating Child Node With ClassLabel=2, nexamples=2631, classes=[(2, 0.9266438616495629), (0, 0.07107563664006081), (1, 0.002280501710376283)]
# Creating Child Node With ClassLabel=0, nexamples=199, classes=[(0, 1.0)]
# Creating Left Child Node With 4308 Examples, and Right Node with 1442 Examples
# Creating Child Node With ClassLabel=1, nexamples=4308, classes=[(1, 0.5766016713091922), (0, 0.24744661095636025), (2, 0.17595171773444754)]
# Creating Child Node With ClassLabel=2, nexamples=1442, classes=[(2, 0.9895977808599168), (0, 0.010402219140083218)]
#
# Creating tree # 11
# Creating Left Child Node With 10924 Examples, and Right Node with 3476 Examples
# Creating Left Child Node With 4945 Examples, and Right Node with 5979 Examples
# Creating Left Child Node With 2752 Examples, and Right Node with 2193 Examples
# Creating Left Child Node With 550 Examples, and Right Node with 2202 Examples
# Creating Child Node With ClassLabel=1, nexamples=550, classes=[(1, 0.7109090909090909), (2, 0.28909090909090907)]
# Creating Child Node With ClassLabel=1, nexamples=2202, classes=[(1, 0.9986376021798365), (0, 0.0013623978201634877)]
# Creating Left Child Node With 0 Examples, and Right Node with 2193 Examples
# Creating Child Node With ClassLabel=1, nexamples=2193, classes=[(1, 0.5056999544003647), (0, 0.4642042863657091), (2, 0.030095759233926128)]
# Creating Left Child Node With 2457 Examples, and Right Node with 3522 Examples
# Creating Left Child Node With 902 Examples, and Right Node with 1555 Examples
# Creating Child Node With ClassLabel=0, nexamples=902, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1555, classes=[(1, 0.7170418006430869), (0, 0.2829581993569132)]
# Creating Left Child Node With 2640 Examples, and Right Node with 882 Examples
# Creating Child Node With ClassLabel=2, nexamples=2640, classes=[(2, 0.7238636363636364), (0, 0.27386363636363636), (1, 0.0022727272727272726)]
# Creating Child Node With ClassLabel=0, nexamples=882, classes=[(0, 0.8208616780045351), (2, 0.17913832199546487)]
# Creating Left Child Node With 526 Examples, and Right Node with 2950 Examples
# Creating Child Node With ClassLabel=0, nexamples=526, classes=[(0, 1.0)]
# Creating Left Child Node With 1822 Examples, and Right Node with 1128 Examples
# Creating Left Child Node With 1794 Examples, and Right Node with 28 Examples
# Creating Child Node With ClassLabel=2, nexamples=1794, classes=[(2, 0.9827201783723523), (1, 0.00947603121516165), (0, 0.007803790412486065)]
# Creating Child Node With ClassLabel=0, nexamples=28, classes=[(0, 1.0)]
# Creating Left Child Node With 667 Examples, and Right Node with 461 Examples
# Creating Child Node With ClassLabel=2, nexamples=667, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=461, classes=[(0, 0.8828633405639913), (2, 0.11713665943600868)]
#
# Creating tree # 12
# Creating Left Child Node With 10513 Examples, and Right Node with 3887 Examples
# Creating Left Child Node With 8264 Examples, and Right Node with 2249 Examples
# Creating Left Child Node With 5980 Examples, and Right Node with 2284 Examples
# Creating Left Child Node With 2939 Examples, and Right Node with 3041 Examples
# Creating Child Node With ClassLabel=1, nexamples=2939, classes=[(1, 0.5076556651922423), (2, 0.2898945219462402), (0, 0.20244981286151753)]
# Creating Child Node With ClassLabel=2, nexamples=3041, classes=[(2, 0.875041104899704), (0, 0.10062479447550148), (1, 0.024334100624794474)]
# Creating Left Child Node With 972 Examples, and Right Node with 1312 Examples
# Creating Child Node With ClassLabel=0, nexamples=972, classes=[(0, 0.98559670781893), (2, 0.01440329218106996)]
# Creating Child Node With ClassLabel=0, nexamples=1312, classes=[(0, 0.7560975609756098), (2, 0.24390243902439024)]
# Creating Left Child Node With 316 Examples, and Right Node with 1933 Examples
# Creating Child Node With ClassLabel=1, nexamples=316, classes=[(1, 1.0)]
# Creating Left Child Node With 1829 Examples, and Right Node with 104 Examples
# Creating Child Node With ClassLabel=0, nexamples=1829, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=104, classes=[(1, 0.9423076923076923), (0, 0.057692307692307696)]
# Creating Left Child Node With 3360 Examples, and Right Node with 527 Examples
# Creating Left Child Node With 424 Examples, and Right Node with 2936 Examples
# Creating Child Node With ClassLabel=2, nexamples=424, classes=[(2, 1.0)]
# Creating Left Child Node With 1960 Examples, and Right Node with 976 Examples
# Creating Child Node With ClassLabel=1, nexamples=1960, classes=[(1, 0.9979591836734694), (2, 0.0020408163265306124)]
# Creating Child Node With ClassLabel=1, nexamples=976, classes=[(1, 0.889344262295082), (0, 0.11065573770491803)]
# Creating Child Node With ClassLabel=2, nexamples=527, classes=[(2, 1.0)]
#
# Creating tree # 13
# Creating Left Child Node With 4639 Examples, and Right Node with 9761 Examples
# Creating Left Child Node With 3195 Examples, and Right Node with 1444 Examples
# Creating Left Child Node With 2899 Examples, and Right Node with 296 Examples
# Creating Left Child Node With 4 Examples, and Right Node with 2895 Examples
# Creating Child Node With ClassLabel=1, nexamples=4, classes=[(1, 0.5), (2, 0.5)]
# Creating Child Node With ClassLabel=1, nexamples=2895, classes=[(1, 0.9837651122625216), (0, 0.01623488773747841)]
# Creating Left Child Node With 64 Examples, and Right Node with 232 Examples
# Creating Child Node With ClassLabel=1, nexamples=64, classes=[(1, 0.515625), (2, 0.484375)]
# Creating Child Node With ClassLabel=2, nexamples=232, classes=[(2, 0.9956896551724138), (0, 0.004310344827586207)]
# Creating Left Child Node With 1 Examples, and Right Node with 1443 Examples
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
# Creating Left Child Node With 1435 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=2, nexamples=1435, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=8, classes=[(0, 1.0)]
# Creating Left Child Node With 1887 Examples, and Right Node with 7874 Examples
# Creating Left Child Node With 1569 Examples, and Right Node with 318 Examples
# Creating Left Child Node With 1300 Examples, and Right Node with 269 Examples
# Creating Child Node With ClassLabel=1, nexamples=1300, classes=[(1, 0.5553846153846154), (0, 0.44461538461538463)]
# Creating Child Node With ClassLabel=1, nexamples=269, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=318, classes=[(0, 1.0)]
# Creating Left Child Node With 5612 Examples, and Right Node with 2262 Examples
# Creating Left Child Node With 2419 Examples, and Right Node with 3193 Examples
# Creating Child Node With ClassLabel=0, nexamples=2419, classes=[(0, 0.4183546920214965), (1, 0.364613476643241), (2, 0.2170318313352625)]
# Creating Child Node With ClassLabel=2, nexamples=3193, classes=[(2, 0.7964296899467586), (0, 0.20294393986846226), (1, 0.0006263701847792045)]
# Creating Left Child Node With 2247 Examples, and Right Node with 15 Examples
# Creating Child Node With ClassLabel=0, nexamples=2247, classes=[(0, 0.9737427681352915), (2, 0.0262572318647085)]
# Creating Child Node With ClassLabel=1, nexamples=15, classes=[(1, 1.0)]
#
# Creating tree # 14
# Creating Left Child Node With 12571 Examples, and Right Node with 1829 Examples
# Creating Left Child Node With 6530 Examples, and Right Node with 6041 Examples
# Creating Left Child Node With 2621 Examples, and Right Node with 3909 Examples
# Creating Left Child Node With 2529 Examples, and Right Node with 92 Examples
# Creating Child Node With ClassLabel=1, nexamples=2529, classes=[(1, 0.9513641755634639), (2, 0.04665875840253064), (0, 0.0019770660340055358)]
# Creating Child Node With ClassLabel=2, nexamples=92, classes=[(2, 1.0)]
# Creating Left Child Node With 835 Examples, and Right Node with 3074 Examples
# Creating Child Node With ClassLabel=2, nexamples=835, classes=[(2, 0.8383233532934131), (1, 0.16167664670658682)]
# Creating Child Node With ClassLabel=2, nexamples=3074, classes=[(2, 0.6782693558880937), (0, 0.3217306441119063)]
# Creating Left Child Node With 2346 Examples, and Right Node with 3695 Examples
# Creating Left Child Node With 2296 Examples, and Right Node with 50 Examples
# Creating Child Node With ClassLabel=0, nexamples=2296, classes=[(0, 0.8310104529616724), (1, 0.16898954703832753)]
# Creating Child Node With ClassLabel=1, nexamples=50, classes=[(1, 1.0)]
# Creating Left Child Node With 2275 Examples, and Right Node with 1420 Examples
# Creating Child Node With ClassLabel=2, nexamples=2275, classes=[(2, 0.7591208791208791), (0, 0.20527472527472526), (1, 0.03560439560439561)]
# Creating Child Node With ClassLabel=0, nexamples=1420, classes=[(0, 0.9774647887323944), (2, 0.02112676056338028), (1, 0.0014084507042253522)]
# Creating Left Child Node With 114 Examples, and Right Node with 1715 Examples
# Creating Child Node With ClassLabel=2, nexamples=114, classes=[(2, 1.0)]
# Creating Left Child Node With 1 Examples, and Right Node with 1714 Examples
# Creating Child Node With ClassLabel=2, nexamples=1, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1714, classes=[(1, 1.0)]
#
# Creating tree # 15
# Creating Left Child Node With 4765 Examples, and Right Node with 9635 Examples
# Creating Left Child Node With 3274 Examples, and Right Node with 1491 Examples
# Creating Left Child Node With 1864 Examples, and Right Node with 1410 Examples
# Creating Left Child Node With 1070 Examples, and Right Node with 794 Examples
# Creating Child Node With ClassLabel=0, nexamples=1070, classes=[(0, 0.997196261682243), (1, 0.001869158878504673), (2, 0.0009345794392523365)]
# Creating Child Node With ClassLabel=1, nexamples=794, classes=[(1, 0.8350125944584383), (0, 0.16498740554156172)]
# Creating Left Child Node With 1283 Examples, and Right Node with 127 Examples
# Creating Child Node With ClassLabel=0, nexamples=1283, classes=[(0, 0.9711613406079501), (2, 0.028838659392049885)]
# Creating Child Node With ClassLabel=0, nexamples=127, classes=[(0, 0.5039370078740157), (1, 0.49606299212598426)]
# Creating Left Child Node With 1491 Examples, and Right Node with 0 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 1491 Examples
# Creating Child Node With ClassLabel=1, nexamples=1491, classes=[(1, 0.9986586183769283), (2, 0.0013413816230717639)]
# Creating Left Child Node With 5464 Examples, and Right Node with 4171 Examples
# Creating Left Child Node With 2408 Examples, and Right Node with 3056 Examples
# Creating Left Child Node With 1081 Examples, and Right Node with 1327 Examples
# Creating Child Node With ClassLabel=0, nexamples=1081, classes=[(0, 0.6253469010175763), (2, 0.2969472710453284), (1, 0.07770582793709528)]
# Creating Child Node With ClassLabel=2, nexamples=1327, classes=[(2, 0.9630746043707611), (0, 0.03692539562923888)]
# Creating Left Child Node With 2487 Examples, and Right Node with 569 Examples
# Creating Child Node With ClassLabel=1, nexamples=2487, classes=[(1, 0.9967832730197025), (0, 0.0024125452352231603), (2, 0.0008041817450743868)]
# Creating Child Node With ClassLabel=2, nexamples=569, classes=[(2, 0.9964850615114236), (1, 0.0035149384885764497)]
# Creating Left Child Node With 2266 Examples, and Right Node with 1905 Examples
# Creating Left Child Node With 1459 Examples, and Right Node with 807 Examples
# Creating Child Node With ClassLabel=2, nexamples=1459, classes=[(2, 0.997943797121316), (1, 0.00205620287868403)]
# Creating Child Node With ClassLabel=2, nexamples=807, classes=[(2, 0.9851301115241635), (0, 0.01486988847583643)]
# Creating Left Child Node With 1476 Examples, and Right Node with 429 Examples
# Creating Child Node With ClassLabel=0, nexamples=1476, classes=[(0, 0.7845528455284553), (2, 0.21544715447154472)]
# Creating Child Node With ClassLabel=0, nexamples=429, classes=[(0, 0.9627039627039627), (2, 0.037296037296037296)]
#
# Creating tree # 16
# Creating Left Child Node With 4355 Examples, and Right Node with 10045 Examples
# Creating Left Child Node With 2124 Examples, and Right Node with 2231 Examples
# Creating Left Child Node With 183 Examples, and Right Node with 1941 Examples
# Creating Left Child Node With 183 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=183, classes=[(2, 0.8797814207650273), (0, 0.12021857923497267)]
# Creating Left Child Node With 1360 Examples, and Right Node with 581 Examples
# Creating Child Node With ClassLabel=2, nexamples=1360, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=581, classes=[(2, 0.9793459552495697), (0, 0.020654044750430294)]
# Creating Left Child Node With 1303 Examples, and Right Node with 928 Examples
# Creating Left Child Node With 265 Examples, and Right Node with 1038 Examples
# Creating Child Node With ClassLabel=2, nexamples=265, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1038, classes=[(0, 0.9585741811175337), (2, 0.041425818882466284)]
# Creating Left Child Node With 20 Examples, and Right Node with 908 Examples
# Creating Child Node With ClassLabel=0, nexamples=20, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=908, classes=[(0, 0.9889867841409692), (2, 0.011013215859030838)]
# Creating Left Child Node With 7940 Examples, and Right Node with 2105 Examples
# Creating Left Child Node With 2198 Examples, and Right Node with 5742 Examples
# Creating Left Child Node With 216 Examples, and Right Node with 1982 Examples
# Creating Child Node With ClassLabel=1, nexamples=216, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1982, classes=[(0, 0.986377396569122), (1, 0.013622603430877902)]
# Creating Left Child Node With 4383 Examples, and Right Node with 1359 Examples
# Creating Child Node With ClassLabel=1, nexamples=4383, classes=[(1, 0.5738078941364362), (2, 0.24001825233858087), (0, 0.1861738535249829)]
# Creating Child Node With ClassLabel=2, nexamples=1359, classes=[(2, 0.9705665930831494), (0, 0.027225901398086828), (1, 0.002207505518763797)]
# Creating Left Child Node With 16 Examples, and Right Node with 2089 Examples
# Creating Child Node With ClassLabel=2, nexamples=16, classes=[(2, 1.0)]
# Creating Left Child Node With 225 Examples, and Right Node with 1864 Examples
# Creating Child Node With ClassLabel=1, nexamples=225, classes=[(1, 0.9911111111111112), (2, 0.008888888888888889)]
# Creating Child Node With ClassLabel=1, nexamples=1864, classes=[(1, 0.9994635193133047), (0, 0.000536480686695279)]
#
# Creating tree # 17
# Creating Left Child Node With 10123 Examples, and Right Node with 4277 Examples
# Creating Left Child Node With 8339 Examples, and Right Node with 1784 Examples
# Creating Left Child Node With 6114 Examples, and Right Node with 2225 Examples
# Creating Left Child Node With 3340 Examples, and Right Node with 2774 Examples
# Creating Child Node With ClassLabel=1, nexamples=3340, classes=[(1, 0.6428143712574851), (0, 0.24790419161676647), (2, 0.1092814371257485)]
# Creating Child Node With ClassLabel=2, nexamples=2774, classes=[(2, 0.8734679163662581), (1, 0.12653208363374188)]
# Creating Left Child Node With 221 Examples, and Right Node with 2004 Examples
# Creating Child Node With ClassLabel=0, nexamples=221, classes=[(0, 0.9411764705882353), (2, 0.058823529411764705)]
# Creating Child Node With ClassLabel=2, nexamples=2004, classes=[(2, 0.9950099800399201), (0, 0.00499001996007984)]
# Creating Left Child Node With 1379 Examples, and Right Node with 405 Examples
# Creating Left Child Node With 1379 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=0, nexamples=1379, classes=[(0, 0.9535895576504714), (2, 0.046410442349528645)]
# Creating Child Node With ClassLabel=0, nexamples=405, classes=[(0, 1.0)]
# Creating Left Child Node With 2712 Examples, and Right Node with 1565 Examples
# Creating Left Child Node With 673 Examples, and Right Node with 2039 Examples
# Creating Child Node With ClassLabel=1, nexamples=673, classes=[(1, 1.0)]
# Creating Left Child Node With 841 Examples, and Right Node with 1198 Examples
# Creating Child Node With ClassLabel=0, nexamples=841, classes=[(0, 0.89179548156956), (1, 0.10820451843043995)]
# Creating Child Node With ClassLabel=0, nexamples=1198, classes=[(0, 1.0)]
# Creating Left Child Node With 12 Examples, and Right Node with 1553 Examples
# Creating Child Node With ClassLabel=2, nexamples=12, classes=[(2, 1.0)]
# Creating Left Child Node With 3 Examples, and Right Node with 1550 Examples
# Creating Child Node With ClassLabel=2, nexamples=3, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1550, classes=[(1, 1.0)]
#
# Creating tree # 18
# Creating Left Child Node With 4533 Examples, and Right Node with 9867 Examples
# Creating Left Child Node With 2511 Examples, and Right Node with 2022 Examples
# Creating Left Child Node With 2466 Examples, and Right Node with 45 Examples
# Creating Left Child Node With 1732 Examples, and Right Node with 734 Examples
# Creating Child Node With ClassLabel=2, nexamples=1732, classes=[(2, 0.9786374133949192), (1, 0.021362586605080832)]
# Creating Child Node With ClassLabel=2, nexamples=734, classes=[(2, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 45 Examples
# Creating Child Node With ClassLabel=2, nexamples=45, classes=[(2, 0.7333333333333333), (0, 0.26666666666666666)]
# Creating Left Child Node With 1039 Examples, and Right Node with 983 Examples
# Creating Left Child Node With 289 Examples, and Right Node with 750 Examples
# Creating Child Node With ClassLabel=0, nexamples=289, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=750, classes=[(0, 0.608), (2, 0.392)]
# Creating Left Child Node With 350 Examples, and Right Node with 633 Examples
# Creating Child Node With ClassLabel=0, nexamples=350, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=633, classes=[(0, 0.9684044233807267), (2, 0.0315955766192733)]
# Creating Left Child Node With 2655 Examples, and Right Node with 7212 Examples
# Creating Left Child Node With 265 Examples, and Right Node with 2390 Examples
# Creating Left Child Node With 265 Examples, and Right Node with 0 Examples
# Creating Child Node With ClassLabel=2, nexamples=265, classes=[(2, 0.9962264150943396), (1, 0.0037735849056603774)]
# Creating Left Child Node With 0 Examples, and Right Node with 2390 Examples
# Creating Child Node With ClassLabel=1, nexamples=2390, classes=[(1, 0.999163179916318), (0, 0.0008368200836820083)]
# Creating Left Child Node With 4799 Examples, and Right Node with 2413 Examples
# Creating Left Child Node With 2766 Examples, and Right Node with 2033 Examples
# Creating Child Node With ClassLabel=2, nexamples=2766, classes=[(2, 0.5365148228488793), (0, 0.43853940708604483), (1, 0.024945770065075923)]
# Creating Child Node With ClassLabel=0, nexamples=2033, classes=[(0, 0.9301524840137727), (1, 0.06984751598622725)]
# Creating Left Child Node With 2052 Examples, and Right Node with 361 Examples
# Creating Child Node With ClassLabel=1, nexamples=2052, classes=[(1, 0.996588693957115), (0, 0.0029239766081871343), (2, 0.0004873294346978557)]
# Creating Child Node With ClassLabel=2, nexamples=361, classes=[(2, 0.7119113573407202), (1, 0.2880886426592798)]
#
# Creating tree # 19
# Creating Left Child Node With 2676 Examples, and Right Node with 11724 Examples
# Creating Left Child Node With 273 Examples, and Right Node with 2403 Examples
# Creating Left Child Node With 265 Examples, and Right Node with 8 Examples
# Creating Child Node With ClassLabel=2, nexamples=265, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=8, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 2403 Examples
# Creating Left Child Node With 0 Examples, and Right Node with 2403 Examples
# Creating Child Node With ClassLabel=1, nexamples=2403, classes=[(1, 0.9991677070328756), (0, 0.0004161464835622139), (2, 0.0004161464835622139)]
# Creating Left Child Node With 6333 Examples, and Right Node with 5391 Examples
# Creating Left Child Node With 4542 Examples, and Right Node with 1791 Examples
# Creating Left Child Node With 1299 Examples, and Right Node with 3243 Examples
# Creating Child Node With ClassLabel=0, nexamples=1299, classes=[(0, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=3243, classes=[(2, 0.8134443416589577), (0, 0.18501387604070305), (1, 0.001541782300339192)]
# Creating Left Child Node With 588 Examples, and Right Node with 1203 Examples
# Creating Child Node With ClassLabel=0, nexamples=588, classes=[(0, 0.7925170068027211), (1, 0.20748299319727892)]
# Creating Child Node With ClassLabel=0, nexamples=1203, classes=[(0, 1.0)]
# Creating Left Child Node With 3697 Examples, and Right Node with 1694 Examples
# Creating Left Child Node With 3407 Examples, and Right Node with 290 Examples
# Creating Child Node With ClassLabel=1, nexamples=3407, classes=[(1, 0.6747872028177282), (0, 0.30584091576166716), (2, 0.01937188142060464)]
# Creating Child Node With ClassLabel=2, nexamples=290, classes=[(2, 1.0)]
# Creating Left Child Node With 1532 Examples, and Right Node with 162 Examples
# Creating Child Node With ClassLabel=2, nexamples=1532, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=162, classes=[(0, 0.7283950617283951), (2, 0.2716049382716049)]
#
# Creating tree # 20
# Creating Left Child Node With 10930 Examples, and Right Node with 3470 Examples
# Creating Left Child Node With 5461 Examples, and Right Node with 5469 Examples
# Creating Left Child Node With 3560 Examples, and Right Node with 1901 Examples
# Creating Left Child Node With 2253 Examples, and Right Node with 1307 Examples
# Creating Child Node With ClassLabel=0, nexamples=2253, classes=[(0, 0.571682201509099), (1, 0.37727474478473144), (2, 0.05104305370616955)]
# Creating Child Node With ClassLabel=1, nexamples=1307, classes=[(1, 0.9961744452945677), (0, 0.0038255547054322878)]
# Creating Left Child Node With 1255 Examples, and Right Node with 646 Examples
# Creating Child Node With ClassLabel=1, nexamples=1255, classes=[(1, 0.8677290836653386), (2, 0.13227091633466134)]
# Creating Child Node With ClassLabel=1, nexamples=646, classes=[(1, 1.0)]
# Creating Left Child Node With 2470 Examples, and Right Node with 2999 Examples
# Creating Left Child Node With 1681 Examples, and Right Node with 789 Examples
# Creating Child Node With ClassLabel=1, nexamples=1681, classes=[(1, 0.5318262938726949), (0, 0.4681737061273052)]
# Creating Child Node With ClassLabel=0, nexamples=789, classes=[(0, 1.0)]
# Creating Left Child Node With 2005 Examples, and Right Node with 994 Examples
# Creating Child Node With ClassLabel=2, nexamples=2005, classes=[(2, 0.969077306733167), (0, 0.023940149625935162), (1, 0.006982543640897756)]
# Creating Child Node With ClassLabel=0, nexamples=994, classes=[(0, 0.9054325955734407), (2, 0.09456740442655935)]
# Creating Left Child Node With 1578 Examples, and Right Node with 1892 Examples
# Creating Left Child Node With 791 Examples, and Right Node with 787 Examples
# Creating Child Node With ClassLabel=2, nexamples=791, classes=[(2, 1.0)]
# Creating Left Child Node With 18 Examples, and Right Node with 769 Examples
# Creating Child Node With ClassLabel=1, nexamples=18, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=769, classes=[(2, 0.9908972691807543), (0, 0.009102730819245773)]
# Creating Left Child Node With 6 Examples, and Right Node with 1886 Examples
# Creating Child Node With ClassLabel=0, nexamples=6, classes=[(0, 1.0)]
# Creating Left Child Node With 65 Examples, and Right Node with 1821 Examples
# Creating Child Node With ClassLabel=2, nexamples=65, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1821, classes=[(0, 0.5079626578802856), (2, 0.49203734211971445)]
#
# Creating tree # 21
# Creating Left Child Node With 4627 Examples, and Right Node with 9773 Examples
# Creating Left Child Node With 2967 Examples, and Right Node with 1660 Examples
# Creating Left Child Node With 460 Examples, and Right Node with 2507 Examples
# Creating Left Child Node With 89 Examples, and Right Node with 371 Examples
# Creating Child Node With ClassLabel=1, nexamples=89, classes=[(1, 0.5168539325842697), (2, 0.48314606741573035)]
# Creating Child Node With ClassLabel=1, nexamples=371, classes=[(1, 1.0)]
# Creating Left Child Node With 1312 Examples, and Right Node with 1195 Examples
# Creating Child Node With ClassLabel=1, nexamples=1312, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=1195, classes=[(1, 0.9548117154811715), (0, 0.045188284518828455)]
# Creating Left Child Node With 1225 Examples, and Right Node with 435 Examples
# Creating Child Node With ClassLabel=2, nexamples=1225, classes=[(2, 1.0)]
# Creating Left Child Node With 430 Examples, and Right Node with 5 Examples
# Creating Child Node With ClassLabel=2, nexamples=430, classes=[(2, 0.9906976744186047), (0, 0.009302325581395349)]
# Creating Child Node With ClassLabel=0, nexamples=5, classes=[(0, 1.0)]
# Creating Left Child Node With 4321 Examples, and Right Node with 5452 Examples
# Creating Left Child Node With 3302 Examples, and Right Node with 1019 Examples
# Creating Left Child Node With 1931 Examples, and Right Node with 1371 Examples
# Creating Child Node With ClassLabel=2, nexamples=1931, classes=[(2, 0.7980321077162092), (0, 0.20196789228379078)]
# Creating Child Node With ClassLabel=0, nexamples=1371, classes=[(0, 0.9416484318016046), (2, 0.058351568198395334)]
# Creating Left Child Node With 292 Examples, and Right Node with 727 Examples
# Creating Child Node With ClassLabel=2, nexamples=292, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=727, classes=[(0, 0.9105914718019257), (1, 0.08665749656121045), (2, 0.002751031636863824)]
# Creating Left Child Node With 2697 Examples, and Right Node with 2755 Examples
# Creating Left Child Node With 1700 Examples, and Right Node with 997 Examples
# Creating Child Node With ClassLabel=2, nexamples=1700, classes=[(2, 0.5552941176470588), (0, 0.35411764705882354), (1, 0.09058823529411765)]
# Creating Child Node With ClassLabel=1, nexamples=997, classes=[(1, 0.7362086258776329), (2, 0.2637913741223671)]
# Creating Left Child Node With 921 Examples, and Right Node with 1834 Examples
# Creating Child Node With ClassLabel=1, nexamples=921, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=1834, classes=[(0, 0.9814612868047983), (1, 0.018538713195201745)]
#
# Creating tree # 22
# Creating Left Child Node With 10065 Examples, and Right Node with 4335 Examples
# Creating Left Child Node With 3918 Examples, and Right Node with 6147 Examples
# Creating Left Child Node With 2559 Examples, and Right Node with 1359 Examples
# Creating Left Child Node With 1777 Examples, and Right Node with 782 Examples
# Creating Child Node With ClassLabel=1, nexamples=1777, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=782, classes=[(1, 0.8734015345268542), (0, 0.1265984654731458)]
# Creating Left Child Node With 1237 Examples, and Right Node with 122 Examples
# Creating Child Node With ClassLabel=2, nexamples=1237, classes=[(2, 0.7720291026677445), (1, 0.22797089733225545)]
# Creating Child Node With ClassLabel=1, nexamples=122, classes=[(1, 0.9918032786885246), (2, 0.00819672131147541)]
# Creating Left Child Node With 1522 Examples, and Right Node with 4625 Examples
# Creating Left Child Node With 1485 Examples, and Right Node with 37 Examples
# Creating Child Node With ClassLabel=1, nexamples=1485, classes=[(1, 0.9946127946127946), (0, 0.0047138047138047135), (2, 0.0006734006734006734)]
# Creating Child Node With ClassLabel=2, nexamples=37, classes=[(2, 1.0)]
# Creating Left Child Node With 2056 Examples, and Right Node with 2569 Examples
# Creating Child Node With ClassLabel=0, nexamples=2056, classes=[(0, 0.7845330739299611), (1, 0.2130350194552529), (2, 0.0024319066147859923)]
# Creating Child Node With ClassLabel=2, nexamples=2569, classes=[(2, 0.5321136629038536), (0, 0.4367458154924095), (1, 0.031140521603736863)]
# Creating Left Child Node With 2446 Examples, and Right Node with 1889 Examples
# Creating Left Child Node With 2085 Examples, and Right Node with 361 Examples
# Creating Left Child Node With 2035 Examples, and Right Node with 50 Examples
# Creating Child Node With ClassLabel=2, nexamples=2035, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=2, nexamples=50, classes=[(2, 0.72), (0, 0.28)]
# Creating Left Child Node With 258 Examples, and Right Node with 103 Examples
# Creating Child Node With ClassLabel=2, nexamples=258, classes=[(2, 0.9767441860465116), (0, 0.023255813953488372)]
# Creating Child Node With ClassLabel=0, nexamples=103, classes=[(0, 1.0)]
# Creating Left Child Node With 1044 Examples, and Right Node with 845 Examples
# Creating Left Child Node With 923 Examples, and Right Node with 121 Examples
# Creating Child Node With ClassLabel=0, nexamples=923, classes=[(0, 0.9815817984832069), (2, 0.018418201516793065)]
# Creating Child Node With ClassLabel=2, nexamples=121, classes=[(2, 0.5785123966942148), (0, 0.4214876033057851)]
# Creating Child Node With ClassLabel=0, nexamples=845, classes=[(0, 1.0)]
#
# Creating tree # 23
# Creating Left Child Node With 10445 Examples, and Right Node with 3955 Examples
# Creating Left Child Node With 6867 Examples, and Right Node with 3578 Examples
# Creating Left Child Node With 3944 Examples, and Right Node with 2923 Examples
# Creating Left Child Node With 2262 Examples, and Right Node with 1682 Examples
# Creating Child Node With ClassLabel=0, nexamples=2262, classes=[(0, 0.5658709106984969), (2, 0.374447391688771), (1, 0.05968169761273209)]
# Creating Child Node With ClassLabel=1, nexamples=1682, classes=[(1, 0.8228299643281808), (2, 0.17717003567181927)]
# Creating Left Child Node With 1891 Examples, and Right Node with 1032 Examples
# Creating Child Node With ClassLabel=2, nexamples=1891, classes=[(2, 0.9941829719725013), (0, 0.005817028027498678)]
# Creating Child Node With ClassLabel=0, nexamples=1032, classes=[(0, 0.688953488372093), (2, 0.311046511627907)]
# Creating Left Child Node With 1472 Examples, and Right Node with 2106 Examples
# Creating Left Child Node With 1022 Examples, and Right Node with 450 Examples
# Creating Child Node With ClassLabel=0, nexamples=1022, classes=[(0, 0.9256360078277887), (2, 0.07436399217221135)]
# Creating Child Node With ClassLabel=2, nexamples=450, classes=[(2, 0.96), (0, 0.04)]
# Creating Left Child Node With 894 Examples, and Right Node with 1212 Examples
# Creating Child Node With ClassLabel=0, nexamples=894, classes=[(0, 0.5413870246085011), (1, 0.45861297539149887)]
# Creating Child Node With ClassLabel=0, nexamples=1212, classes=[(0, 1.0)]
# Creating Left Child Node With 2573 Examples, and Right Node with 1382 Examples
# Creating Left Child Node With 1346 Examples, and Right Node with 1227 Examples
# Creating Left Child Node With 154 Examples, and Right Node with 1192 Examples
# Creating Child Node With ClassLabel=1, nexamples=154, classes=[(1, 0.9285714285714286), (0, 0.07142857142857142)]
# Creating Child Node With ClassLabel=1, nexamples=1192, classes=[(1, 1.0)]
# Creating Left Child Node With 0 Examples, and Right Node with 1227 Examples
# Creating Child Node With ClassLabel=1, nexamples=1227, classes=[(1, 0.9233903830480847), (0, 0.07660961695191525)]
# Creating Left Child Node With 394 Examples, and Right Node with 988 Examples
# Creating Left Child Node With 146 Examples, and Right Node with 248 Examples
# Creating Child Node With ClassLabel=1, nexamples=146, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=248, classes=[(1, 0.7862903225806451), (2, 0.21370967741935484)]
# Creating Left Child Node With 788 Examples, and Right Node with 200 Examples
# Creating Child Node With ClassLabel=2, nexamples=788, classes=[(2, 0.9098984771573604), (1, 0.0901015228426396)]
# Creating Child Node With ClassLabel=2, nexamples=200, classes=[(2, 1.0)]
#
# Creating tree # 24
# Creating Left Child Node With 9519 Examples, and Right Node with 4881 Examples
# Creating Left Child Node With 7608 Examples, and Right Node with 1911 Examples
# Creating Left Child Node With 5382 Examples, and Right Node with 2226 Examples
# Creating Left Child Node With 1597 Examples, and Right Node with 3785 Examples
# Creating Child Node With ClassLabel=1, nexamples=1597, classes=[(1, 0.7946149029430182), (0, 0.20538509705698185)]
# Creating Child Node With ClassLabel=0, nexamples=3785, classes=[(0, 0.5297225891677675), (2, 0.25072655217965656), (1, 0.21955085865257595)]
# Creating Left Child Node With 0 Examples, and Right Node with 2226 Examples
# Creating Child Node With ClassLabel=1, nexamples=2226, classes=[(1, 0.9986522911051213), (0, 0.0008984725965858042), (2, 0.0004492362982929021)]
# Creating Left Child Node With 464 Examples, and Right Node with 1447 Examples
# Creating Left Child Node With 63 Examples, and Right Node with 401 Examples
# Creating Child Node With ClassLabel=1, nexamples=63, classes=[(1, 1.0)]
# Creating Child Node With ClassLabel=1, nexamples=401, classes=[(1, 0.8753117206982544), (2, 0.12468827930174564)]
# Creating Child Node With ClassLabel=2, nexamples=1447, classes=[(2, 1.0)]
# Creating Left Child Node With 2269 Examples, and Right Node with 2612 Examples
# Creating Left Child Node With 1252 Examples, and Right Node with 1017 Examples
# Creating Left Child Node With 1249 Examples, and Right Node with 3 Examples
# Creating Child Node With ClassLabel=0, nexamples=1249, classes=[(0, 0.9815852682145717), (2, 0.016813450760608487), (1, 0.0016012810248198558)]
# Creating Child Node With ClassLabel=1, nexamples=3, classes=[(1, 1.0)]
# Creating Left Child Node With 275 Examples, and Right Node with 742 Examples
# Creating Child Node With ClassLabel=2, nexamples=275, classes=[(2, 1.0)]
# Creating Child Node With ClassLabel=0, nexamples=742, classes=[(0, 0.9420485175202157), (2, 0.057951482479784364)]
# Creating Left Child Node With 1057 Examples, and Right Node with 1555 Examples
# Creating Left Child Node With 664 Examples, and Right Node with 393 Examples
# Creating Child Node With ClassLabel=0, nexamples=664, classes=[(0, 0.822289156626506), (1, 0.12048192771084337), (2, 0.0572289156626506)]
# Creating Child Node With ClassLabel=2, nexamples=393, classes=[(2, 1.0)]
# Creating Left Child Node With 1543 Examples, and Right Node with 12 Examples
# Creating Child Node With ClassLabel=2, nexamples=1543, classes=[(2, 0.9993519118600129), (0, 0.0006480881399870382)]
# Creating Child Node With ClassLabel=0, nexamples=12, classes=[(0, 1.0)]
